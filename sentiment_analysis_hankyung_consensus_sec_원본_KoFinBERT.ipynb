# %% [markdown]
# predicted_label은 text와 label을 분석하여 산출하고 Bert_Sentiment는 text

# %%
import pandas as pd
import torch
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
from torch.nn import CrossEntropyLoss
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
import matplotlib.pyplot as plt
from transformers import AutoModelForSequenceClassification, AutoTokenizer, TextClassificationPipeline

import numpy as np
import time
from matplotlib import rcParams
# 한글 폰트 설정
rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕으로 설정
rcParams['axes.unicode_minus'] = False     # 음수 기호 문제 해결

# %% [markdown]
# 1. 데이터 준비

# %%
file_path = './Text_Data/한경_리포트_데이터_기업_SEC.xlsx'
df_hankyung_consensus = pd.read_excel(file_path)

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
# ...

# %%
# 종목코드 자리수 맞추기 (종목코드가 숫자로 되어 있는 경우)
df_hankyung_consensus['종목코드'] = df_hankyung_consensus['종목코드'].apply(lambda x: str(x).zfill(6))

# %%
# 평가의견 라벨 변경 (-1, 0, 1 => 0, 1, 2)
df_hankyung_consensus['평가의견_label'] = df_hankyung_consensus['평가의견_label'].map({-1: 0, 0: 1, 1: 2})

# %% [markdown]
# 2. KoBERT 모델 및 토크나이저 로드

# %%
tokenizer = AutoTokenizer.from_pretrained("kwoncho/KoFinBERT")
model = AutoModelForSequenceClassification.from_pretrained("kwoncho/KoFinBERT")
# Out:
# C:\Users\dybae\anaconda3\envs\CUDA1\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# GPU 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
# ...

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# 3. 데이터 분리 및 데이터셋 정의

# %%
train_df, test_df = train_test_split(df_hankyung_consensus, test_size=0.2, random_state=42, stratify=df_hankyung_consensus['평가의견_label'])

# %%
train_df
# Out:
#            작성일   종목명    종목코드                       제목     적정가격 평가의견      작성자  \
# 917 2024-03-14  삼성전자  005930         1Q24 메모리 흑자전환 예상  100,000   매수      한동희
# 289 2018-10-08  삼성전자  005930     사상 최고 실적 vs 불확실한 매크로   57,000  Buy      이승우
# 842 2022-06-20  삼성전자  005930         점점 더 거세지는 매크로 역풍   79,000  Buy      이승우
# 782 2021-10-12  삼성전자  005930   매크로 우려로 실적 전망 및 목표가 하향   93,000  Buy      이승우
# 872 2023-01-09  삼성전자  005930             4Q22 잠정실적 리뷰   82,000  Buy      김광진
# ..         ...   ...     ...                      ...      ...  ...      ...
# 823 2022-02-09  삼성전자  005930                  에게필요한것은   93,000  Buy      이승우
# 516 2019-11-01  삼성전자  005930           매력 대비 아쉬운 영업가치   60,000  Buy  김선우,서승연
# 694 2021-01-04  삼성전자  005930        DRAM 가격 전망치 상향 조정  100,000  Buy      박유악
# 818 2022-01-28  삼성전자  005930       4Q21 실적발표 자료 하이라이트        0    -      김선우
# 607 2020-06-01  삼성전자  005930  메모리 업황 둔화 vs IM과 DP는 회복   62,000  Buy      박유악
#
# ...

# %%
# 데이터셋 클래스
class SentimentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# 데이터셋 준비
max_seq_len = 128
train_dataset = SentimentDataset(train_df['제목_세부내용_전처리후'].tolist(), train_df['평가의견_label'].tolist(), tokenizer, max_seq_len)
test_dataset = SentimentDataset(test_df['제목_세부내용_전처리후'].tolist(), test_df['평가의견_label'].tolist(), tokenizer, max_seq_len)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # 4. KoFinBERT + 분류기 모델 정의

# %%
class KoFinBERTClassifier(nn.Module):
    def __init__(self, bert_model, num_labels=3):
        super(KoFinBERTClassifier, self).__init__()
        self.bert_model = bert_model
        self.device     = device
        self.classifier = nn.Linear(bert_model.config.hidden_size, num_labels)
        self.config = bert_model.config  # config 속성을 추가

    def forward(self, input_ids, attention_mask=None, token_type_ids=None):
        outputs = self.bert_model(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        logits = outputs.logits
        return logits

# 원래 모델을 변경하지 않고 초기화
model = KoFinBERTClassifier(model).to(device)  # 여기서 `model`은 원래 BERT 모델입니다.

# %% [markdown]
# 5. 옵티마이저 및 손실 함수 설정

# %%
optimizer = AdamW(model.parameters(), lr=2e-5)
loss_fn = CrossEntropyLoss()

# %% [markdown]
# 6. 모델 학습 루프

# %%
# 나머지 학습 코드는 그대로 유지
epochs = 5
train_acc_list = []
train_loss_list = []

for epoch in range(epochs):
    start_time = time.time()  # epoch 시작 시간 기록
    
    model.train()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0

    for batch in tqdm(train_loader, desc=f"학습 Epoch {epoch+1}"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds = torch.max(outputs, dim=1)
        correct_predictions += torch.sum(preds == labels)
        total_predictions += labels.size(0)

    train_accuracy = correct_predictions.double() / total_predictions
    avg_train_loss = total_loss / len(train_loader)

    train_acc_list.append(train_accuracy.item())
    train_loss_list.append(avg_train_loss)

    end_time = time.time()  # epoch 끝 시간 기록
    duration = end_time - start_time  # 소요 시간 계산

    print(f"Epoch [{epoch+1}/{epochs}] - 손실: {avg_train_loss:.4f}, 정확도: {train_accuracy:.2%}, 소요 시간: {duration:.2f} 초")
# Out:
# 학습 Epoch 1: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:36<00:00,  3.03s/it]
# Epoch [1/5] - 손실: 0.7299, 정확도: 85.07%, 소요 시간: 36.35 초
# 학습 Epoch 2: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:35<00:00,  3.00s/it]
# Epoch [2/5] - 손실: 0.1728, 정확도: 95.90%, 소요 시간: 36.00 초
# 학습 Epoch 3: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:35<00:00,  2.99s/it]
# Epoch [3/5] - 손실: 0.1713, 정확도: 95.90%, 소요 시간: 35.90 초
# 학습 Epoch 4: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:35<00:00,  2.96s/it]
# Epoch [4/5] - 손실: 0.1706, 정확도: 95.90%, 소요 시간: 35.48 초
# 학습 Epoch 5: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:36<00:00,  3.07s/it]
# Epoch [5/5] - 손실: 0.1694, 정확도: 95.90%, 소요 시간: 36.79 초

# %% [markdown]
# 7. 학습 결과 그래프로 시각화

# %%
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(14, 7))

# Accuracy 그래프
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_acc_list, marker='o', linestyle='-', color='b', label='Train Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Loss 그래프
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_loss_list, marker='o', linestyle='-', color='b', label='Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# %% [markdown]
# 8. 모델 평가 및 정확도 계산

# %%
test_acc_list = []
test_loss_list = []

model.eval()
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels)

        test_loss_list.append(loss.item())

        _, preds = torch.max(outputs, dim=1)
        correct_predictions = torch.sum(preds == labels)
        total_predictions = labels.size(0)

        accuracy = correct_predictions.double() / total_predictions
        test_acc_list.append(accuracy.item())
# Out:
# Evaluating: 100%|████████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.33it/s]

# %% [markdown]
# 9. 예측 결과 추가 및 저장

# %%
def predict_labels(data_loader):
    model.eval()
    all_texts = []
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in tqdm(data_loader, desc="Predicting"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(batch['label'].cpu().numpy())

    return all_labels, all_preds

# %%
# Train 데이터에 대해 예측
train_labels, train_preds = predict_labels(train_loader)
# Out:
# Predicting: 100%|██████████████████████████████████████████████████████████████████████| 12/12 [00:08<00:00,  1.47it/s]

# %%
# Test 데이터에 대해 예측
test_labels, test_preds = predict_labels(test_loader)
# Out:
# Predicting: 100%|████████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.42it/s]

# %%
# DataFrame에 예측 결과 추가
train_df['predicted_label'] = train_preds
test_df['predicted_label'] = test_preds

# %%
# 평가의견_label 및 predicted_label 환원
train_df['평가의견_label'] = train_df['평가의견_label'].map({0: -1, 1: 0, 2: 1})
test_df['평가의견_label'] = test_df['평가의견_label'].map({0: -1, 1: 0, 2: 1})
train_df['predicted_label'] = train_df['predicted_label'].map({0: -1, 1: 0, 2: 1})
test_df['predicted_label'] = test_df['predicted_label'].map({0: -1, 1: 0, 2: 1})

# %%
train_df
# Out:
#            작성일   종목명    종목코드                       제목     적정가격 평가의견      작성자  \
# 917 2024-03-14  삼성전자  005930         1Q24 메모리 흑자전환 예상  100,000   매수      한동희
# 289 2018-10-08  삼성전자  005930     사상 최고 실적 vs 불확실한 매크로   57,000  Buy      이승우
# 842 2022-06-20  삼성전자  005930         점점 더 거세지는 매크로 역풍   79,000  Buy      이승우
# 782 2021-10-12  삼성전자  005930   매크로 우려로 실적 전망 및 목표가 하향   93,000  Buy      이승우
# 872 2023-01-09  삼성전자  005930             4Q22 잠정실적 리뷰   82,000  Buy      김광진
# ..         ...   ...     ...                      ...      ...  ...      ...
# 823 2022-02-09  삼성전자  005930                  에게필요한것은   93,000  Buy      이승우
# 516 2019-11-01  삼성전자  005930           매력 대비 아쉬운 영업가치   60,000  Buy  김선우,서승연
# 694 2021-01-04  삼성전자  005930        DRAM 가격 전망치 상향 조정  100,000  Buy      박유악
# 818 2022-01-28  삼성전자  005930       4Q21 실적발표 자료 하이라이트        0    -      김선우
# 607 2020-06-01  삼성전자  005930  메모리 업황 둔화 vs IM과 DP는 회복   62,000  Buy      박유악
#
# ...

# %%
test_df
# Out:
#            작성일   종목명    종목코드                              제목     적정가격 평가의견  \
# 405 2019-03-27  삼성전자  005930                    큰 방향의 중심에 있다   52,000  Buy
# 593 2020-05-04  삼성전자  005930       보수적 가이던스 제시했으나 장기적으로는 긍정적   60,000  Buy
# 357 2019-01-09  삼성전자  005930               수요 급감 속의 실적 Shock   50,000  Buy
# 669 2020-10-30  삼성전자  005930      투자에 대한 시각을 DRAM으로 옮겨야 할 시기   75,000  Buy
# 204 2018-06-11  삼성전자  005930             전자도 어쩔 수 없는 스마트폰 시장   68,000  Buy
# ..         ...   ...     ...                             ...      ...  ...
# 784 2021-10-12  삼성전자  005930            우려했던 NAND의 업황 둔화 가시화   95,000  Buy
# 247 2018-08-01  삼성전자  005930  2Q18 실적 컨퍼런스 콜이 주는 Implication   76,000  Buy
# 527 2019-11-19  삼성전자  005930                      한고비넘어두개의선물   63,000  Buy
# 751 2021-06-24  삼성전자  005930      단기 실적 모멘텀 vs 4Q21 이후 우려 요인  107,000  Buy
# 511 2019-10-16  삼성전자  005930        19 3Q 빠르게 감소한 메모리 반도체 재고   60,000  Buy
#
# ...

# %% [markdown]
# 10. 감정 분석을 위한 KoFinBERT Sentiment score 산출

# %%
text_classifier = TextClassificationPipeline(
    tokenizer=tokenizer,
    model=AutoModelForSequenceClassification.from_pretrained("kwoncho/KoFinBERT"),  
    top_k=None,  # 모든 레이블의 확률 반환
    device=0 if torch.cuda.is_available() else -1  
)

# %%
predicted_train_scores = []
for text in train_df['제목_세부내용_전처리후'] :
    # 감정 분석 수행
    prediction = text_classifier(text)
    
    # 레이블을 숫자 값으로 매핑
    label_mapping = {
        'positive': 1,
        'neutral': 0,
        'negative': -1
    }
    
    # 연속적인 점수 직접 계산
    score = 0
    for item in prediction[0]:
        label = item['label']
        prob = item['score']
        score += label_mapping[label] * prob

    predicted_train_scores.append(score)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
predicted_test_scores = []
for text in test_df['제목_세부내용_전처리후'] :
    # 감정 분석 수행
    prediction = text_classifier(text)
    
    # 레이블을 숫자 값으로 매핑
    label_mapping = {
        'positive': 1,
        'neutral': 0,
        'negative': -1
    }
    
    # 연속적인 점수 직접 계산
    score = 0
    for item in prediction[0]:
        label = item['label']
        prob = item['score']
        score += label_mapping[label] * prob
    predicted_test_scores.append(score)

# %%
predicted_train_scores
# Out:
# [0.9969551096437499,
#  -0.022253311472013593,
#  -0.9959620127920061,
#  -0.9947399124503136,
#  -0.9957253654720262,
#  0.9961529232095927,
#  -7.708696648478508e-05,
#  -0.8417826220393181,
#  -0.9898109886562452,
#  0.9969563944032416,
#  -0.00039926532190293074,
#  0.9673196811927482,
#  -0.9959118478000164,
#  0.9958904221421108,
#  -0.0006475266418419778,
#  0.9966932294191793,
#  0.0036686736857518554,
#  0.47495136596262455,
#  0.9969707293203101,
#  0.10376253561116755,
#  0.003435525286477059,
#  0.9962352736038156,
#  -0.9957086051581427,
#  0.9964602321851999,
#  0.9617897756397724,
#  0.9963809337932616,
#  0.996837331331335,
#  0.10502806457225233,
#  0.9925538287498057,
#  0.8450437212595716,
#  -7.38480594009161e-07,
#  0.0016421069449279457,
#  0.997057132597547,
#  0.9968625293113291,
#  0.6121918626595289,
#  -0.9953443940030411,
#  -0.0003291452885605395,
#  0.9970055984449573,
#  0.9957990333205089,
#  0.03128807072062045,
#  0.9961879882030189,
# ...

# %%
# DataFrame에 감정 분석 결과 추가
train_df['KoFinBERT_Sentiment'] = predicted_train_scores
test_df['KoFinBERT_Sentiment'] = predicted_test_scores

# %%
# train_df와 test_df를 합쳐서 저장
combined_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
combined_df = combined_df.sort_values(by=['작성일', '작성기관'])

# %%
combined_df
# Out:
#            작성일   종목명    종목코드                                 제목       적정가격  \
# 232 2017-09-06  삼성전자  005930                    조정의 빌미는 사라지고 있나  2,800,000
# 834 2017-09-08  삼성전자  005930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000
# 161 2017-09-08  삼성전자  005930                      3분기 증익을 예상합니다  3,300,000
# 675 2017-09-08  삼성전자  005930                    3분기 감익 우려 해소 기대  3,100,000
# 900 2017-09-11  삼성전자  005930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000
# ..         ...   ...     ...                                ...        ...
# 416 2024-08-01  삼성전자  005930                  메모리반도체 수익성 개선 본격화    110,000
# 48  2024-08-01  삼성전자  005930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000
# 61  2024-08-01  삼성전자  005930                       HBM 경쟁 심화 예상     97,000
# 147 2024-08-01  삼성전자  005930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000
# 231 2024-08-07  삼성전자  005930              추세 하락 이전에 주가 반등 가능할 듯     87,000
#
#     평가의견       작성자     작성기관  \
# 232  Buy       황민성     삼성증권
# ...

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT.xlsx', index=False)

# %% [markdown]
# 여기서부터 소수점 1자리로 처리하기 위한 코드

# %%
# EXCEL파일 읽기
file_path = './Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT.xlsx'
combined_df = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# %%
combined_df
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
# ...

# %%
combined_df = combined_df[['작성일', '종목명', '종목코드', '제목', '적정가격', '평가의견', '작성자',
                           '작성기관', '제목_세부내용_전처리후', 'KoFinBERT_Sentiment']]

# %%
# 소수점 1자리로 반올림
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# Out:
# C:\Users\dybae\AppData\Local\Temp\ipykernel_41140\3055127085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
# C:\Users\dybae\AppData\Local\Temp\ipykernel_41140\3055127085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)

# %%
combined_df
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
# ...

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT.xlsx', index=False)
#
# NameError: name 'combined_df' is not defined

# %%
combined_df = combined_df.groupby('작성일', as_index=False)['KoFinBERT_Sentiment'].mean()
# 소수점 1자리로 반올림
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
combined_df
# Out:
#            작성일  KoFinBERT_Sentiment
# 0   2017-09-06                  1.0
# 1   2017-09-08                  1.0
# 2   2017-09-11                  1.0
# 3   2017-09-12                  1.0
# 4   2017-09-13                  1.0
# ..         ...                  ...
# 425 2024-06-24                  1.0
# 426 2024-07-02                  1.0
# 427 2024-07-05                  0.9
# 428 2024-08-01                  1.0
# 429 2024-08-07                  1.0
#
# [430 rows x 2 columns]

# %%
combined_df
# Out:
#            작성일  KoFinBERT_Sentiment
# 0   2017-09-06                  1.0
# 1   2017-09-08                  1.0
# 2   2017-09-11                  1.0
# 3   2017-09-12                  1.0
# 4   2017-09-13                  1.0
# ..         ...                  ...
# 425 2024-06-24                  1.0
# 426 2024-07-02                  1.0
# 427 2024-07-05                  0.9
# 428 2024-08-01                  1.0
# 429 2024-08-07                  1.0
#
# [430 rows x 2 columns]

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT_daily.xlsx', index=False)

# %%
df_hankyung_consesus_sec = pd.read_excel('./Text_Data/한경_리포트_데이터_기업_SEC_원본_KoFinBERT.xlsx')

# %%
df_hankyung_consesus_sec
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_hankyung_consesus_sec['작성일'] = pd.to_datetime(df_hankyung_consesus_sec['작성일'])

sentiment_by_date = df_hankyung_consesus_sec.groupby('작성일')['KoFinBERT_Sentiment'].mean()

plt.figure(figsize=(10, 5))
plt.plot(sentiment_by_date.index, sentiment_by_date.values, marker='o', linestyle='-', color='b')

# 그래프 제목 및 라벨 설정
plt.title('일자별 KoFinBERT 감정 점수 분포')
plt.xlabel('일자')
plt.ylabel('평균 감정 점수')
plt.grid(True)
plt.show()
