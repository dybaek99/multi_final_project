# %% [markdown]
# predicted_label은 text와 label을 분석하여 산출하고 Bert_Sentiment는 text

# %%
import pandas as pd
import torch
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
from torch.nn import CrossEntropyLoss
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
import matplotlib.pyplot as plt
from transformers import AutoModelForSequenceClassification, AutoTokenizer, TextClassificationPipeline

import numpy as np
import time
from matplotlib import rcParams
# 한글 폰트 설정
rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕으로 설정
rcParams['axes.unicode_minus'] = False     # 음수 기호 문제 해결

# %% [markdown]
# 1. 데이터 준비

# %%
file_path = './Text_Data/한경_리포트_데이터_기업_SEC.xlsx'
df_hankyung_consensus = pd.read_excel(file_path)

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
#           작성자     작성기관                                               세부내용  \
# 0         황민성     삼성증권  삼성전자(005930)조정의 빌미는 사라지고 있나?반도체 혁신으로 메모리 반도체 제...
# 1         김선우  메리츠종금증권  삼성전자(005930)실적 성장 재개와 함께 강화되는 주주환원시장 기대치를 소폭 능...
# 2         어규진   이베스트증권       삼성전자(005930)3분기 증익을 예상합니다!3분기 영업이익 14.3조원 전망
# 3     이순학,김정현   한화투자증권         삼성전자(005930)3분기 감익 우려 해소 기대4분기 서프라이즈 실적 기대
# 4         박유악     키움증권  삼성전자(005930)3Q17 영업이익 총 15조원, 반도체 10조원 전망3Q17 ...
# ..        ...      ...                                                ...
# 942       백길현    유안타증권    삼성전자(005930) 메모리반도체 수익성 개선 본격화메모리반도체 수익성 개선 본격화
# 943       이승우   유진투자증권  삼성전자(005930) TSMC와의 시가총액 격차를 좁혀나 갈 시간TSMC와의 시가...
# 944   송명섭,손우성   하이투자증권              삼성전자(005930) HBM 경쟁 심화 예상HBM 경쟁 심화 예상
# 945  김광진,최영주    한화투자증권  삼성전자(005930) 여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주...
# 946       송명섭   하이투자증권  삼성전자(005930) 추세 하락 이전에 주가 반등 가능할 듯추세 하락 이전에 주가...
#
#                                              세부내용_전처리후  \
# 0      반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. 매수의견과 목표가 280만...
# 1     시장 기대치를 소폭 능가하는 3Q17 영업이익 14.3조원 전망 지속 유지 4Q1...
# 2                                   3분기 영업이익 14.3조원 전망
# 3                                      4분기 서프라이즈 실적 기대
# 4                         3Q17 영업이익 15조원 시장 기대치 상회할 전망
# ..                                                 ...
# 942
# 943
# 944
# 945   여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주가여전히 강력한 AI발...
# 946
#
#                                           제목_세부내용_전처리후  \
# 0    조정의 빌미는 사라지고 있나 반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. ...
# 1    실적 성장 재개와 함께 강화되는 주주환원 시장 기대치를 소폭 능가하는 3Q17 영업...
# 2                     3분기 증익을 예상합니다 3분기 영업이익 14.3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                  메모리반도체 수익성 개선 본격화
# 943                           TSMC와의 시가총액 격차를 좁혀나 갈 시간
# 944                                       HBM 경쟁 심화 예상
# 945  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가 여전히 강력한 AI발 ...
# 946                              추세 하락 이전에 주가 반등 가능할 듯
#
#                                       제목_세부내용_전처리후_Okt  \
# 0    조정 빌 미는 사라지고 있나 반도체 혁신 메모리 반도체 값 받기는 진행 중 수 의견...
# 1    실적 성장 재개 강화 되는 주주 환원 시장 기 대치 소 폭 능가 하는 3 Q 17 ...
# 2                  3분 기 증익 예상 합니다 3분 기 영업 이익 14.3조원 전망
# 3                    3분 기 감익 우려 해소 기대 4분 기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15조원 반도체 10조원 전망 3 Q 17 영업 이익 1...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                              TSMC 와의 시가총액 격차 좁혀나 갈
# 944                                       HBM 경쟁 심화 예상
# 945  강력한 AI 발 수요 조 정기 거치 며 더욱 편해진 주가 강력한 AI 발 수요 조 ...
# 946                               추세 하락 이전 주가 반등 가능할 듯
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2                    3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                 메모리반도체 수익성 개 선 본격화
# 943                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_Kkma  \
# 0    조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2                3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 3                  3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                                 메모리 반도체 수익성 개선 본격화
# 943                              TSMC 와의 시가 총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                   제목_세부내용_전처리후_Komoran  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2               3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 3                   3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                                  TSMC 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_kiwi  \
# 0           조정 빌미 반도체 혁신 메모리 반도체 제값 진행 매수 의견 목표 280 유지
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 14.3 전...
# 2                               분기 예상 분기 영업 이익 14.3 전망
# 3                           분기 우려 해소 기대 분기 서프라이즈 실적 기대
# 4       17 영업 이익 15 반도체 10 전망 17 영업 이익 15 시장 기대치 상회 전망
# ..                                                 ...
# 942                                   메모리 반도체 수익 개선 본격
# 943                                      TSMC 시가 총액 격차
# 944                                       HBM 경쟁 심화 예상
# 945          AI 수요 조정기 편하 AI 수요 조정기 편하 AI 수요 조정기 편하 주가
# 946                                  추세 하락 이전 주가 반등 가능
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label
# 0          조정 빌미 반도체 혁신 메모리 반도체 제값 진행 중 매수 의견 목표 만원 유지           1
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 원 전망 지...           1
# 2                              분기 증 익 예상 분기 영업 이익 원 전망           1
# 3                       분기 감 익 우려 해소 기대 분기 서프라이즈 실적 기대           1
# 4           17 영업 이익 원 반도체 원 전망 17 영업 이익 원 시장 기대 상회 전망           1
# ..                                                 ...         ...
# 942                                      메모리 반도체 수익 개선           1
# 943                                            시가총액 격차           1
# 944                                           경쟁 심화 예상           1
# 945    발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가           1
# 946                                   추세 하락 이전 주가 반등 듯           1
#
# [947 rows x 18 columns]

# %%
# 종목코드 자리수 맞추기 (종목코드가 숫자로 되어 있는 경우)
df_hankyung_consensus['종목코드'] = df_hankyung_consensus['종목코드'].apply(lambda x: str(x).zfill(6))

# %%
# 평가의견 라벨 변경 (-1, 0, 1 => 0, 1, 2)
df_hankyung_consensus['평가의견_label'] = df_hankyung_consensus['평가의견_label'].map({-1: 0, 0: 1, 1: 2})

# %% [markdown]
# 2. KoBERT 모델 및 토크나이저 로드

# %%
tokenizer = AutoTokenizer.from_pretrained("kwoncho/KoFinBERT")
model = AutoModelForSequenceClassification.from_pretrained("kwoncho/KoFinBERT")
# Out:
# C:\Users\dybae\anaconda3\envs\CUDA1\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# GPU 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# 3. 데이터 분리 및 데이터셋 정의

# %%
train_df, test_df = train_test_split(df_hankyung_consensus, test_size=0.2, random_state=42, stratify=df_hankyung_consensus['평가의견_label'])

# %%
train_df
# Out:
#            작성일   종목명    종목코드                       제목     적정가격 평가의견      작성자  \
# 917 2024-03-14  삼성전자  005930         1Q24 메모리 흑자전환 예상  100,000   매수      한동희
# 289 2018-10-08  삼성전자  005930     사상 최고 실적 vs 불확실한 매크로   57,000  Buy      이승우
# 842 2022-06-20  삼성전자  005930         점점 더 거세지는 매크로 역풍   79,000  Buy      이승우
# 782 2021-10-12  삼성전자  005930   매크로 우려로 실적 전망 및 목표가 하향   93,000  Buy      이승우
# 872 2023-01-09  삼성전자  005930             4Q22 잠정실적 리뷰   82,000  Buy      김광진
# ..         ...   ...     ...                      ...      ...  ...      ...
# 823 2022-02-09  삼성전자  005930                  에게필요한것은   93,000  Buy      이승우
# 516 2019-11-01  삼성전자  005930           매력 대비 아쉬운 영업가치   60,000  Buy  김선우,서승연
# 694 2021-01-04  삼성전자  005930        DRAM 가격 전망치 상향 조정  100,000  Buy      박유악
# 818 2022-01-28  삼성전자  005930       4Q21 실적발표 자료 하이라이트        0    -      김선우
# 607 2020-06-01  삼성전자  005930  메모리 업황 둔화 vs IM과 DP는 회복   62,000  Buy      박유악
#
#         작성기관                                               세부내용  \
# 917     SK증권      삼성전자(005930) 1Q24 메모리 흑자전환 예상1Q24 메모리 흑자전환 예상
# 289   유진투자증권  삼성전자(005930)사상 최고 실적  vs. 불확실한 매크로삼성전자(005930)...
# 842   유진투자증권  삼성전자(005930) 점점 더 거세지는 매크로 역풍What’s New : 하이 인...
# 782   유진투자증권  삼성전자(005930)매크로 우려로 실적 전망 및 목표가 하향What’s New: ...
# 872   한화투자증권  삼성전자(005930) 4Q22 잠정실적 리뷰4Q22 잠정실적 Review : 전 ...
# ..       ...                                                ...
# 823   유진투자증권   삼성전자(005930)삼성전자에게필요한것은?삼성전자(005930)삼성전자에게필요한것은?
# 516  메리츠종금증권           삼성전자(005930)매력 대비 아쉬운 영업가치매력 대비 아쉬운 영업가치
# 694     키움증권  삼성전자(005930)DRAM 가격 전망치 상향 조정4Q20 영업이익 9.2조원, ...
# 818    메리츠증권   삼성전자(005930)4Q21 실적발표 자료 하이라이트4Q21 실적발표 자료 하이라이트
# 607     키움증권  삼성전자(005930)메모리 업황 둔화 vs. IM과 DP는 회복메모리 업황 둔화 ...
#
#                                              세부내용_전처리후  \
# 917
# 289        사상 최고 실적 vs. 불확실한 매크로 사상 최고 실적 vs. 불확실한 매크로
# 842   What s New 하이 인플레이션과 자이언트 스텝 2Q Preview 세트 사업...
# 782            What s New 3 분기 실적은 예상 수준이나 매크로 우려가 높아짐
# 872     4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q23 실적 부진 지속 예상
# ..                                                 ...
# 823
# 516
# 694   4Q20 영업이익 9.2조원 세트 부문 부진 예상 1Q21 영업이익 8조원 분기 ...
# 818
# 607   메모리 업황 둔화 vs. IM과 DP는 회복메모리 업황 둔화 vs. IM과 DP는 회복
#
#                                           제목_세부내용_전처리후  \
# 917                                   1Q24 메모리 흑자전환 예상
# 289  사상 최고 실적 vs 불확실한 매크로 사상 최고 실적 vs. 불확실한 매크로 사상 ...
# 842  점점 더 거세지는 매크로 역풍 What s New 하이 인플레이션과 자이언트 스텝 ...
# 782  매크로 우려로 실적 전망 및 목표가 하향 What s New 3 분기 실적은 예상 ...
# 872  4Q22 잠정실적 리뷰 4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q2...
# ..                                                 ...
# 823                                            에게필요한것은
# 516                                     매력 대비 아쉬운 영업가치
# 694  DRAM 가격 전망치 상향 조정 4Q20 영업이익 9.2조원 세트 부문 부진 예상 ...
# 818                                 4Q21 실적발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM과 DP는 회복 메모리 업황 둔화 vs. IM과 DP는 ...
#
#                                       제목_세부내용_전처리후_Okt  \
# 917                                1 Q 24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 불확실한 매크로 사상 최고 실적 vs 불확실한 매크로 사상 최...
# 842  점점 더 거세지는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝 2...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠정 실적 Review 전 사업 부 기 대...
# ..                                                 ...
# 823                                              필요한것은
# 516                                    매력 대비 아쉬운 영업 가치
# 694  DRAM 가격 전 망치 상향 조정 4 Q 20 영업 이익 9.2조원 세트 부문 부진...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 917                                   1Q24 메모리 흑자전환 예상
# 289  사상 최고 실적 vs 불확실 ㄴ 매크로 사상 최고 실적 vs 불확실 ㄴ 매크로 사상...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 인플레이션 자이언트 스텝 2Q...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4Q22 잠정실적 리뷰 4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q2...
# ..                                                 ...
# 823                                           에게필요한것 은
# 516                                    매력 대비 아쉽 은 영업가치
# 694  DRAM 가격 전망치 상향 조정 4Q20 영업이익 9.2조원 세트 부문 부진 예상 ...
# 818                                 4Q21 실적발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                      제목_세부내용_전처리후_Kkma  \
# 917                                1 Q 24 메 리 흑자 전환 예상
# 289  사상 최고 실적 vs 불확실 ㄴ 매크로 사상 최고 실적 vs 불확실 ㄴ 매크로 사상...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠 정실 적 Review 전 사업부 기대치...
# ..                                                 ...
# 823                                            에게필요한것은
# 516                                   매력 대비 아쉽 ㄴ 영업 가치
# 694  DRAM 가격 전망 지 상향 조정 4 Q 20 영업 이익 9.2 조 원 세트 부문 ...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업 황 둔화 vs IM DP 는 회복 메모리 업 황 둔화 vs IM DP 는...
#
#                                   제목_세부내용_전처리후_Komoran  \
# 917                                1 Q 24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 불 확실 ㄴ 매크로 사상 최고 실적 vs 불 확실 ㄴ 매크로 ...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠정 실적 Review 전 사업부 기대 지...
# ..                                                 ...
# 823                                             필요 ㄴ 은
# 516                                   매력 대비 아쉽 ㄴ 영업 가치
# 694  DRAM 가격 전망 지 상향 조정 4 Q 20 영업 이익 9 2 조 원 세트 부문 ...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                      제목_세부내용_전처리후_kiwi  \
# 917                                    24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 매크로 사상 최고 실적 vs. 매크로 사상 최고 실적 vs. 매크로
# 842  거세 매크로 역풍 What New 하이 인플레이션 자이언트 스텝 Preview 세트...
# 782     매크로 우려 실적 전망 목표 하향 What New 분기 실적 예상 수준 매크로 우려
# 872  22 잠정 실적 리뷰 22 잠정 실적 Review 사업부 기대치 하회 23 실적 부...
# ..                                                 ...
# 823                                                 필요
# 516                                     매력 대비 아쉽 영업 가치
# 694  DRAM 가격 전망 상향 조정 20 영업 이익 9.2 세트 부문 부진 예상 21 영...
# 818                                  21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 회복 메모리 업황 둔화 vs. IM DP 회복 메...
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label
# 917                                    24 메모리 흑자 전환 예상           2
# 289             사상 최고 실적 매크로 사상 최고 실적 매크로 사상 최고 실적 매크로           2
# 842  매크로 역풍 하이 인플레이션 자이언트 스텝 세트 사업부 부진 분기 영업 이익 추정 ...           2
# 782              매크로 우려 실적 전망 목표 하향 분기 실적 예상 수준 매크로 우려           2
# 872      22 잠정 실적 리뷰 22 잠정 실적 사업부 기대 하회 23 실적 부진 지속 예상           2
# ..                                                 ...         ...
# 823                                                 필요           2
# 516                                        매력 대비 영업 가치           2
# 694  가격 전망 상향 조정 20 영업 이익 원 세트 부문 부진 예상 21 영업 이익 원 ...           2
# 818                                  21 실적 발표 자료 하이라이트           1
# 607             메모리 업황 둔화 회복 메모리 업황 둔화 회복 메모리 업황 둔화 회복           2
#
# [757 rows x 18 columns]

# %%
# 데이터셋 클래스
class SentimentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# 데이터셋 준비
max_seq_len = 128
train_dataset = SentimentDataset(train_df['제목_세부내용_전처리후_Hannanum'].tolist(), train_df['평가의견_label'].tolist(), tokenizer, max_seq_len)
test_dataset = SentimentDataset(test_df['제목_세부내용_전처리후_Hannanum'].tolist(), test_df['평가의견_label'].tolist(), tokenizer, max_seq_len)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # 4. KoFinBERT + 분류기 모델 정의

# %%
class KoFinBERTClassifier(nn.Module):
    def __init__(self, bert_model, num_labels=3):
        super(KoFinBERTClassifier, self).__init__()
        self.bert_model = bert_model
        self.device     = device
        self.classifier = nn.Linear(bert_model.config.hidden_size, num_labels)
        self.config = bert_model.config  # config 속성을 추가

    def forward(self, input_ids, attention_mask=None, token_type_ids=None):
        outputs = self.bert_model(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        logits = outputs.logits
        return logits

# 원래 모델을 변경하지 않고 초기화
model = KoFinBERTClassifier(model).to(device)  # 여기서 `model`은 원래 BERT 모델입니다.

# %% [markdown]
# 5. 옵티마이저 및 손실 함수 설정

# %%
optimizer = AdamW(model.parameters(), lr=2e-5)
loss_fn = CrossEntropyLoss()

# %% [markdown]
# 6. 모델 학습 루프

# %%
# 나머지 학습 코드는 그대로 유지
epochs = 5
train_acc_list = []
train_loss_list = []

for epoch in range(epochs):
    start_time = time.time()  # epoch 시작 시간 기록
    
    model.train()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0

    for batch in tqdm(train_loader, desc=f"학습 Epoch {epoch+1}"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds = torch.max(outputs, dim=1)
        correct_predictions += torch.sum(preds == labels)
        total_predictions += labels.size(0)

    train_accuracy = correct_predictions.double() / total_predictions
    avg_train_loss = total_loss / len(train_loader)

    train_acc_list.append(train_accuracy.item())
    train_loss_list.append(avg_train_loss)

    end_time = time.time()  # epoch 끝 시간 기록
    duration = end_time - start_time  # 소요 시간 계산

    print(f"Epoch [{epoch+1}/{epochs}] - 손실: {avg_train_loss:.4f}, 정확도: {train_accuracy:.2%}, 소요 시간: {duration:.2f} 초")
# Out:
# 학습 Epoch 1: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:10<00:00,  1.15it/s]
# Epoch [1/5] - 손실: 0.7976, 정확도: 85.20%, 소요 시간: 10.42 초
# 학습 Epoch 2: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:08<00:00,  1.43it/s]
# Epoch [2/5] - 손실: 0.1807, 정확도: 95.90%, 소요 시간: 8.42 초
# 학습 Epoch 3: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:08<00:00,  1.44it/s]
# Epoch [3/5] - 손실: 0.1757, 정확도: 95.90%, 소요 시간: 8.31 초
# 학습 Epoch 4: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:08<00:00,  1.42it/s]
# Epoch [4/5] - 손실: 0.1741, 정확도: 95.90%, 소요 시간: 8.46 초
# 학습 Epoch 5: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:08<00:00,  1.42it/s]
# Epoch [5/5] - 손실: 0.1733, 정확도: 95.90%, 소요 시간: 8.44 초

# %% [markdown]
# 7. 학습 결과 그래프로 시각화

# %%
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(14, 7))

# Accuracy 그래프
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_acc_list, marker='o', linestyle='-', color='b', label='Train Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Loss 그래프
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_loss_list, marker='o', linestyle='-', color='b', label='Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# %% [markdown]
# 8. 모델 평가 및 정확도 계산

# %%
test_acc_list = []
test_loss_list = []

model.eval()
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels)

        test_loss_list.append(loss.item())

        _, preds = torch.max(outputs, dim=1)
        correct_predictions = torch.sum(preds == labels)
        total_predictions = labels.size(0)

        accuracy = correct_predictions.double() / total_predictions
        test_acc_list.append(accuracy.item())
# Out:
# Evaluating: 100%|████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.59it/s]

# %% [markdown]
# 9. 예측 결과 추가 및 저장

# %%
def predict_labels(data_loader):
    model.eval()
    all_texts = []
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in tqdm(data_loader, desc="Predicting"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(batch['label'].cpu().numpy())

    return all_labels, all_preds

# %%
# Train 데이터에 대해 예측
train_labels, train_preds = predict_labels(train_loader)
# Out:
# Predicting: 100%|██████████████████████████████████████████████████████████████████████| 12/12 [00:03<00:00,  3.56it/s]

# %%
# Test 데이터에 대해 예측
test_labels, test_preds = predict_labels(test_loader)
# Out:
# Predicting: 100%|████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.99it/s]

# %%
# DataFrame에 예측 결과 추가
train_df['predicted_label'] = train_preds
test_df['predicted_label'] = test_preds

# %%
# 평가의견_label 및 predicted_label 환원
train_df['평가의견_label'] = train_df['평가의견_label'].map({0: -1, 1: 0, 2: 1})
test_df['평가의견_label'] = test_df['평가의견_label'].map({0: -1, 1: 0, 2: 1})
train_df['predicted_label'] = train_df['predicted_label'].map({0: -1, 1: 0, 2: 1})
test_df['predicted_label'] = test_df['predicted_label'].map({0: -1, 1: 0, 2: 1})

# %%
train_df
# Out:
#            작성일   종목명    종목코드                       제목     적정가격 평가의견      작성자  \
# 917 2024-03-14  삼성전자  005930         1Q24 메모리 흑자전환 예상  100,000   매수      한동희
# 289 2018-10-08  삼성전자  005930     사상 최고 실적 vs 불확실한 매크로   57,000  Buy      이승우
# 842 2022-06-20  삼성전자  005930         점점 더 거세지는 매크로 역풍   79,000  Buy      이승우
# 782 2021-10-12  삼성전자  005930   매크로 우려로 실적 전망 및 목표가 하향   93,000  Buy      이승우
# 872 2023-01-09  삼성전자  005930             4Q22 잠정실적 리뷰   82,000  Buy      김광진
# ..         ...   ...     ...                      ...      ...  ...      ...
# 823 2022-02-09  삼성전자  005930                  에게필요한것은   93,000  Buy      이승우
# 516 2019-11-01  삼성전자  005930           매력 대비 아쉬운 영업가치   60,000  Buy  김선우,서승연
# 694 2021-01-04  삼성전자  005930        DRAM 가격 전망치 상향 조정  100,000  Buy      박유악
# 818 2022-01-28  삼성전자  005930       4Q21 실적발표 자료 하이라이트        0    -      김선우
# 607 2020-06-01  삼성전자  005930  메모리 업황 둔화 vs IM과 DP는 회복   62,000  Buy      박유악
#
#         작성기관                                               세부내용  \
# 917     SK증권      삼성전자(005930) 1Q24 메모리 흑자전환 예상1Q24 메모리 흑자전환 예상
# 289   유진투자증권  삼성전자(005930)사상 최고 실적  vs. 불확실한 매크로삼성전자(005930)...
# 842   유진투자증권  삼성전자(005930) 점점 더 거세지는 매크로 역풍What’s New : 하이 인...
# 782   유진투자증권  삼성전자(005930)매크로 우려로 실적 전망 및 목표가 하향What’s New: ...
# 872   한화투자증권  삼성전자(005930) 4Q22 잠정실적 리뷰4Q22 잠정실적 Review : 전 ...
# ..       ...                                                ...
# 823   유진투자증권   삼성전자(005930)삼성전자에게필요한것은?삼성전자(005930)삼성전자에게필요한것은?
# 516  메리츠종금증권           삼성전자(005930)매력 대비 아쉬운 영업가치매력 대비 아쉬운 영업가치
# 694     키움증권  삼성전자(005930)DRAM 가격 전망치 상향 조정4Q20 영업이익 9.2조원, ...
# 818    메리츠증권   삼성전자(005930)4Q21 실적발표 자료 하이라이트4Q21 실적발표 자료 하이라이트
# 607     키움증권  삼성전자(005930)메모리 업황 둔화 vs. IM과 DP는 회복메모리 업황 둔화 ...
#
#                                              세부내용_전처리후  \
# 917
# 289        사상 최고 실적 vs. 불확실한 매크로 사상 최고 실적 vs. 불확실한 매크로
# 842   What s New 하이 인플레이션과 자이언트 스텝 2Q Preview 세트 사업...
# 782            What s New 3 분기 실적은 예상 수준이나 매크로 우려가 높아짐
# 872     4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q23 실적 부진 지속 예상
# ..                                                 ...
# 823
# 516
# 694   4Q20 영업이익 9.2조원 세트 부문 부진 예상 1Q21 영업이익 8조원 분기 ...
# 818
# 607   메모리 업황 둔화 vs. IM과 DP는 회복메모리 업황 둔화 vs. IM과 DP는 회복
#
#                                           제목_세부내용_전처리후  \
# 917                                   1Q24 메모리 흑자전환 예상
# 289  사상 최고 실적 vs 불확실한 매크로 사상 최고 실적 vs. 불확실한 매크로 사상 ...
# 842  점점 더 거세지는 매크로 역풍 What s New 하이 인플레이션과 자이언트 스텝 ...
# 782  매크로 우려로 실적 전망 및 목표가 하향 What s New 3 분기 실적은 예상 ...
# 872  4Q22 잠정실적 리뷰 4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q2...
# ..                                                 ...
# 823                                            에게필요한것은
# 516                                     매력 대비 아쉬운 영업가치
# 694  DRAM 가격 전망치 상향 조정 4Q20 영업이익 9.2조원 세트 부문 부진 예상 ...
# 818                                 4Q21 실적발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM과 DP는 회복 메모리 업황 둔화 vs. IM과 DP는 ...
#
#                                       제목_세부내용_전처리후_Okt  \
# 917                                1 Q 24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 불확실한 매크로 사상 최고 실적 vs 불확실한 매크로 사상 최...
# 842  점점 더 거세지는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝 2...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠정 실적 Review 전 사업 부 기 대...
# ..                                                 ...
# 823                                              필요한것은
# 516                                    매력 대비 아쉬운 영업 가치
# 694  DRAM 가격 전 망치 상향 조정 4 Q 20 영업 이익 9.2조원 세트 부문 부진...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 917                                   1Q24 메모리 흑자전환 예상
# 289  사상 최고 실적 vs 불확실 ㄴ 매크로 사상 최고 실적 vs 불확실 ㄴ 매크로 사상...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 인플레이션 자이언트 스텝 2Q...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4Q22 잠정실적 리뷰 4Q22 잠정실적 Review 전 사업부 기대치 하회 1Q2...
# ..                                                 ...
# 823                                           에게필요한것 은
# 516                                    매력 대비 아쉽 은 영업가치
# 694  DRAM 가격 전망치 상향 조정 4Q20 영업이익 9.2조원 세트 부문 부진 예상 ...
# 818                                 4Q21 실적발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                      제목_세부내용_전처리후_Kkma  \
# 917                                1 Q 24 메 리 흑자 전환 예상
# 289  사상 최고 실적 vs 불확실 ㄴ 매크로 사상 최고 실적 vs 불확실 ㄴ 매크로 사상...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠 정실 적 Review 전 사업부 기대치...
# ..                                                 ...
# 823                                            에게필요한것은
# 516                                   매력 대비 아쉽 ㄴ 영업 가치
# 694  DRAM 가격 전망 지 상향 조정 4 Q 20 영업 이익 9.2 조 원 세트 부문 ...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업 황 둔화 vs IM DP 는 회복 메모리 업 황 둔화 vs IM DP 는...
#
#                                   제목_세부내용_전처리후_Komoran  \
# 917                                1 Q 24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 불 확실 ㄴ 매크로 사상 최고 실적 vs 불 확실 ㄴ 매크로 ...
# 842  점점 더 거세 지 는 매크로 역풍 What s New 하이 인플레이션 자이언트 스텝...
# 782  매크로 우려 실적 전망 목표 하향 What s New 3 분기 실적 은 예상 수준 ...
# 872  4 Q 22 잠정 실적 리뷰 4 Q 22 잠정 실적 Review 전 사업부 기대 지...
# ..                                                 ...
# 823                                             필요 ㄴ 은
# 516                                   매력 대비 아쉽 ㄴ 영업 가치
# 694  DRAM 가격 전망 지 상향 조정 4 Q 20 영업 이익 9 2 조 원 세트 부문 ...
# 818                              4 Q 21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 는 회복 메모리 업황 둔화 vs IM DP 는 회...
#
#                                      제목_세부내용_전처리후_kiwi  \
# 917                                    24 메모리 흑자 전환 예상
# 289  사상 최고 실적 vs 매크로 사상 최고 실적 vs. 매크로 사상 최고 실적 vs. 매크로
# 842  거세 매크로 역풍 What New 하이 인플레이션 자이언트 스텝 Preview 세트...
# 782     매크로 우려 실적 전망 목표 하향 What New 분기 실적 예상 수준 매크로 우려
# 872  22 잠정 실적 리뷰 22 잠정 실적 Review 사업부 기대치 하회 23 실적 부...
# ..                                                 ...
# 823                                                 필요
# 516                                     매력 대비 아쉽 영업 가치
# 694  DRAM 가격 전망 상향 조정 20 영업 이익 9.2 세트 부문 부진 예상 21 영...
# 818                                  21 실적 발표 자료 하이라이트
# 607  메모리 업황 둔화 vs IM DP 회복 메모리 업황 둔화 vs. IM DP 회복 메...
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label  \
# 917                                    24 메모리 흑자 전환 예상           1
# 289             사상 최고 실적 매크로 사상 최고 실적 매크로 사상 최고 실적 매크로           1
# 842  매크로 역풍 하이 인플레이션 자이언트 스텝 세트 사업부 부진 분기 영업 이익 추정 ...           1
# 782              매크로 우려 실적 전망 목표 하향 분기 실적 예상 수준 매크로 우려           1
# 872      22 잠정 실적 리뷰 22 잠정 실적 사업부 기대 하회 23 실적 부진 지속 예상           1
# ..                                                 ...         ...
# 823                                                 필요           1
# 516                                        매력 대비 영업 가치           1
# 694  가격 전망 상향 조정 20 영업 이익 원 세트 부문 부진 예상 21 영업 이익 원 ...           1
# 818                                  21 실적 발표 자료 하이라이트           0
# 607             메모리 업황 둔화 회복 메모리 업황 둔화 회복 메모리 업황 둔화 회복           1
#
#      predicted_label
# 917                1
# 289                1
# 842                1
# 782                1
# 872                1
# ..               ...
# 823                1
# 516                1
# 694                1
# 818                1
# 607                1
#
# [757 rows x 19 columns]

# %%
test_df
# Out:
#            작성일   종목명    종목코드                              제목     적정가격 평가의견  \
# 405 2019-03-27  삼성전자  005930                    큰 방향의 중심에 있다   52,000  Buy
# 593 2020-05-04  삼성전자  005930       보수적 가이던스 제시했으나 장기적으로는 긍정적   60,000  Buy
# 357 2019-01-09  삼성전자  005930               수요 급감 속의 실적 Shock   50,000  Buy
# 669 2020-10-30  삼성전자  005930      투자에 대한 시각을 DRAM으로 옮겨야 할 시기   75,000  Buy
# 204 2018-06-11  삼성전자  005930             전자도 어쩔 수 없는 스마트폰 시장   68,000  Buy
# ..         ...   ...     ...                             ...      ...  ...
# 784 2021-10-12  삼성전자  005930            우려했던 NAND의 업황 둔화 가시화   95,000  Buy
# 247 2018-08-01  삼성전자  005930  2Q18 실적 컨퍼런스 콜이 주는 Implication   76,000  Buy
# 527 2019-11-19  삼성전자  005930                      한고비넘어두개의선물   63,000  Buy
# 751 2021-06-24  삼성전자  005930      단기 실적 모멘텀 vs 4Q21 이후 우려 요인  107,000  Buy
# 511 2019-10-16  삼성전자  005930        19 3Q 빠르게 감소한 메모리 반도체 재고   60,000  Buy
#
#          작성자     작성기관                                               세부내용  \
# 405      노근창  현대차투자증권               삼성전자(005930)큰 방향의 중심에 있다큰 방향의 중심에 있다
# 593      이승우   유진투자증권  삼성전자(005930)보수적 가이던스 제시했으나, 장기적으로는 긍정적 1Q Rev...
# 357      박유악     키움증권     삼성전자(005930)수요 급감 속의 실적 Shock수요 급감 속의 실적 Shock
# 669      박유악     키움증권  삼성전자(005930)투자에 대한 시각을 DRAM으로 옮겨야 할 시기투자에 대한 시...
# 204      어규진   이베스트증권  삼성전자(005930)전자도 어쩔 수 없는 스마트폰 시장전자도 어쩔 수 없는 스마트...
# ..       ...      ...                                                ...
# 784      박유악     키움증권  삼성전자(005930)우려했던 NAND의 업황 둔화 가시화우려했던 NAND의 업황 ...
# 247      이재윤    유안타증권  삼성전자(005930)2Q18 실적 컨퍼런스 콜이 주는 Implication2Q18...
# 527      김선우  메리츠종금증권                   삼성전자(005930)한고비넘어두개의선물한고비넘어두개의선물
# 751  이재윤,백길현    유안타증권  삼성전자(005930)단기 실적 모멘텀 vs. 4Q21 이후 우려 요인단기 실적 모...
# 511      김영우     SK증권  삼성전자(005930)’19.3Q, 빠르게 감소한 메모리 반도체 재고’19.3Q, ...
#
#                                              세부내용_전처리후  \
# 405
# 593    1Q Review 영업이익 6.45조원 불확실성에도 선전 2Q 전망 영업이익 6...
# 357
# 669
# 204
# ..                                                 ...
# 784
# 247
# 527
# 751   단기 실적 모멘텀 vs. 4Q21 이후 우려 요인단기 실적 모멘텀 vs. 4Q21...
# 511   19.3Q 빠르게 감소한 메모리 반도체 재고 19.3Q 빠르게 감소한 메모리 반도...
#
#                                           제목_세부내용_전처리후  \
# 405                                       큰 방향의 중심에 있다
# 593  보수적 가이던스 제시했으나 장기적으로는 긍정적 1Q Review 영업이익 6.45조...
# 357                                  수요 급감 속의 실적 Shock
# 669                         투자에 대한 시각을 DRAM으로 옮겨야 할 시기
# 204                                전자도 어쩔 수 없는 스마트폰 시장
# ..                                                 ...
# 784                               우려했던 NAND의 업황 둔화 가시화
# 247                     2Q18 실적 컨퍼런스 콜이 주는 Implication
# 527                                         한고비넘어두개의선물
# 751  단기 실적 모멘텀 vs 4Q21 이후 우려 요인 단기 실적 모멘텀 vs. 4Q21 ...
# 511  19 3Q 빠르게 감소한 메모리 반도체 재고 19.3Q 빠르게 감소한 메모리 반도체...
#
#                                       제목_세부내용_전처리후_Okt  \
# 405                                            큰 방향 중심
# 593  보수 적 가이던스 제시 했으나 장기 적 으로는 긍정 적 1 Q Review 영업 이...
# 357                                   수요 급감 속 실적 Shock
# 669                                투자 대한 DRAM 옮겨야 할 시기
# 204                                  도 어쩔 수 없는 스마트폰 시장
# ..                                                 ...
# 784                              우려 했던 NAND 업황 둔화 가시 화
# 247                    2 Q 18 실적 컨퍼런스 콜 주는 Implication
# 527                                      한고비 넘어 두 개 선물
# 751  단기 실적 모멘텀 vs 4 Q 21 이후 우려 요인 단기 실적 모멘텀 vs 4 Q ...
# 511  19 3 Q 빠르게 감소 한 메모리 반도체 재고 19.3 Q 빠르게 감소 한 메모리...
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 405                                      크 ㄴ 방향 중심 있 다
# 593  보수적 가이던스 제시 었으나 장기적 으로는 긍정적 1Q Review 영업이익 6. ...
# 357                                   수요 급감 속 실적 Shock
# 669                            투자 대하 ㄴ DRAM 옮기 어야 ㄹ 시기
# 204                               도 어쩌 ㄹ 수 없 는 스마트폰 시장
# ..                                                 ...
# 784                             우 리어 었던 NAND 업황 둔화 가시화
# 247                     2Q18 실적 컨퍼런스 콜 주 는 Implication
# 527                                         한고비넘어두개의선물
# 751  단기 실적 모멘텀 vs 4Q21 이후 우려 요 ㄴ 단기 실적 모멘텀 vs 4Q21 ...
# 511  19 3Q 빠르 게 감소 ㄴ 메모리 반도체 재고 19.3Q 빠르 게 감소 ㄴ 메모리...
#
#                                      제목_세부내용_전처리후_Kkma  \
# 405                                      크 ㄴ 방향 중심 있 다
# 593  보수적 가이 던스 제시 었 으나 장기적 는 긍정적 1 Q Review 영업 이익 6...
# 357                                   수요 급감 속 실적 Shock
# 669                            투자 대하 ㄴ DRAM 옮기 어야 ㄹ 시기
# 204                              도 어쩌 ㄹ 수 없 는 스마트 폰 시장
# ..                                                 ...
# 784                             우려 었 던 NAND 업 황 둔화 가시화
# 247                   2 Q 18 실적 컨퍼런스 콜 줄 는 Implication
# 527                                      한고비 넘 두 개의 선물
# 751  단기 실적 모멘텀 vs 4 Q 21 이후 우려 요인 단기 실적 모멘텀 vs 4 Q ...
# 511  19 3 Q 빠르 게 감소 ㄴ 메모리 반도체 재고 19.3 Q 빠르 게 감소 ㄴ 메...
#
#                                   제목_세부내용_전처리후_Komoran  \
# 405                                      크 ㄴ 방향 중심 있 다
# 593  보수 적 가이던스 제시 았 으나 장기 적 는 긍정 적 1 Q Review 영업 이익...
# 357                                   수요 급감 속 실적 Shock
# 669                            투자 대하 ㄴ DRAM 옮기 어야 ㄹ 시기
# 204                               도 어쩌 ㄹ 수 없 는 스마트폰 시장
# ..                                                 ...
# 784                             우려 았 던 NAND 업황 둔화 가시 화
# 247                   2 Q 18 실적 컨퍼런스 콜 주 는 Implication
# 527                                     한고비 넘 어두 개의 선물
# 751  단기 실적 모멘텀 vs 4 Q 21 이후 우려 요인 단기 실적 모멘텀 vs 4 Q ...
# 511  19 3 Q 빠르 게 감소 ㄴ 메모리 반도체 재고 19 3 Q 빠르 게 감소 ㄴ 메...
#
#                                      제목_세부내용_전처리후_kiwi  \
# 405                                              방향 중심
# 593  보수 가이던스 제시 장기 긍정 Review 영업 이익 6.45 선전 전망 영업 이익...
# 357                                     수요 급감 실적 Shock
# 669                                         투자 DRAM 시기
# 204                                            스마트폰 시장
# ..                                                 ...
# 784                                   우려 NAND 업황 둔화 가시
# 247                             18 실적 컨퍼런스 Implication
# 527                                              고비 선물
# 751  단기 실적 모멘텀 vs 21 이후 우려 요인 단기 실적 모멘텀 vs. 21 이후 우...
# 511  19 빠르 감소 메모리 반도체 재고 19.3 빠르 감소 메모리 반도체 재고 19.3...
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label  \
# 405                                              방향 중심           1
# 593  보수 가이던스 제시 장기 긍정 영업 이익 원 불확실성 선전 전망 영업 이익 원 감 ...           1
# 357                                         수요 급감 속 실적           1
# 669                                              투자 시기           1
# 204                                          수 스마트폰 시장           1
# ..                                                 ...         ...
# 784                                        우려 업황 둔화 가시           1
# 247                                       18 실적 컨퍼런스 콜           1
# 527                                          한고비 개의 선물           1
# 751  단기 실적 모멘텀 21 이후 우려 요인 단기 실적 모멘텀 21 이후 우려 요인 단기...           1
# 511          감소 메모리 반도체 재고 감소 메모리 반도체 재고 감소 메모리 반도체 재고           1
#
#      predicted_label
# 405                1
# 593                1
# 357                1
# 669                1
# 204                1
# ..               ...
# 784                1
# 247                1
# 527                1
# 751                1
# 511                1
#
# [190 rows x 19 columns]

# %% [markdown]
# 10. 감정 분석을 위한 KoFinBERT Sentiment score 산출

# %%
text_classifier = TextClassificationPipeline(
    tokenizer=tokenizer,
    model=AutoModelForSequenceClassification.from_pretrained("kwoncho/KoFinBERT"),  # Load original model
    top_k=None,  # 모든 레이블의 확률 반환
    device=0 if torch.cuda.is_available() else -1  # Use GPU if available
)

# %%
predicted_train_scores = []
for text in train_df['제목_세부내용_전처리후_Hannanum'] :
    # 감정 분석 수행
    prediction = text_classifier(text)
    
    # 레이블을 숫자 값으로 매핑
    label_mapping = {
        'positive': 1,
        'neutral': 0,
        'negative': -1
    }
    
    # 연속적인 점수 직접 계산
    score = 0
    for item in prediction[0]:
        label = item['label']
        prob = item['score']
        score += label_mapping[label] * prob

    predicted_train_scores.append(score)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
predicted_test_scores = []
for text in test_df['제목_세부내용_전처리후_Hannanum'] :
    # 감정 분석 수행
    prediction = text_classifier(text)
    
    # 레이블을 숫자 값으로 매핑
    label_mapping = {
        'positive': 1,
        'neutral': 0,
        'negative': -1
    }
    
    # 연속적인 점수 직접 계산
    score = 0
    for item in prediction[0]:
        label = item['label']
        prob = item['score']
        score += label_mapping[label] * prob
    predicted_test_scores.append(score)

# %%
predicted_train_scores
# Out:
# [0.9969551096437499,
#  -0.0005655178101733327,
#  -0.9959589911159128,
#  -0.9950367137789726,
#  -0.9957253654720262,
#  0.9877976074349135,
#  -0.00021444086451083422,
#  -0.9813899351283908,
#  -0.9486013012938201,
#  0.996555614634417,
#  -0.00039926532190293074,
#  0.9673196811927482,
#  -0.9959118478000164,
#  0.9958904221421108,
#  -0.00022646988509222865,
#  0.0011094150831922889,
#  0.24541597708594054,
#  0.47495136596262455,
#  0.9969387849560007,
#  0.0015934404800646007,
#  0.002733362664002925,
#  0.9962470572208986,
#  -0.9957086051581427,
#  0.9962273690616712,
#  -0.989469169639051,
#  0.9960381335695274,
#  0.9970096533652395,
#  0.0010562028910499066,
#  0.9901688611134887,
#  0.8450437212595716,
#  8.274492574855685e-05,
#  0.0007517291815020144,
#  0.9970427607186139,
#  0.9968487395672128,
#  0.11855866602854803,
#  -0.9953443940030411,
#  -0.00017648941138759255,
#  0.390427915379405,
#  0.9957872162922285,
#  0.9846936106332578,
#  0.9857865881058387,
#  -0.9958651787601411,
#  -0.9429623577743769,
#  -0.0035411384887993336,
#  0.9959830893203616,
#  0.9968746261438355,
#  -0.9953230728860945,
#  -0.6542648021131754,
#  0.0033523299789521843,
#  -0.00010297866538167,
#  -0.0002553717349655926,
#  0.9088803488994017,
#  -0.8706621285527945,
#  -0.9931527306325734,
#  0.9970678889076225,
#  -0.9151708967983723,
#  0.0008666063076816499,
#  -6.168283289298415e-05,
#  -0.9961578872753307,
#  0.9956607428612188,
#  0.996225027134642,
#  -0.9952740066219121,
#  3.465107874944806e-05,
#  0.9937310134992003,
#  0.9705364457913674,
#  0.9803717690519989,
#  0.9961065407842398,
#  0.9965177060803398,
#  -0.99545730848331,
#  0.9964360243757255,
#  0.9969172215787694,
#  0.00042285496601834893,
#  -0.00013297295663505793,
#  -0.00014078541425988078,
#  0.004829883633647114,
#  0.9967296824324876,
#  0.9970560213550925,
#  -0.5362095981836319,
#  0.00029735075077041984,
#  0.9965870551532134,
#  0.9559270213940181,
#  0.0008543138392269611,
#  0.9953611393575557,
#  -0.02112394361756742,
#  0.8852569423615932,
#  -0.9950822305399925,
#  -0.9360839207656682,
#  -0.0006003646994940937,
#  0.9960600701160729,
#  0.9947456958470866,
#  0.9969329362502322,
#  0.37678572116419673,
#  -0.9959118478000164,
#  0.9967205949942581,
#  0.9965888892766088,
#  -0.9953215392306447,
#  0.00023751065600663424,
#  0.996899280406069,
#  0.02094871981535107,
#  0.0006674792966805398,
#  0.9965589737403207,
#  0.9969089771620929,
#  -0.07884866371750832,
#  -6.890215445309877e-05,
#  -0.9784883491229266,
#  0.9969053989625536,
#  0.9966582448105328,
#  -0.9907390701118857,
#  -0.0003617004258558154,
#  8.846109267324209e-05,
#  0.9968665061169304,
#  -8.832797175273299e-05,
#  -0.994901983300224,
#  0.00010635005310177803,
#  0.9956314447335899,
#  -5.529384361580014e-05,
#  -0.0002955954987555742,
#  -0.9959816216723993,
#  0.9957708124420606,
#  0.005510218383278698,
#  -0.9388298306148499,
#  0.0001333095133304596,
#  0.000647052947897464,
#  0.9960282765096053,
#  -0.7247008206322789,
#  0.03151630610227585,
#  0.9964658392127603,
#  0.996901651204098,
#  0.0008974449010565877,
#  0.00014419312356039882,
#  -0.9961981534725055,
#  0.9958477331092581,
#  -0.9962439571972936,
#  -0.9956976083340123,
#  0.9969918345450424,
#  0.9970578129286878,
#  0.996119552932214,
#  0.0005185186164453626,
#  0.008126418571919203,
#  0.9969268697313964,
#  -0.9954892942914739,
#  0.9896044456399977,
#  0.9950156631530263,
#  0.9968330200063065,
#  0.8442070707678795,
#  0.0797262581763789,
#  0.00026874971808865666,
#  0.0027735620096791536,
#  0.00012629205593839288,
#  0.996881403552834,
#  0.9962470572208986,
#  -0.0006649592542089522,
#  0.00022337050177156925,
#  0.9783787915366702,
#  0.0004520164802670479,
#  -8.525594603270292e-05,
#  0.9969992881524377,
#  0.9963261373341084,
#  0.9786383644095622,
#  -0.995244495337829,
#  0.3125524176284671,
#  0.9927711804048158,
#  0.9918471170822158,
#  0.12222252646461129,
#  -0.00343566742958501,
#  -0.0009123343043029308,
#  -0.9950404136907309,
#  -0.9958350021624938,
#  0.9908730674069375,
#  -0.00010570150334388018,
#  0.9955813253764063,
#  0.9893676785868593,
#  0.001277353847399354,
#  0.9966809912584722,
#  0.00031941209454089403,
#  0.00020442460663616657,
#  0.0003896139096468687,
#  0.0005442692199721932,
#  0.90818708576262,
#  0.9953038706444204,
#  0.009249235794413835,
#  0.9919678709702566,
#  -0.9813261991366744,
#  -7.176422514021397e-05,
#  -0.9763090345077217,
#  0.9953915189253166,
#  0.009642603108659387,
#  -5.5010837968438864e-05,
#  -5.164847243577242e-05,
#  0.9724304373376071,
#  0.9969300822122023,
#  0.995908719021827,
#  0.9967523943632841,
#  0.029222673561889678,
#  -0.02071627927944064,
#  -0.9839721194002777,
#  -0.000746476580388844,
#  -0.9960846871836111,
#  -0.0053487480618059635,
#  0.0027957047568634152,
#  0.0005568750784732401,
#  0.001715538848657161,
#  0.0018811770132742822,
#  -2.6623252779245377e-05,
#  -0.9951441723387688,
#  0.0008224049815908074,
#  0.01898090826580301,
#  -0.0003780880360864103,
#  0.9967050063423812,
#  0.997007273719646,
#  4.333851393312216e-06,
#  0.9961048180120997,
#  0.9966601936612278,
#  0.9968774133594707,
#  0.9942015581764281,
#  0.0022401861497201025,
#  0.0904101300984621,
#  -0.00028866849606856704,
#  -0.000731594511307776,
#  0.00022371980594471097,
#  0.9966514570405707,
#  0.985645747045055,
#  -0.005919076327700168,
#  -0.9937104706186801,
#  -5.5797339882701635e-05,
#  -0.9961291057989001,
#  0.9969341224641539,
#  -0.0004803800256922841,
#  0.9924021791666746,
#  0.0019639635283965617,
#  -0.9961906055686995,
#  0.9896834070095792,
#  0.9965093419887125,
#  -0.9956137002445757,
#  -0.9929660381749272,
#  -0.9953577402047813,
#  -5.66464732401073e-05,
#  0.9962436103960499,
#  0.00013869436224922538,
#  -0.0011428286088630557,
#  0.9930167329730466,
#  0.9031497724354267,
#  0.7416531061753631,
#  0.9964741665171459,
#  -0.9695670420769602,
#  0.9948955393047072,
#  0.9187541451537982,
#  -0.0007227289024740458,
#  0.9808076358749531,
#  0.047558915393892676,
#  0.9970511286519468,
#  4.6212400775402784e-05,
#  0.9967699008993804,
#  -6.902549648657441e-05,
#  -0.9866774869151413,
#  -0.4112661434337497,
#  -0.00019665667787194252,
#  0.9964327868656255,
#  0.9696616833098233,
#  -0.9962063651764765,
#  0.9968892396427691,
#  -7.840403122827411e-05,
#  0.8133028969168663,
#  -0.01687852875329554,
#  0.0032551729818806052,
#  0.9969003741862252,
#  -0.9799899128265679,
#  -0.993930182652548,
#  0.9954009121283889,
#  0.9959251267719083,
#  0.00032820249907672405,
#  -0.9957206061808392,
#  -0.9920023058075458,
#  0.027536091627553105,
#  0.14421416469849646,
#  -0.9954501499887556,
#  0.9965354170417413,
#  0.968952014867682,
#  -0.9625970666529611,
#  -0.00045652390690520406,
#  0.9968893327750266,
#  0.9775118069374003,
#  0.002233218547189608,
#  0.5520882786950096,
#  -3.30926850438118e-05,
#  0.7365689554717392,
#  0.9966698811622337,
#  -0.001452816417440772,
#  0.2415916173486039,
#  0.030445555923506618,
#  0.9911035375553183,
#  0.9968665061169304,
#  0.9968810414429754,
#  0.996953699272126,
#  -0.9916253760457039,
#  0.9886429132311605,
#  0.9969986285432242,
#  -0.9560123700648546,
#  0.9969735244521871,
#  0.9969575572176836,
#  0.996466099342797,
#  0.9961010356200859,
#  -0.995002098265104,
#  0.1319473721086979,
#  0.9968176688998938,
#  -0.731240700930357,
#  -0.9953138574492186,
#  -0.9951436819974333,
#  -0.9945121651981026,
#  -2.4584063794463873e-05,
#  0.9969843222061172,
#  0.00012354768114164472,
#  0.003218573343474418,
#  -0.0081588220782578,
#  0.8298910255543888,
#  -0.00016273983055725694,
#  0.9932735960464925,
#  0.005547630717046559,
#  0.20234820619225502,
#  -0.0378699594293721,
#  0.001766767119988799,
#  0.010286510339938104,
#  0.9830014082835987,
#  0.9454242491628975,
#  -0.9957361206179485,
#  0.9965178232523613,
#  0.0003204898675903678,
#  -0.9897369064856321,
#  0.9964881413034163,
#  0.9628158591222018,
#  0.9970241377595812,
#  -0.9951765693258494,
#  0.23650813102722168,
#  0.004876487975707278,
#  0.0002571812947280705,
#  7.305905455723405e-05,
#  0.9949726788327098,
#  -0.0008364998502656817,
#  0.996266097179614,
#  0.0006628086557611823,
#  0.996826049988158,
#  0.955174004600849,
#  0.9969616382732056,
#  0.0013918138574808836,
#  0.0002863019471988082,
#  0.0001601455733180046,
#  0.9968765554949641,
#  0.9704679861897603,
#  0.0002071709604933858,
#  0.9946438714396209,
#  0.0002361637889407575,
#  0.2900513776112348,
#  0.9967168861767277,
#  0.9968904529232532,
#  0.006032172590494156,
#  0.996031902555842,
#  0.00031427753856405616,
#  0.9966617223690264,
#  0.00015421333955600858,
#  0.9956250704126433,
#  0.9967366879573092,
#  -0.00049854681128636,
#  0.995200271718204,
#  -0.9962991027859971,
#  0.8701752263586968,
#  0.29056909680366516,
#  0.0101339005632326,
#  0.9969181747292168,
#  0.996951274224557,
#  -0.00010313314851373434,
#  -0.9959901045076549,
#  -0.0001344009069725871,
#  0.9917451559449546,
#  -0.9935139892622828,
#  0.4843848757445812,
#  0.9956419024965726,
#  -0.1803791078273207,
#  0.7689201559405774,
#  -0.014058559900149703,
#  0.9965093011269346,
#  0.0003343720454722643,
#  -0.0002793053863570094,
#  -0.9824135730741546,
#  -5.3511932492256165e-05,
#  0.9935880468110554,
#  6.538338493555784e-05,
#  0.00012354768114164472,
#  -4.183396231383085e-05,
#  0.9966684603132308,
#  -0.00016862712800502777,
#  0.0008736702147871256,
#  0.0032074690680019557,
#  0.06181809678673744,
#  0.9889394089113921,
#  0.00011353305308148265,
#  0.009156054817140102,
#  0.00011450581951066852,
#  0.0006219765054993331,
#  0.00020352820865809917,
#  -8.22476577013731e-05,
#  8.050329051911831e-05,
#  0.0001559557276777923,
#  0.9965854929760098,
#  0.9969768426381052,
#  -0.00034208071883767843,
#  -9.10293310880661e-05,
#  0.0003269911394454539,
#  -0.9928529590833932,
#  0.8556311294669285,
#  -0.9215249270200729,
#  -0.0017784119700081646,
#  6.119930185377598e-05,
#  0.009784645400941372,
#  -0.9959711107658222,
#  0.9960172651335597,
#  0.9757256535813212,
#  0.8170225991634652,
#  0.9801490660756826,
#  0.1337832510471344,
#  0.9960853545926511,
#  0.9969739238731563,
#  0.9709761802223511,
#  0.2505265772342682,
#  0.0008258988382294774,
#  -0.9952472168952227,
#  -0.995533294742927,
#  -0.6498221755027771,
#  0.9940988954040222,
#  0.9960590556147508,
#  0.9960796783561818,
#  0.0009475615224801004,
#  -2.3475673515349627e-05,
#  -0.9924427760997787,
#  0.0006085086497478187,
#  -0.9960759320529178,
#  0.5478311479091644,
#  5.27410302311182e-05,
#  -0.0031268276507034898,
#  -0.9940261765150353,
#  0.9862992610433139,
#  0.9965907317819074,
#  -0.9957585613010451,
#  -0.9953883006237447,
#  0.9640098398085684,
#  0.9958142399555072,
#  -0.00035020423820242286,
#  0.0025188899599015713,
#  0.9970128358108923,
#  0.006026292801834643,
#  -9.058427531272173e-05,
#  0.9946271094959229,
#  -6.890215445309877e-05,
#  0.7531967910472304,
#  0.9967947936966084,
#  0.871868334710598,
#  -5.2293878979980946e-05,
#  0.9968559671542607,
#  0.9968186609330587,
#  0.0014251677202992141,
#  0.0010341245215386152,
#  0.9966311125899665,
#  0.0013475261512212455,
#  0.9953020589891821,
#  0.0008666063076816499,
#  0.9961605301359668,
#  0.9970610339660197,
#  -0.0010568472207523882,
#  0.9966983815538697,
#  0.9943307846551761,
#  0.9651555691380054,
#  -7.514376193284988e-06,
#  0.9924799638683908,
#  0.9964029615512118,
#  -0.0006264274124987423,
#  0.9946582602569833,
#  0.9907451311592013,
#  0.0061334301135502756,
#  -0.6441079012583941,
#  -0.9943954051705077,
#  5.750427953898907e-05,
#  -0.001002908800728619,
#  -0.1111298002069816,
#  0.996871976996772,
#  -0.0002546635805629194,
#  0.9926941099693067,
#  0.9947962216683663,
#  0.9747237652773038,
#  0.9969736299244687,
#  -0.003008460160344839,
#  0.0002911134506575763,
#  0.9931875377078541,
#  0.6989799491129816,
#  0.0011683542397804558,
#  0.018886157777160406,
#  -0.002311800606548786,
#  0.9969256696640514,
#  0.00024667277466505766,
#  0.030215836828574538,
#  -0.9958695507375523,
#  0.9970751516520977,
#  0.003104419680312276,
#  0.0002929411130025983,
#  0.9804167686961591,
#  0.9963188591063954,
#  0.0013796724379062653,
#  0.9767662059166469,
#  0.9961364608607255,
#  0.9856611015275121,
#  0.9950179808074608,
#  -0.0008285768562927842,
#  0.16420883522368968,
#  0.9970880023902282,
#  0.9946765584172681,
#  0.8376017292030156,
#  -0.061729833483695984,
#  0.9967145617702045,
#  -0.9942407966591418,
#  0.8566462397575378,
#  0.994783048343379,
#  1.676258398219943e-05,
#  0.9960689169820398,
#  0.9970119565841742,
#  0.9968663081526756,
#  0.9958004204672761,
#  -0.9891209781635553,
#  -0.9940443745581433,
#  0.9950538548873737,
#  0.9815742233768106,
#  0.9959405841073021,
#  0.001383409253321588,
#  0.9931471770396456,
#  0.9849517425755039,
#  -0.00022657011868432164,
#  0.9968800707138143,
#  -0.2778497040271759,
#  0.9970112512819469,
#  0.9923356025246903,
#  0.7827996332198381,
#  0.00016734382370486856,
#  0.8020470542833209,
#  -0.9918076611938886,
#  -0.004968557565007359,
#  0.9909675361122936,
#  0.0005193909746594727,
#  0.9635721503873356,
#  -0.9957265813136473,
#  -1.010968117043376e-05,
#  -0.00022214947966858745,
#  0.0004019406624138355,
#  -0.00014661898603662848,
#  0.9957065444323234,
#  -0.0007698442786931992,
#  -0.04824881756212562,
#  0.9970441004261374,
#  0.9965629032230936,
#  0.3426576225319877,
#  0.9970325392787345,
#  0.00026874971808865666,
#  -0.0002237907610833645,
#  0.00020096305524930358,
#  0.9754538151901215,
#  0.011126261961180717,
#  0.9910941172274761,
#  0.9956887371372432,
#  0.007867108943173662,
#  0.005547630717046559,
#  0.0003802704159170389,
#  0.010304330848157406,
#  -0.004479272989556193,
#  -0.9879745868965983,
#  0.9969425825402141,
#  0.7382327895611525,
#  0.9945020887535065,
#  0.047043356811627746,
#  -0.00040813744999468327,
#  4.897196777164936e-05,
#  0.014910825993865728,
#  0.9971076636575162,
#  0.9961722292355262,
#  -3.409624332562089e-05,
#  0.09590516012394801,
#  -0.3139281200710684,
#  0.008533932617865503,
#  -0.9625970666529611,
#  -0.9937778203748167,
#  0.9970425592618994,
#  0.33288609981536865,
#  0.9932263545924798,
#  -0.9955993137555197,
#  -0.00022806331980973482,
#  -0.9833039446966723,
#  0.0007919806521385908,
#  -0.00046689307782799006,
#  0.9965403420501389,
#  -0.01430448261089623,
#  0.00015334179624915123,
#  0.0010401714243926108,
#  -0.019365649903193116,
#  0.00042625231435522437,
#  0.99332106532529,
#  0.0024351522733923048,
#  0.8111776020377874,
#  -0.9942567892139778,
#  -0.9965534685179591,
#  0.9936087230453268,
#  0.19053177861496806,
#  -0.9812414488987997,
#  0.9967914338922128,
#  -0.9947588513605297,
#  0.9966996372677386,
#  0.9916549675981514,
#  0.9893676785868593,
#  9.301898535341024e-05,
#  6.984127685427666e-05,
#  0.9968616534606554,
#  0.99466428643791,
#  0.993932097684592,
#  0.9960623290389776,
#  0.00026423437520861626,
#  0.9958246301393956,
#  0.00011527969036251307,
#  0.9969756379141472,
#  -0.023630768759176135,
#  -8.067372255027294e-05,
#  0.9948369505582377,
#  0.9966936635319144,
#  -0.0028879024321213365,
#  0.9962157774134539,
#  0.9968833290040493,
#  5.990744102746248e-05,
#  -0.000420670083258301,
#  0.996259979030583,
#  0.9967036676243879,
#  0.9950685984222218,
#  0.8695316510275006,
#  0.9969513746327721,
#  -0.9074899486731738,
#  -0.09134394489228725,
#  6.538338493555784e-05,
#  -0.9931267952779308,
#  0.007119576563127339,
#  0.9964202697155997,
#  0.6824860419146717,
#  0.984448877396062,
#  -0.9949394585564733,
#  0.9966410904889926,
#  0.9786189026199281,
#  0.9878899489995092,
#  -2.3023458197712898e-05,
#  0.9966377855162136,
#  -0.9937722312752157,
#  0.013838608691003174,
#  0.9966009389027022,
#  0.0004807028453797102,
#  0.9935152868856676,
#  0.9968011453747749,
#  0.055750447791069746,
#  0.9969118125736713,
#  0.98883490631124,
#  0.993184334365651,
#  0.00012569944374263287,
#  0.9968469550949521,
#  0.0013989116996526718,
#  0.995874916901812,
#  0.009141421178355813,
#  0.9966696273186244,
#  0.9305826798081398,
#  -0.9948255025083199,
#  0.9969138856977224,
#  0.50528358516749,
#  0.9965668653603643,
#  -6.56325719319284e-05,
#  -0.9719341900199652,
#  -0.9944163316395134,
#  0.9963980164611712,
#  0.9967596285277978,
#  0.9892852152697742,
#  -0.00019549636635929346,
#  0.9968689204542898,
#  -0.9674166063778102,
#  0.9890638100914657,
#  -0.9896596502512693,
#  0.00015478621935471892,
#  0.9962146506877616,
#  -0.9945581462234259,
#  0.927142191096209,
#  0.9969733734615147,
#  0.0007897836621850729,
#  0.0020170503994449973,
#  0.7827156111598015,
#  -0.9950565742328763,
#  0.9907682805787772,
#  -0.9656214278656989,
#  0.1781835244037211,
#  -0.9367785867070779,
#  -0.9923505930928513,
#  4.179618554189801e-05,
#  -0.9960003729211167,
#  -0.0009393218206241727,
#  0.961879716720432,
#  0.00042285496601834893,
#  -0.9956475289072841,
#  0.0010508228442631662,
#  0.9934238386922516,
#  0.9957266037818044,
#  0.00023627321934327483,
#  -0.00016699935076758265,
#  0.9787467134301551,
#  -0.5096940763760358,
#  0.9933490204857662,
#  0.9967559652868658,
#  -3.969087265431881e-05,
#  0.0004632677882909775,
#  0.9875248615280725,
#  0.9970616089412943,
#  0.9912060272763483,
#  0.0023753385175950825,
#  -0.0030838100938126445,
#  0.00015994824934750795,
#  0.003838211647234857,
#  -0.00037922407500445843,
#  9.055872214958072e-05,
#  0.9794938292470761,
#  0.9666379364207387,
#  -3.144307993352413e-05,
#  -0.0005564162274822593,
#  0.9151283054379746,
#  -0.860938620287925,
#  -0.23319670651108027,
#  -0.00019549636635929346,
#  0.9967861126642674,
#  -0.6095048785209656,
#  0.9849987379275262,
#  -0.995566823752597,
#  -0.00031803303863853216,
#  0.8414439135231078,
#  -0.9965925695141777,
#  -0.7898320578970015,
#  0.966568621690385,
#  0.9963829595944844,
#  0.0004584505222737789,
#  -0.002914036507718265,
#  0.007737382489722222,
#  0.9917199942283332,
#  -0.0007624338613823056,
#  0.2919110096991062,
#  -4.693923983722925e-05,
#  0.9971191278309561,
#  -0.00022646988509222865,
#  0.00030254427110776305,
#  -0.07881445623934269,
#  0.9941694092703983,
#  0.00018106773495674133,
#  -0.9881353718228638,
#  -0.9909702076110989,
#  0.0004951027221977711,
#  -0.0036166038480587304]

# %%
# DataFrame에 감정 분석 결과 추가
train_df['KoFinBERT_Sentiment'] = predicted_train_scores
test_df['KoFinBERT_Sentiment'] = predicted_test_scores

# %%
# train_df와 test_df를 합쳐서 저장
combined_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
combined_df = combined_df.sort_values(by=['작성일', '작성기관'])

# %%
combined_df
# Out:
#            작성일   종목명    종목코드                                 제목       적정가격  \
# 232 2017-09-06  삼성전자  005930                    조정의 빌미는 사라지고 있나  2,800,000
# 834 2017-09-08  삼성전자  005930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000
# 161 2017-09-08  삼성전자  005930                      3분기 증익을 예상합니다  3,300,000
# 675 2017-09-08  삼성전자  005930                    3분기 감익 우려 해소 기대  3,100,000
# 900 2017-09-11  삼성전자  005930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000
# ..         ...   ...     ...                                ...        ...
# 416 2024-08-01  삼성전자  005930                  메모리반도체 수익성 개선 본격화    110,000
# 48  2024-08-01  삼성전자  005930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000
# 61  2024-08-01  삼성전자  005930                       HBM 경쟁 심화 예상     97,000
# 147 2024-08-01  삼성전자  005930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000
# 231 2024-08-07  삼성전자  005930              추세 하락 이전에 주가 반등 가능할 듯     87,000
#
#     평가의견       작성자     작성기관  \
# 232  Buy       황민성     삼성증권
# 834  Buy       김선우  메리츠종금증권
# 161  Buy       어규진   이베스트증권
# 675  Buy   이순학,김정현   한화투자증권
# 900  Buy       박유악     키움증권
# ..   ...       ...      ...
# 416  Buy       백길현    유안타증권
# 48   Buy       이승우   유진투자증권
# 61   Buy   송명섭,손우성   하이투자증권
# 147  Buy  김광진,최영주    한화투자증권
# 231  Buy       송명섭   하이투자증권
#
#                                                   세부내용  \
# 232  삼성전자(005930)조정의 빌미는 사라지고 있나?반도체 혁신으로 메모리 반도체 제...
# 834  삼성전자(005930)실적 성장 재개와 함께 강화되는 주주환원시장 기대치를 소폭 능...
# 161       삼성전자(005930)3분기 증익을 예상합니다!3분기 영업이익 14.3조원 전망
# 675         삼성전자(005930)3분기 감익 우려 해소 기대4분기 서프라이즈 실적 기대
# 900  삼성전자(005930)3Q17 영업이익 총 15조원, 반도체 10조원 전망3Q17 ...
# ..                                                 ...
# 416    삼성전자(005930) 메모리반도체 수익성 개선 본격화메모리반도체 수익성 개선 본격화
# 48   삼성전자(005930) TSMC와의 시가총액 격차를 좁혀나 갈 시간TSMC와의 시가...
# 61               삼성전자(005930) HBM 경쟁 심화 예상HBM 경쟁 심화 예상
# 147  삼성전자(005930) 여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주...
# 231  삼성전자(005930) 추세 하락 이전에 주가 반등 가능할 듯추세 하락 이전에 주가...
#
#                                              세부내용_전처리후  \
# 232    반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. 매수의견과 목표가 280만...
# 834   시장 기대치를 소폭 능가하는 3Q17 영업이익 14.3조원 전망 지속 유지 4Q1...
# 161                                 3분기 영업이익 14.3조원 전망
# 675                                    4분기 서프라이즈 실적 기대
# 900                       3Q17 영업이익 15조원 시장 기대치 상회할 전망
# ..                                                 ...
# 416
# 48
# 61
# 147   여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주가여전히 강력한 AI발...
# 231
#
#                                           제목_세부내용_전처리후  \
# 232  조정의 빌미는 사라지고 있나 반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. ...
# 834  실적 성장 재개와 함께 강화되는 주주환원 시장 기대치를 소폭 능가하는 3Q17 영업...
# 161                   3분기 증익을 예상합니다 3분기 영업이익 14.3조원 전망
# 675                    3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 900  3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 416                                  메모리반도체 수익성 개선 본격화
# 48                            TSMC와의 시가총액 격차를 좁혀나 갈 시간
# 61                                        HBM 경쟁 심화 예상
# 147  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가 여전히 강력한 AI발 ...
# 231                              추세 하락 이전에 주가 반등 가능할 듯
#
#                                       제목_세부내용_전처리후_Okt  \
# 232  조정 빌 미는 사라지고 있나 반도체 혁신 메모리 반도체 값 받기는 진행 중 수 의견...
# 834  실적 성장 재개 강화 되는 주주 환원 시장 기 대치 소 폭 능가 하는 3 Q 17 ...
# 161                3분 기 증익 예상 합니다 3분 기 영업 이익 14.3조원 전망
# 675                  3분 기 감익 우려 해소 기대 4분 기 서프라이즈 실적 기대
# 900  3 Q 17 영업 이익 총 15조원 반도체 10조원 전망 3 Q 17 영업 이익 1...
# ..                                                 ...
# 416                               메모리 반도체 수익 성 개선 본격 화
# 48                               TSMC 와의 시가총액 격차 좁혀나 갈
# 61                                        HBM 경쟁 심화 예상
# 147  강력한 AI 발 수요 조 정기 거치 며 더욱 편해진 주가 강력한 AI 발 수요 조 ...
# 231                               추세 하락 이전 주가 반등 가능할 듯
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 232  조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 834  실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 161                  3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 675                    3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 900  3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 416                                 메모리반도체 수익성 개 선 본격화
# 48                                TSMC 와의 시가총액 격차 좁히 ㄹ
# 61                                        HBM 경쟁 심화 예상
# 147  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 231                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_Kkma  \
# 232  조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 834  실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 161              3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 675                3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 900  3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 416                                 메모리 반도체 수익성 개선 본격화
# 48                               TSMC 와의 시가 총액 격차 좁히 ㄹ
# 61                                        HBM 경쟁 심화 예상
# 147  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 231                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                   제목_세부내용_전처리후_Komoran  \
# 232  조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 834  실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 161             3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 675                 3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 900  3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 416                               메모리 반도체 수익 성 개선 본격 화
# 48                                   TSMC 시가총액 격차 좁히 ㄹ
# 61                                        HBM 경쟁 심화 예상
# 147  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 231                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_kiwi  \
# 232         조정 빌미 반도체 혁신 메모리 반도체 제값 진행 매수 의견 목표 280 유지
# 834  실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 14.3 전...
# 161                             분기 예상 분기 영업 이익 14.3 전망
# 675                         분기 우려 해소 기대 분기 서프라이즈 실적 기대
# 900     17 영업 이익 15 반도체 10 전망 17 영업 이익 15 시장 기대치 상회 전망
# ..                                                 ...
# 416                                   메모리 반도체 수익 개선 본격
# 48                                       TSMC 시가 총액 격차
# 61                                        HBM 경쟁 심화 예상
# 147          AI 수요 조정기 편하 AI 수요 조정기 편하 AI 수요 조정기 편하 주가
# 231                                  추세 하락 이전 주가 반등 가능
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label  \
# 232        조정 빌미 반도체 혁신 메모리 반도체 제값 진행 중 매수 의견 목표 만원 유지           1
# 834  실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 원 전망 지...           1
# 161                            분기 증 익 예상 분기 영업 이익 원 전망           1
# 675                     분기 감 익 우려 해소 기대 분기 서프라이즈 실적 기대           1
# 900         17 영업 이익 원 반도체 원 전망 17 영업 이익 원 시장 기대 상회 전망           1
# ..                                                 ...         ...
# 416                                      메모리 반도체 수익 개선           1
# 48                                             시가총액 격차           1
# 61                                            경쟁 심화 예상           1
# 147    발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가           1
# 231                                   추세 하락 이전 주가 반등 듯           1
#
#      predicted_label  KoFinBERT_Sentiment
# 232                1             0.996509
# 834                1             0.996725
# 161                1             0.992771
# 675                1             0.996760
# 900                1             0.996863
# ..               ...                  ...
# 416                1             0.817023
# 48                 1             0.003352
# 61                 1            -0.995274
# 147                1             0.002774
# 231                1             0.989683
#
# [947 rows x 20 columns]

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Hannanum_KoFinBERT.xlsx', index=False)

# %% [markdown]
# 여기서부터 소수점 1자리로 처리하기 위한 코드

# %%
# EXCEL파일 읽기
file_path = './Text_Data/한경_리포트_데이터_기업_SEC_Hannanum_KoFinBERT.xlsx'
combined_df = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# %%
combined_df
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
#           작성자     작성기관                                               세부내용  \
# 0         황민성     삼성증권  삼성전자(005930)조정의 빌미는 사라지고 있나?반도체 혁신으로 메모리 반도체 제...
# 1         김선우  메리츠종금증권  삼성전자(005930)실적 성장 재개와 함께 강화되는 주주환원시장 기대치를 소폭 능...
# 2         어규진   이베스트증권       삼성전자(005930)3분기 증익을 예상합니다!3분기 영업이익 14.3조원 전망
# 3     이순학,김정현   한화투자증권         삼성전자(005930)3분기 감익 우려 해소 기대4분기 서프라이즈 실적 기대
# 4         박유악     키움증권  삼성전자(005930)3Q17 영업이익 총 15조원, 반도체 10조원 전망3Q17 ...
# ..        ...      ...                                                ...
# 942       백길현    유안타증권    삼성전자(005930) 메모리반도체 수익성 개선 본격화메모리반도체 수익성 개선 본격화
# 943       이승우   유진투자증권  삼성전자(005930) TSMC와의 시가총액 격차를 좁혀나 갈 시간TSMC와의 시가...
# 944   송명섭,손우성   하이투자증권              삼성전자(005930) HBM 경쟁 심화 예상HBM 경쟁 심화 예상
# 945  김광진,최영주    한화투자증권  삼성전자(005930) 여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주...
# 946       송명섭   하이투자증권  삼성전자(005930) 추세 하락 이전에 주가 반등 가능할 듯추세 하락 이전에 주가...
#
#                                              세부내용_전처리후  \
# 0      반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. 매수의견과 목표가 280만...
# 1     시장 기대치를 소폭 능가하는 3Q17 영업이익 14.3조원 전망 지속 유지 4Q1...
# 2                                   3분기 영업이익 14.3조원 전망
# 3                                      4분기 서프라이즈 실적 기대
# 4                         3Q17 영업이익 15조원 시장 기대치 상회할 전망
# ..                                                 ...
# 942
# 943
# 944
# 945   여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주가여전히 강력한 AI발...
# 946
#
#                                           제목_세부내용_전처리후  \
# 0    조정의 빌미는 사라지고 있나 반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. ...
# 1    실적 성장 재개와 함께 강화되는 주주환원 시장 기대치를 소폭 능가하는 3Q17 영업...
# 2                     3분기 증익을 예상합니다 3분기 영업이익 14.3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                  메모리반도체 수익성 개선 본격화
# 943                           TSMC와의 시가총액 격차를 좁혀나 갈 시간
# 944                                       HBM 경쟁 심화 예상
# 945  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가 여전히 강력한 AI발 ...
# 946                              추세 하락 이전에 주가 반등 가능할 듯
#
#                                       제목_세부내용_전처리후_Okt  \
# 0    조정 빌 미는 사라지고 있나 반도체 혁신 메모리 반도체 값 받기는 진행 중 수 의견...
# 1    실적 성장 재개 강화 되는 주주 환원 시장 기 대치 소 폭 능가 하는 3 Q 17 ...
# 2                  3분 기 증익 예상 합니다 3분 기 영업 이익 14.3조원 전망
# 3                    3분 기 감익 우려 해소 기대 4분 기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15조원 반도체 10조원 전망 3 Q 17 영업 이익 1...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                              TSMC 와의 시가총액 격차 좁혀나 갈
# 944                                       HBM 경쟁 심화 예상
# 945  강력한 AI 발 수요 조 정기 거치 며 더욱 편해진 주가 강력한 AI 발 수요 조 ...
# 946                               추세 하락 이전 주가 반등 가능할 듯
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2                    3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                 메모리반도체 수익성 개 선 본격화
# 943                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_Kkma  \
# 0    조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2                3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 3                  3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                                 메모리 반도체 수익성 개선 본격화
# 943                              TSMC 와의 시가 총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                   제목_세부내용_전처리후_Komoran  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2               3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 3                   3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                                  TSMC 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_kiwi  \
# 0           조정 빌미 반도체 혁신 메모리 반도체 제값 진행 매수 의견 목표 280 유지
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 14.3 전...
# 2                               분기 예상 분기 영업 이익 14.3 전망
# 3                           분기 우려 해소 기대 분기 서프라이즈 실적 기대
# 4       17 영업 이익 15 반도체 10 전망 17 영업 이익 15 시장 기대치 상회 전망
# ..                                                 ...
# 942                                   메모리 반도체 수익 개선 본격
# 943                                      TSMC 시가 총액 격차
# 944                                       HBM 경쟁 심화 예상
# 945          AI 수요 조정기 편하 AI 수요 조정기 편하 AI 수요 조정기 편하 주가
# 946                                  추세 하락 이전 주가 반등 가능
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label  \
# 0          조정 빌미 반도체 혁신 메모리 반도체 제값 진행 중 매수 의견 목표 만원 유지           1
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 원 전망 지...           1
# 2                              분기 증 익 예상 분기 영업 이익 원 전망           1
# 3                       분기 감 익 우려 해소 기대 분기 서프라이즈 실적 기대           1
# 4           17 영업 이익 원 반도체 원 전망 17 영업 이익 원 시장 기대 상회 전망           1
# ..                                                 ...         ...
# 942                                      메모리 반도체 수익 개선           1
# 943                                            시가총액 격차           1
# 944                                           경쟁 심화 예상           1
# 945    발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가           1
# 946                                   추세 하락 이전 주가 반등 듯           1
#
#      predicted_label  KoFinBERT_Sentiment
# 0                  1             0.996509
# 1                  1             0.996725
# 2                  1             0.992771
# 3                  1             0.996760
# 4                  1             0.996863
# ..               ...                  ...
# 942                1             0.817023
# 943                1             0.003352
# 944                1            -0.995274
# 945                1             0.002774
# 946                1             0.989683
#
# [947 rows x 20 columns]

# %%
combined_df = combined_df[['작성일', '종목명', '종목코드', '제목', '적정가격', '평가의견', '작성자',
                           '작성기관', '제목_세부내용_전처리후_Hannanum', 'KoFinBERT_Sentiment']]

# %%
# 소수점 1자리로 반올림
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# Out:
# C:\Users\dybae\AppData\Local\Temp\ipykernel_40884\3055127085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
# C:\Users\dybae\AppData\Local\Temp\ipykernel_40884\3055127085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)

# %%
combined_df
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
#           작성자     작성기관                              제목_세부내용_전처리후_Hannanum  \
# 0         황민성     삼성증권  조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1         김선우  메리츠종금증권  실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2         어규진   이베스트증권                  3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3     이순학,김정현   한화투자증권                    3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4         박유악     키움증권  3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..        ...      ...                                                ...
# 942       백길현    유안타증권                                 메모리반도체 수익성 개 선 본격화
# 943       이승우   유진투자증권                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944   송명섭,손우성   하이투자증권                                       HBM 경쟁 심화 예상
# 945  김광진,최영주    한화투자증권  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946       송명섭   하이투자증권                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#      KoFinBERT_Sentiment
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                    1.0
# 4                    1.0
# ..                   ...
# 942                  0.8
# 943                  0.0
# 944                 -1.0
# 945                  0.0
# 946                  1.0
#
# [947 rows x 10 columns]

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Hannanum_KoFinBERT.xlsx', index=False)

# %%
combined_df
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
#           작성자     작성기관                              제목_세부내용_전처리후_Hannanum  \
# 0         황민성     삼성증권  조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1         김선우  메리츠종금증권  실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2         어규진   이베스트증권                  3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3     이순학,김정현   한화투자증권                    3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4         박유악     키움증권  3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..        ...      ...                                                ...
# 942       백길현    유안타증권                                 메모리반도체 수익성 개 선 본격화
# 943       이승우   유진투자증권                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944   송명섭,손우성   하이투자증권                                       HBM 경쟁 심화 예상
# 945  김광진,최영주    한화투자증권  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946       송명섭   하이투자증권                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#      KoFinBERT_Sentiment
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                    1.0
# 4                    1.0
# ..                   ...
# 942                  0.8
# 943                  0.0
# 944                 -1.0
# 945                  0.0
# 946                  1.0
#
# [947 rows x 10 columns]

# %%
combined_df = combined_df.groupby('작성일', as_index=False)['KoFinBERT_Sentiment'].mean()
# 소수점 1자리로 반올림
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].round(1)
combined_df['KoFinBERT_Sentiment'] = combined_df['KoFinBERT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
combined_df
# Out:
#            작성일  KoFinBERT_Sentiment
# 0   2017-09-06                  1.0
# 1   2017-09-08                  1.0
# 2   2017-09-11                  1.0
# 3   2017-09-12                  1.0
# 4   2017-09-13                  1.0
# ..         ...                  ...
# 425 2024-06-24                  0.0
# 426 2024-07-02                  0.5
# 427 2024-07-05                  0.0
# 428 2024-08-01                  0.2
# 429 2024-08-07                  1.0
#
# [430 rows x 2 columns]

# %%
combined_df.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Hannanum_KoFinBERT_daily.xlsx', index=False)
