# %%
from openai import OpenAI
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from matplotlib import rcParams
# 한글 폰트 설정
rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕으로 설정
rcParams['axes.unicode_minus'] = False     # 음수 기호 문제 해결

# %%
# APIKEY 정의
api_key = ""
client = OpenAI(api_key=api_key)

# %%
# EXCEL파일 읽기
file_path = './Text_Data/한경_리포트_데이터_기업_SEC.xlsx'
df_hankyung_consensus = pd.read_excel(file_path)

# %%
# 종목코드 자리수 맞추기 (종목코드가 숫자로 되어 있는 경우)
df_hankyung_consensus['종목코드'] = df_hankyung_consensus['종목코드'].apply(lambda x: str(x).zfill(6))

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명    종목코드                                 제목       적정가격  \
# 0   2017-09-06  삼성전자  005930                    조정의 빌미는 사라지고 있나  2,800,000
# 1   2017-09-08  삼성전자  005930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000
# 2   2017-09-08  삼성전자  005930                      3분기 증익을 예상합니다  3,300,000
# 3   2017-09-08  삼성전자  005930                    3분기 감익 우려 해소 기대  3,100,000
# 4   2017-09-11  삼성전자  005930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000
# ..         ...   ...     ...                                ...        ...
# 942 2024-08-01  삼성전자  005930                  메모리반도체 수익성 개선 본격화    110,000
# 943 2024-08-01  삼성전자  005930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000
# 944 2024-08-01  삼성전자  005930                       HBM 경쟁 심화 예상     97,000
# 945 2024-08-01  삼성전자  005930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000
# 946 2024-08-07  삼성전자  005930              추세 하락 이전에 주가 반등 가능할 듯     87,000
#
#     평가의견       작성자     작성기관  \
# 0    Buy       황민성     삼성증권
# 1    Buy       김선우  메리츠종금증권
# 2    Buy       어규진   이베스트증권
# 3    Buy   이순학,김정현   한화투자증권
# 4    Buy       박유악     키움증권
# ..   ...       ...      ...
# 942  Buy       백길현    유안타증권
# 943  Buy       이승우   유진투자증권
# 944  Buy   송명섭,손우성   하이투자증권
# 945  Buy  김광진,최영주    한화투자증권
# 946  Buy       송명섭   하이투자증권
#
#                                                   세부내용  \
# 0    삼성전자(005930)조정의 빌미는 사라지고 있나?반도체 혁신으로 메모리 반도체 제...
# 1    삼성전자(005930)실적 성장 재개와 함께 강화되는 주주환원시장 기대치를 소폭 능...
# 2         삼성전자(005930)3분기 증익을 예상합니다!3분기 영업이익 14.3조원 전망
# 3           삼성전자(005930)3분기 감익 우려 해소 기대4분기 서프라이즈 실적 기대
# 4    삼성전자(005930)3Q17 영업이익 총 15조원, 반도체 10조원 전망3Q17 ...
# ..                                                 ...
# 942    삼성전자(005930) 메모리반도체 수익성 개선 본격화메모리반도체 수익성 개선 본격화
# 943  삼성전자(005930) TSMC와의 시가총액 격차를 좁혀나 갈 시간TSMC와의 시가...
# 944              삼성전자(005930) HBM 경쟁 심화 예상HBM 경쟁 심화 예상
# 945  삼성전자(005930) 여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주...
# 946  삼성전자(005930) 추세 하락 이전에 주가 반등 가능할 듯추세 하락 이전에 주가...
#
#                                              세부내용_전처리후  \
# 0      반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. 매수의견과 목표가 280만...
# 1     시장 기대치를 소폭 능가하는 3Q17 영업이익 14.3조원 전망 지속 유지 4Q1...
# 2                                   3분기 영업이익 14.3조원 전망
# 3                                      4분기 서프라이즈 실적 기대
# 4                         3Q17 영업이익 15조원 시장 기대치 상회할 전망
# ..                                                 ...
# 942
# 943
# 944
# 945   여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주가여전히 강력한 AI발...
# 946
#
#                                           제목_세부내용_전처리후  \
# 0    조정의 빌미는 사라지고 있나 반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. ...
# 1    실적 성장 재개와 함께 강화되는 주주환원 시장 기대치를 소폭 능가하는 3Q17 영업...
# 2                     3분기 증익을 예상합니다 3분기 영업이익 14.3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                  메모리반도체 수익성 개선 본격화
# 943                           TSMC와의 시가총액 격차를 좁혀나 갈 시간
# 944                                       HBM 경쟁 심화 예상
# 945  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가 여전히 강력한 AI발 ...
# 946                              추세 하락 이전에 주가 반등 가능할 듯
#
#                                       제목_세부내용_전처리후_Okt  \
# 0    조정 빌 미는 사라지고 있나 반도체 혁신 메모리 반도체 값 받기는 진행 중 수 의견...
# 1    실적 성장 재개 강화 되는 주주 환원 시장 기 대치 소 폭 능가 하는 3 Q 17 ...
# 2                  3분 기 증익 예상 합니다 3분 기 영업 이익 14.3조원 전망
# 3                    3분 기 감익 우려 해소 기대 4분 기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15조원 반도체 10조원 전망 3 Q 17 영업 이익 1...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                              TSMC 와의 시가총액 격차 좁혀나 갈
# 944                                       HBM 경쟁 심화 예상
# 945  강력한 AI 발 수요 조 정기 거치 며 더욱 편해진 주가 강력한 AI 발 수요 조 ...
# 946                               추세 하락 이전 주가 반등 가능할 듯
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2                    3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                 메모리반도체 수익성 개 선 본격화
# 943                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_Kkma  \
# 0    조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2                3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 3                  3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                                 메모리 반도체 수익성 개선 본격화
# 943                              TSMC 와의 시가 총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                   제목_세부내용_전처리후_Komoran  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2               3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 3                   3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                                  TSMC 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_kiwi  \
# 0           조정 빌미 반도체 혁신 메모리 반도체 제값 진행 매수 의견 목표 280 유지
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 14.3 전...
# 2                               분기 예상 분기 영업 이익 14.3 전망
# 3                           분기 우려 해소 기대 분기 서프라이즈 실적 기대
# 4       17 영업 이익 15 반도체 10 전망 17 영업 이익 15 시장 기대치 상회 전망
# ..                                                 ...
# 942                                   메모리 반도체 수익 개선 본격
# 943                                      TSMC 시가 총액 격차
# 944                                       HBM 경쟁 심화 예상
# 945          AI 수요 조정기 편하 AI 수요 조정기 편하 AI 수요 조정기 편하 주가
# 946                                  추세 하락 이전 주가 반등 가능
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label
# 0          조정 빌미 반도체 혁신 메모리 반도체 제값 진행 중 매수 의견 목표 만원 유지           1
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 원 전망 지...           1
# 2                              분기 증 익 예상 분기 영업 이익 원 전망           1
# 3                       분기 감 익 우려 해소 기대 분기 서프라이즈 실적 기대           1
# 4           17 영업 이익 원 반도체 원 전망 17 영업 이익 원 시장 기대 상회 전망           1
# ..                                                 ...         ...
# 942                                      메모리 반도체 수익 개선           1
# 943                                            시가총액 격차           1
# 944                                           경쟁 심화 예상           1
# 945    발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가           1
# 946                                   추세 하락 이전 주가 반등 듯           1
#
# [947 rows x 18 columns]

# %%
df_hankyung_consensus['제목_세부내용_전처리후_Kkma']
# Out:
# 0      조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 1      실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2                  3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 3                    3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 4      3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
#                              ...
# 942                                   메모리 반도체 수익성 개선 본격화
# 943                                TSMC 와의 시가 총액 격차 좁히 ㄹ
# 944                                         HBM 경쟁 심화 예상
# 945    강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 946                                추세 하락 이전 주가 반등 가능 ㄹ 듯
# Name: 제목_세부내용_전처리후_Kkma, Length: 947, dtype: object

# %%
def analyze_text_impact(text):
    """
    주어진 텍스트가 삼성전자 주가에 미칠 영향을 분석하는 함수
    """
    prompt = f"""
    이전 지시사항을 모두 잊으세요. 당신은 주식 추천 경험이 있는 금융 전문가라고 가정하세요.
    -1에서 1 사이의 숫자로 응답하세요. -1은 매우 나쁜 소식, 0은 중립적이거나 불확실한 소식, 1은 매우 좋은 소식을 의미합니다. 소수점 한 자리까지 사용할 수 있습니다.
    첫 줄에 숫자로 답하고, 그 다음 줄에 한 문장으로 간결하게 설명하세요.
    이 텍스트는 앞으로 10일 동안에 삼성전자의 주가에 어떤 영향을 미칠까요?
    텍스트: {text}
    """
    model = "gpt-4o-mini"
    messages = [
        {"role": "user", "content": prompt}
    ] 
    # API 호출
    response = client.chat.completions.create(
        model=model,          # 사용하고자 하는 모델
        messages=messages,    # 메시지 리스트      
        max_tokens=50,        # 생성할 응답의 최대 토큰 수
        temperature=0         # 일관성 있는 답변을 위해 낮은 temperature 설정 (0이면 거의 동일한 답변, 1이면 매번 다른 답변)
    )
    # 응답 결과 가져오기
    result = response.choices[0].message.content
    # 숫자와 설명 문구를 분리
    sentiment, predicted_text = result.split('\n', 1)
    return sentiment,predicted_text

# 결과를 저장할 리스트
sentiments = []
predicted_texts = []

for text in tqdm(df_hankyung_consensus['제목_세부내용_전처리후_Kkma']):
    sentiment,predicted_text = analyze_text_impact(text)
    # 리스트에 추가
    sentiments.append(float(sentiment.strip()))     # 숫자로 변환
    predicted_texts.append(predicted_text.strip())  # 텍스트 정리
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 947/947 [10:26<00:00,  1.51it/s]

# %%
# 결과를 데이터프레임에 추가
df_hankyung_consensus['GPT_Sentiment'] = sentiments
df_hankyung_consensus['Predicted_Text'] = predicted_texts

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명    종목코드                                 제목       적정가격  \
# 0   2017-09-06  삼성전자  005930                    조정의 빌미는 사라지고 있나  2,800,000
# 1   2017-09-08  삼성전자  005930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000
# 2   2017-09-08  삼성전자  005930                      3분기 증익을 예상합니다  3,300,000
# 3   2017-09-08  삼성전자  005930                    3분기 감익 우려 해소 기대  3,100,000
# 4   2017-09-11  삼성전자  005930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000
# ..         ...   ...     ...                                ...        ...
# 942 2024-08-01  삼성전자  005930                  메모리반도체 수익성 개선 본격화    110,000
# 943 2024-08-01  삼성전자  005930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000
# 944 2024-08-01  삼성전자  005930                       HBM 경쟁 심화 예상     97,000
# 945 2024-08-01  삼성전자  005930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000
# 946 2024-08-07  삼성전자  005930              추세 하락 이전에 주가 반등 가능할 듯     87,000
#
#     평가의견       작성자     작성기관  \
# 0    Buy       황민성     삼성증권
# 1    Buy       김선우  메리츠종금증권
# 2    Buy       어규진   이베스트증권
# 3    Buy   이순학,김정현   한화투자증권
# 4    Buy       박유악     키움증권
# ..   ...       ...      ...
# 942  Buy       백길현    유안타증권
# 943  Buy       이승우   유진투자증권
# 944  Buy   송명섭,손우성   하이투자증권
# 945  Buy  김광진,최영주    한화투자증권
# 946  Buy       송명섭   하이투자증권
#
#                                                   세부내용  \
# 0    삼성전자(005930)조정의 빌미는 사라지고 있나?반도체 혁신으로 메모리 반도체 제...
# 1    삼성전자(005930)실적 성장 재개와 함께 강화되는 주주환원시장 기대치를 소폭 능...
# 2         삼성전자(005930)3분기 증익을 예상합니다!3분기 영업이익 14.3조원 전망
# 3           삼성전자(005930)3분기 감익 우려 해소 기대4분기 서프라이즈 실적 기대
# 4    삼성전자(005930)3Q17 영업이익 총 15조원, 반도체 10조원 전망3Q17 ...
# ..                                                 ...
# 942    삼성전자(005930) 메모리반도체 수익성 개선 본격화메모리반도체 수익성 개선 본격화
# 943  삼성전자(005930) TSMC와의 시가총액 격차를 좁혀나 갈 시간TSMC와의 시가...
# 944              삼성전자(005930) HBM 경쟁 심화 예상HBM 경쟁 심화 예상
# 945  삼성전자(005930) 여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주...
# 946  삼성전자(005930) 추세 하락 이전에 주가 반등 가능할 듯추세 하락 이전에 주가...
#
#                                              세부내용_전처리후  \
# 0      반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. 매수의견과 목표가 280만...
# 1     시장 기대치를 소폭 능가하는 3Q17 영업이익 14.3조원 전망 지속 유지 4Q1...
# 2                                   3분기 영업이익 14.3조원 전망
# 3                                      4분기 서프라이즈 실적 기대
# 4                         3Q17 영업이익 15조원 시장 기대치 상회할 전망
# ..                                                 ...
# 942
# 943
# 944
# 945   여전히 강력한 AI발 수요. 조정기를 거치며 더욱 편해진 주가여전히 강력한 AI발...
# 946
#
#                                           제목_세부내용_전처리후  \
# 0    조정의 빌미는 사라지고 있나 반도체 혁신으로 메모리 반도체 제값 받기는 진행 중. ...
# 1    실적 성장 재개와 함께 강화되는 주주환원 시장 기대치를 소폭 능가하는 3Q17 영업...
# 2                     3분기 증익을 예상합니다 3분기 영업이익 14.3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                  메모리반도체 수익성 개선 본격화
# 943                           TSMC와의 시가총액 격차를 좁혀나 갈 시간
# 944                                       HBM 경쟁 심화 예상
# 945  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가 여전히 강력한 AI발 ...
# 946                              추세 하락 이전에 주가 반등 가능할 듯
#
#                                       제목_세부내용_전처리후_Okt  \
# 0    조정 빌 미는 사라지고 있나 반도체 혁신 메모리 반도체 값 받기는 진행 중 수 의견...
# 1    실적 성장 재개 강화 되는 주주 환원 시장 기 대치 소 폭 능가 하는 3 Q 17 ...
# 2                  3분 기 증익 예상 합니다 3분 기 영업 이익 14.3조원 전망
# 3                    3분 기 감익 우려 해소 기대 4분 기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15조원 반도체 10조원 전망 3 Q 17 영업 이익 1...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                              TSMC 와의 시가총액 격차 좁혀나 갈
# 944                                       HBM 경쟁 심화 예상
# 945  강력한 AI 발 수요 조 정기 거치 며 더욱 편해진 주가 강력한 AI 발 수요 조 ...
# 946                               추세 하락 이전 주가 반등 가능할 듯
#
#                                  제목_세부내용_전처리후_Hannanum  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주환원 시장 기대치 소폭 능가 는 3Q17 영업이익 ...
# 2                    3분기 증익 예상 ㅂ니다 3분기 영업이익 14. 3조원 전망
# 3                      3분기 감익 우려 해소 기대 4분기 서프라이즈 실적 기대
# 4    3Q17 영업이익 총 15조원 반도체 10조원 전망 3Q17 영업이익 15조원 시장...
# ..                                                 ...
# 942                                 메모리반도체 수익성 개 선 본격화
# 943                               TSMC 와의 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 편하 지 ㄴ 주 강력 ㄴ AI 발 수요...
# 946                               추세 하락 이전 주 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_Kkma  \
# 0    조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2                3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망
# 3                  3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                                 메모리 반도체 수익성 개선 본격화
# 943                              TSMC 와의 시가 총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                   제목_세부내용_전처리후_Komoran  \
# 0    조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2               3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 3                   3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..                                                 ...
# 942                               메모리 반도체 수익 성 개선 본격 화
# 943                                  TSMC 시가총액 격차 좁히 ㄹ
# 944                                       HBM 경쟁 심화 예상
# 945  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#                                      제목_세부내용_전처리후_kiwi  \
# 0           조정 빌미 반도체 혁신 메모리 반도체 제값 진행 매수 의견 목표 280 유지
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 14.3 전...
# 2                               분기 예상 분기 영업 이익 14.3 전망
# 3                           분기 우려 해소 기대 분기 서프라이즈 실적 기대
# 4       17 영업 이익 15 반도체 10 전망 17 영업 이익 15 시장 기대치 상회 전망
# ..                                                 ...
# 942                                   메모리 반도체 수익 개선 본격
# 943                                      TSMC 시가 총액 격차
# 944                                       HBM 경쟁 심화 예상
# 945          AI 수요 조정기 편하 AI 수요 조정기 편하 AI 수요 조정기 편하 주가
# 946                                  추세 하락 이전 주가 반등 가능
#
#                                제목_세부내용_전처리후_Komoran_명사  평가의견_label  \
# 0          조정 빌미 반도체 혁신 메모리 반도체 제값 진행 중 매수 의견 목표 만원 유지           1
# 1    실적 성장 재개 강화 주주 환원 시장 기대치 소폭 능가 17 영업 이익 원 전망 지...           1
# 2                              분기 증 익 예상 분기 영업 이익 원 전망           1
# 3                       분기 감 익 우려 해소 기대 분기 서프라이즈 실적 기대           1
# 4           17 영업 이익 원 반도체 원 전망 17 영업 이익 원 시장 기대 상회 전망           1
# ..                                                 ...         ...
# 942                                      메모리 반도체 수익 개선           1
# 943                                            시가총액 격차           1
# 944                                           경쟁 심화 예상           1
# 945    발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가 발 수요 조정 편 해진 주가           1
# 946                                   추세 하락 이전 주가 반등 듯           1
#
#      GPT_Sentiment                                     Predicted_Text
# 0              0.5  조정 우려가 줄어들고 있으며, 메모리 반도체의 가격 회복이 긍정적인 신호로 작용할 ...
# 1              1.0  삼성전자의 실적 성장과 주주 환원 기대가 긍정적으로 작용하여 주가 상승에 기여할 것...
# 2              1.0  삼성전자의 3분기 증익 예상은 긍정적인 투자 신호로, 주가 상승에 기여할 것으로 보...
# 3              0.7  삼성전자의 3분기 감익 우려가 해소될 것으로 보이며, 4분기 실적에 대한 긍정적인 ...
# 4              1.0  삼성전자의 3분기 영업 이익이 시장 기대치를 상회할 것으로 예상되며, 이는 긍정적인...
# ..             ...                                                ...
# 942            1.0  메모리 반도체 수익성 개선은 삼성전자의 실적 향상에 긍정적인 영향을 미칠 것으로 예...
# 943            0.5  삼성전자가 TSMC와의 시가 총액 격차를 좁히는 것은 긍정적인 신호로 해석될 수 있...
# 944           -0.7  HBM 경쟁 심화는 삼성전자의 시장 점유율과 수익성에 부정적인 영향을 미칠 가능성이...
# 945            1.0    강력한 AI 수요 조정기가 삼성전자의 주가에 긍정적인 영향을 미칠 것으로 예상됩니다.
# 946            0.5     주가 반등 가능성이 있지만, 추세 하락이 지속될 경우 불확실성이 여전히 존재합니다.
#
# [947 rows x 20 columns]

# %%
# 원하는 열만 선택하여 새로운 데이터프레임 생성
df_hankyung_consensus = df_hankyung_consensus[['작성일', '종목명', '종목코드', '제목', '적정가격', '평가의견', '작성자',
                                              '작성기관', '제목_세부내용_전처리후_Kkma', 'GPT_Sentiment', 'Predicted_Text']]

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명    종목코드                                 제목       적정가격  \
# 0   2017-09-06  삼성전자  005930                    조정의 빌미는 사라지고 있나  2,800,000
# 1   2017-09-08  삼성전자  005930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000
# 2   2017-09-08  삼성전자  005930                      3분기 증익을 예상합니다  3,300,000
# 3   2017-09-08  삼성전자  005930                    3분기 감익 우려 해소 기대  3,100,000
# 4   2017-09-11  삼성전자  005930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000
# ..         ...   ...     ...                                ...        ...
# 942 2024-08-01  삼성전자  005930                  메모리반도체 수익성 개선 본격화    110,000
# 943 2024-08-01  삼성전자  005930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000
# 944 2024-08-01  삼성전자  005930                       HBM 경쟁 심화 예상     97,000
# 945 2024-08-01  삼성전자  005930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000
# 946 2024-08-07  삼성전자  005930              추세 하락 이전에 주가 반등 가능할 듯     87,000
#
#     평가의견       작성자     작성기관  \
# 0    Buy       황민성     삼성증권
# 1    Buy       김선우  메리츠종금증권
# 2    Buy       어규진   이베스트증권
# 3    Buy   이순학,김정현   한화투자증권
# 4    Buy       박유악     키움증권
# ..   ...       ...      ...
# 942  Buy       백길현    유안타증권
# 943  Buy       이승우   유진투자증권
# 944  Buy   송명섭,손우성   하이투자증권
# 945  Buy  김광진,최영주    한화투자증권
# 946  Buy       송명섭   하이투자증권
#
#                                      제목_세부내용_전처리후_Kkma  GPT_Sentiment  \
# 0    조정 빌미 는 사라지 고 있 반 도 체 혁신 메모리 반도체 제값 받 기 는 진행 중...            0.5
# 1    실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...            1.0
# 2                3 분기 증익 예상 ㅂ니다 3 분기 영업 이익 14.3 조 원 전망            1.0
# 3                  3 분기 감익 우려 해소 기대 4 분기 서 프라이 즈 실적 기대            0.7
# 4    3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...            1.0
# ..                                                 ...            ...
# 942                                 메모리 반도체 수익성 개선 본격화            1.0
# 943                              TSMC 와의 시가 총액 격차 좁히 ㄹ            0.5
# 944                                       HBM 경쟁 심화 예상           -0.7
# 945  강력 ㄴ AI 발 수요 조정기 거치 며 더욱 펴 ㄴ 해진 주가 강력 ㄴ AI 발 수...            1.0
# 946                              추세 하락 이전 주가 반등 가능 ㄹ 듯            0.5
#
#                                         Predicted_Text
# 0    조정 우려가 줄어들고 있으며, 메모리 반도체의 가격 회복이 긍정적인 신호로 작용할 ...
# 1    삼성전자의 실적 성장과 주주 환원 기대가 긍정적으로 작용하여 주가 상승에 기여할 것...
# 2    삼성전자의 3분기 증익 예상은 긍정적인 투자 신호로, 주가 상승에 기여할 것으로 보...
# 3    삼성전자의 3분기 감익 우려가 해소될 것으로 보이며, 4분기 실적에 대한 긍정적인 ...
# 4    삼성전자의 3분기 영업 이익이 시장 기대치를 상회할 것으로 예상되며, 이는 긍정적인...
# ..                                                 ...
# 942  메모리 반도체 수익성 개선은 삼성전자의 실적 향상에 긍정적인 영향을 미칠 것으로 예...
# 943  삼성전자가 TSMC와의 시가 총액 격차를 좁히는 것은 긍정적인 신호로 해석될 수 있...
# 944  HBM 경쟁 심화는 삼성전자의 시장 점유율과 수익성에 부정적인 영향을 미칠 가능성이...
# 945    강력한 AI 수요 조정기가 삼성전자의 주가에 긍정적인 영향을 미칠 것으로 예상됩니다.
# 946     주가 반등 가능성이 있지만, 추세 하락이 지속될 경우 불확실성이 여전히 존재합니다.
#
# [947 rows x 11 columns]

# %%
df_hankyung_consensus.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Kkma_chatgpt.xlsx', index=False)

# %%
#여기서부터 소수점 1자리로 처리하기 위한 코드
# EXCEL파일 읽기
file_path = './Text_Data/한경_리포트_데이터_기업_SEC_Komoran_chatgpt.xlsx'
df_hankyung_consensus = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# 소수점 1자리로 반올림
df_hankyung_consensus['GPT_Sentiment'] = df_hankyung_consensus['GPT_Sentiment'].round(1)
df_hankyung_consensus['GPT_Sentiment'] = df_hankyung_consensus['GPT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)

# %%
df_hankyung_consensus
# Out:
#            작성일   종목명  종목코드                                 제목       적정가격 평가의견  \
# 0   2017-09-06  삼성전자  5930                    조정의 빌미는 사라지고 있나  2,800,000  Buy
# 1   2017-09-08  삼성전자  5930             실적 성장 재개와 함께 강화되는 주주환원  3,040,000  Buy
# 2   2017-09-08  삼성전자  5930                      3분기 증익을 예상합니다  3,300,000  Buy
# 3   2017-09-08  삼성전자  5930                    3분기 감익 우려 해소 기대  3,100,000  Buy
# 4   2017-09-11  삼성전자  5930       3Q17 영업이익 총 15조원 반도체 10조원 전망  3,100,000  Buy
# ..         ...   ...   ...                                ...        ...  ...
# 942 2024-08-01  삼성전자  5930                  메모리반도체 수익성 개선 본격화    110,000  Buy
# 943 2024-08-01  삼성전자  5930           TSMC와의 시가총액 격차를 좁혀나 갈 시간    110,000  Buy
# 944 2024-08-01  삼성전자  5930                       HBM 경쟁 심화 예상     97,000  Buy
# 945 2024-08-01  삼성전자  5930  여전히 강력한 AI발 수요 조정기를 거치며 더욱 편해진 주가    115,000  Buy
# 946 2024-08-07  삼성전자  5930              추세 하락 이전에 주가 반등 가능할 듯     87,000  Buy
#
#           작성자     작성기관                               제목_세부내용_전처리후_Komoran  \
# 0         황민성     삼성증권  조정 빌미 는 사라지 고 있 반도체 혁신 메모리 반도체 제값 받 기 는 진행 중 매...
# 1         김선우  메리츠종금증권  실적 성장 재개 강화 되 는 주주 환원 시장 기대치 소폭 능가 는 3 Q 17 영업...
# 2         어규진   이베스트증권             3 분기 증 익 예상 ㅂ니다 3 분기 영업 이익 14 3 조 원 전망
# 3     이순학,김정현   한화투자증권                 3 분기 감 익 우려 해소 기대 4 분기 서프라이즈 실적 기대
# 4         박유악     키움증권  3 Q 17 영업 이익 총 15 조 원 반도체 10 조 원 전망 3 Q 17 영업 ...
# ..        ...      ...                                                ...
# 942       백길현    유안타증권                               메모리 반도체 수익 성 개선 본격 화
# 943       이승우   유진투자증권                                  TSMC 시가총액 격차 좁히 ㄹ
# 944   송명섭,손우성   하이투자증권                                       HBM 경쟁 심화 예상
# 945  김광진,최영주    한화투자증권  강력 ㄴ AI 발 수요 조정 기 거치 며 더욱 편 해진 주가 강력 ㄴ AI 발 수요...
# 946       송명섭   하이투자증권                              추세 하락 이전 주가 반등 가능 ㄹ 듯
#
#      GPT_Sentiment                                     Predicted_Text
# 0              0.8  삼성전자의 반도체 혁신과 매수 의견 유지가 긍정적인 신호를 주지만, 조정 가능성도 ...
# 1              1.0  삼성전자의 3분기 영업 이익 전망이 시장 기대치를 소폭 능가하며 실적 성장 재개에 ...
# 2              1.0  삼성전자의 3분기 영업 이익이 14.3조 원으로 예상되면서 긍정적인 실적 전망이 주...
# 3              1.0  삼성전자의 3분기 감익 우려가 해소되고 4분기 실적에 대한 긍정적인 기대감이 주가에...
# 4              1.0  삼성전자의 3분기 영업 이익이 시장 기대치를 상회할 것으로 보이며, 이는 긍정적인 ...
# ..             ...                                                ...
# 942            1.0  메모리 반도체 수익 성 개선이 긍정적인 신호로 작용하여 삼성전자의 주가에 긍정적인 ...
# 943            0.5  TSMC의 시가총액 격차가 좁혀지면 삼성전자의 경쟁력이 강화될 수 있지만, 시장의 ...
# 944           -0.5  HBM 경쟁 심화는 삼성전자의 시장 점유율과 수익성에 부정적인 영향을 미칠 가능성이...
# 945            1.0     강력한 AI 수요 조정이 삼성전자의 주가에 긍정적인 영향을 미칠 것으로 예상됩니다.
# 946            0.5     주가 반등 가능성이 있지만, 추세 하락이 지속될 경우 불확실성이 여전히 존재합니다.
#
# [947 rows x 11 columns]

# %%
# 'Date' 열을 datetime 타입으로 변환
df_hankyung_consensus.loc[:, '작성일'] = pd.to_datetime(df_hankyung_consensus['작성일'])

# 날짜별로 'GPT_Sentiment'의 평균을 계산
df_hankyung_consensus_grouped = df_hankyung_consensus.groupby('작성일')['GPT_Sentiment'].mean().reset_index()

# 그래프 시각화
plt.figure(figsize=(12, 6))
plt.plot(df_hankyung_consensus_grouped['작성일'], df_hankyung_consensus_grouped['GPT_Sentiment'], marker='o', linestyle='-', color='b')
plt.title('Time Series of GPT Sentiment')
plt.xlabel('작성일')
plt.ylabel('GPT Sentiment')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# 그래프 보여주기
plt.show()

# %%
df_hankyung_consensus.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Kkma_chatgpt.xlsx', index=False)

# %%
df_hankyung_consensus_avg = df_hankyung_consensus.groupby('작성일', as_index=False)['GPT_Sentiment'].mean()
# 소수점 1자리로 반올림
df_hankyung_consensus_avg['GPT_Sentiment'] = df_hankyung_consensus_avg['GPT_Sentiment'].round(1)
df_hankyung_consensus_avg['GPT_Sentiment'] = df_hankyung_consensus_avg['GPT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
df_hankyung_consensus_avg
# Out:
#            작성일  GPT_Sentiment
# 0   2017-09-06            0.8
# 1   2017-09-08            1.0
# 2   2017-09-11            1.0
# 3   2017-09-12            0.5
# 4   2017-09-13            1.0
# ..         ...            ...
# 425 2024-06-24            1.0
# 426 2024-07-02            1.0
# 427 2024-07-05            0.0
# 428 2024-08-01            0.6
# 429 2024-08-07            0.5
#
# [430 rows x 2 columns]

# %%
# 감정 분석 결과 저장(일자별)
df_hankyung_consensus_avg.to_excel('./Text_Data/한경_리포트_데이터_기업_SEC_Kkma_chatgpt_daily.xlsx', index=False)
