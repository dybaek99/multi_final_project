# %% [markdown]
# 파일을 기간별로 나누어 크롤링하고 나누어지 파일 저장

# %%
import os
import pandas as pd

# File paths
file_list = [
    '한경_리포트_데이터_기업_SEC.csv',
    '매일경제/NewsResult_20170901-20240830.xlsx',
    '서울경제/NewsResult_20170901-20240830.xlsx',
    '한국경제/NewsResult_20170901-20240830.xlsx',
    '경제/NewsResult_20170901-20190124.xlsx',
    '경제/NewsResult_20190125-20200618.xlsx',
    '경제/NewsResult_20200619-20211111.xlsx',
    '경제/NewsResult_20211112-20230406.xlsx',
    '경제/NewsResult_20230407-20240830.xlsx',
    '국제/NewsResult_20170901-20240830.xlsx',
    '사회/매일,서울경제/NewsResult_20170901-20240830.xlsx',
    '사회/한국경제/NewsResult_20170901-20240830.xlsx',
    '과학/NewsResult_20170901-20200901.xlsx',
    '과학/NewsResult_20200902-20240830.xlsx',
    '삼성전자_정치_20170901-20240830.xlsx',
    '삼성전자_경제_20170901-20240830.xlsx',
    '삼성전자_국제_20170901-20240830.xlsx',
    '삼성전자_IT_과학_20170901-20240830.xlsx',
    '삼성전자_사회_20170901-20240830.xlsx',
    '한경_리포트_데이터_기업_SEC.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후.xlsx',
    '삼성전자_국제_20170901-20240830_전처리후.xlsx',
    '삼성전자_IT_과학_20170901-20240830_전처리후.xlsx',
    '삼성전자_사회_20170901-20240830_전처리후.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_원본_daily.csv',
    '삼성전자_경제_20170901-20240830_전처리후_원본_daily.csv',
    '삼성전자_국제_20170901-20240830_전처리후_원본_daily.csv',
    '삼성전자_IT_과학_20170901-20240830_전처리후_원본_daily.csv',
    '삼성전자_사회_20170901-20240830_전처리후_원본_daily.csv',
    '한경_리포트_데이터_기업_SEC_원본_daily.csv',
    'Samsung_bigkind_sentiment_merge.csv',
    'Community_Sentiment.csv',
    '삼성전자_IT_경제_20170901-20240830.xlsx',
    '한경_리포트_데이터_기업_SEC_원본_KoBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Okt_KoBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Hannanum_KoBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Kkma_KoBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Komoran_KoBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_원본_chatgpt_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Okt_chatgpt_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Hannanum_chatgpt_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Kkma_chatgpt_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Komoran_chatgpt_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_원본_KoFinBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Okt_KoFinBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Hannanum_KoFinBERT_daily.xlsx',
    '한경_리포트_데이터_기업_SEC_Kkma_KoFinBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_원본_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_Okt_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_Hannanum_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_Kkma_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_Komoran_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_kiwi_KoBERT_daily.xlsx',
    '삼성전자_정치_20170901-20240830_전처리후_Komoran_명사_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_원본_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_Okt_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_Kkma_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_kiwi_KoBERT_daily.xlsx',
    '삼성전자_경제_20170901-20240830_전처리후_Komoran_명사_KoBERT_daily.xlsx'
]

# Split into file name and path
file_data = [(os.path.basename(file), os.path.dirname(file)) for file in file_list]

# Create a DataFrame
df_files = pd.DataFrame(file_data, columns=["File Name", "File Path"])

# Display the DataFrame
print(df_files)

# Optionally display it nicely in a notebook environment (if you're using one)
# df_files
# Out:
#                                             File Name File Path
# 0                               한경_리포트_데이터_기업_SEC.csv
# 1                   NewsResult_20170901-20240830.xlsx      매일경제
# 2                   NewsResult_20170901-20240830.xlsx      서울경제
# 3                   NewsResult_20170901-20240830.xlsx      한국경제
# 4                   NewsResult_20170901-20190124.xlsx        경제
# ..                                                ...       ...
# 56  삼성전자_경제_20170901-20240830_전처리후_Okt_KoBERT_dail...
# 57  삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT...
# 58  삼성전자_경제_20170901-20240830_전처리후_Kkma_KoBERT_dai...
# 59  삼성전자_경제_20170901-20240830_전처리후_kiwi_KoBERT_dai...
# 60  삼성전자_경제_20170901-20240830_전처리후_Komoran_명사_KoBE...
#
# [61 rows x 2 columns]

# %%
df_files
# Out:
#                                             File Name File Path
# 0                               한경_리포트_데이터_기업_SEC.csv
# 1                   NewsResult_20170901-20240830.xlsx      매일경제
# 2                   NewsResult_20170901-20240830.xlsx      서울경제
# 3                   NewsResult_20170901-20240830.xlsx      한국경제
# 4                   NewsResult_20170901-20190124.xlsx        경제
# ..                                                ...       ...
# 56  삼성전자_경제_20170901-20240830_전처리후_Okt_KoBERT_dail...
# 57  삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT...
# 58  삼성전자_경제_20170901-20240830_전처리후_Kkma_KoBERT_dai...
# 59  삼성전자_경제_20170901-20240830_전처리후_kiwi_KoBERT_dai...
# 60  삼성전자_경제_20170901-20240830_전처리후_Komoran_명사_KoBE...
#
# [61 rows x 2 columns]
