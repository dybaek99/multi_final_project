# %%
from openai import OpenAI
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import time
import gc
from openai import OpenAIError, RateLimitError

from matplotlib import rcParams
# 한글 폰트 설정
rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕으로 설정
rcParams['axes.unicode_minus'] = False     # 음수 기호 문제 해결

# %%
# APIKEY 정의
api_key = "" 
client = OpenAI(api_key=api_key)

# %%
# EXCEL파일 읽기
file_path = './Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후.xlsx'
df_bigkinds = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# %%
df_bigkinds
# Out:
#                            뉴스 식별자         일자   언론사  기고자  \
# 0      02100101.20170901161300001 2017-09-01  매일경제  NaN
# 1      02100101.20170901162741001 2017-09-01  매일경제  김동은
# 2      02100101.20170901160436001 2017-09-01  매일경제  박진형
# 3      02100101.20170901084332002 2017-09-01  매일경제  박진형
# 4      02100101.20170901134823001 2017-09-01  매일경제  박진형
# ...                           ...        ...   ...  ...
# 77777  02100601.20240830155007001 2024-08-30  한국경제  한경우
# 77778  02100601.20240830110414001 2024-08-30  한국경제  한경우
# 77779  02100601.20240830092005001 2024-08-30  한국경제  한경우
# 77780  02100601.20240830174157001 2024-08-30  한국경제  황정수
# 77781  02100601.20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                      URL 분석제외 여부  \
# 0      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 1      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 2      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 3      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 4      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# ...                                                  ...     ...
# 77777     https://www.hankyung.com/article/2024083072596     NaN
# 77778     https://www.hankyung.com/article/2024083065006     NaN
# 77779     https://www.hankyung.com/article/2024083060686     NaN
# 77780     https://www.hankyung.com/article/2024083076661     NaN
# 77781     https://www.hankyung.com/article/2024083076681     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                          제목_키워드_전처리후_Okt  \
# 0      코스닥 공시 코웰 패션 유니 셈 MDS 테크 코웰 패션 유니 셈 MDS 테크 코웰 ...
# 1      함대 가라앉는건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계...
# 2      LG 유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG 유플러스 라...
# 3      Hot - Line 해성 옵 틱 스 듀얼 카메라 확대 따른 수혜 기대 해성 옵 틱 ...
# 4      삼성 갤 노트 8 100만원 웃 돌듯 고동진 낮추려 노력 했지만 어려워 삼성 갤 노...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 한 코스피 HLB 코스닥 시 총 3 위 올라 엔비디아 ...
# 77778  외국인 매수 코스피 강세 코스닥 선 바이오 vs 2 차전지 공 방 외국인 매수 코스...
# 77779  코스피 외국인 매수 강세 삼성 SK 하이닉스 소 폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                     제목_키워드_전처리후_Hannanum  \
# 0      코스닥 공시 코웰패션 유니셈 MDS 테크 코웰패션 유니셈 MDS 테크 코웰패션 안정...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독 ㄹ 세계가...
# 2      LG유플러스 천안역사 동아 라이크 텐 홈IoT 플랫폼 구축 LG유플러스 라이크 천안...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 갤노트8 100만원 웃돌 듯 고동진 낮추 려 노력 었지만 어렵 삼성 갤노트 1...
# ...                                                  ...
# 77777  엔비디 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 오르 엔비디아 쇼크 회...
# 77778  외국 ㄴ 매수 코스피 강세 코스닥 선 바 vs 2차전지 공방 외국 ㄴ 매수 코스피 ...
# 77779  코스피 외국 ㄴ 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국 ㄴ 매수 강...
# 77780  DB 글로벌칩 대표 박찬호 DDI 설계 제2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드 리 힘 빼 ㄴ다 인텔 파운드 리 실적 부진 구조조정 인텔 파운드 리 반...
#
#                                         제목_키워드_전처리후_Kkma  \
# 0      코스닥 공시 코 웨 ㄹ 패션 유니 셈 MDS 테크 코 웨 ㄹ 패션 유니 셈 MDS ...
# 1      함대 가라앉 는 은 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG 유 플러스 천안 역사 동아 라이크 터 ㄴ 홈 IoT 플랫폼 구축 LG 유 플러...
# 3      Hot-Line 해성 옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성 옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만 원 웃돌 듯 고동진 낮추 려 노력 었 어렵 삼성 개...
# ...                                                  ...
# 77777  엔 비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 올르 엔 비...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK 하이닉스 소폭 반등 코스 피 외국인 매수 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체...
#
#                                      제목_키워드_전처리후_Komoran  \
# 0      코스닥 공시 코웰패션 유니 셈 MDS 테크 코웰패션 유니 셈 MDS 테크 코웰패션 ...
# 1      함대 가라앉 는 건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG유플러스 라이 ...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만원 웃돌 듯 고동진 낮추 려 노력 았 어렵 삼성 개 ...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 오르 엔비디아...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 ...
#
#                                         제목_키워드_전처리후_kiwi  \
# 0      코스닥 공시 코웰 패션 유니셈 MDS 테크 코웰 패션 유니셈 MDS 테크 코웰 패션...
# 1      함대 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계 가전 박람...
# 2      LG유플러스 천안 역사 동아 라이크 IoT 플랫폼 구축 LG유플러스 라이크 천안 역...
# 3      Hot Line 해성옵틱스 듀얼 카메라 확대 수혜 기대 해성옵틱스 확대 듀얼 카메라...
# 4      삼성 갤노트8 100 고동진 노력 어렵 삼성 노트 100 고동진 노력 노트 삼성전자...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스피 HLB 코스닥 엔비디아 쇼크 회복 시도 코스피 HL...
# 77778  외국인 매수 코스피 강세 코스닥 바이오 vs 전지 공방 외국인 매수 코스피 강세 코...
# 77779  코스피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 대표 박찬호 DDI 설계 도약 DB 글로벌 대표 박찬호 DDI 설계 도...
# 77781  인텔 파운드리 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체 수탁 생산 ...
#
#                                   제목_키워드_전처리후_Komoran_명사
# 0      코스닥 공시 유니 셈 테크 유니 셈 테크 안정 임대 수익 창출 펜타포트 토지 건물 ...
# 1      함대 건 순식간 총수 부재 함대 순식간 함대 총수 부재 독일 세계 가전 박람회 윤 ...
# 2      LG유플러스 천안 역사 동아 라이 텐 홈 플랫폼 구축 LG유플러스 라이 천안 역사 ...
# 3      카메라 확대 수혜 기대 확대 카메라 수혜 유진 투자 증권 채택 카메라 수혜 설립 전...
# 4      삼성 노트 만원 고동진 노력 삼성 노트 고동진 노력 노트 삼성전자 갤럭시 노트 가격...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스 피 코스닥 시 총 위 엔비디아 쇼크 회복 시도 코스 ...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 차 전지 공방 외국인 매수 코스 피 강...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  글로벌 칩 대표 박찬호 설계 도약 글로벌 대표 박찬호 설계 도약 분사 반도체 기업 ...
# 77781  인텔 파운드리 힘 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수 탁 생...
#
# [77782 rows x 27 columns]

# %%
df_bigkinds.columns
# Out:
# Index(['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2', '통합 분류3',
#        '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드',
#        '특성추출(가중치순 상위 50개)', '본문', 'URL', '분석제외 여부', '제목_키워드', '제목_키워드_전처리후',
#        '제목_키워드_전처리후_Okt', '제목_키워드_전처리후_Hannanum', '제목_키워드_전처리후_Kkma',
#        '제목_키워드_전처리후_Komoran', '제목_키워드_전처리후_kiwi', '제목_키워드_전처리후_Komoran_명사'],
#       dtype='object')

# %%
df_bigkinds['제목_키워드_전처리후']
# Out:
# 0        코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...
# 1        함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...
# 2        LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...
# 3        Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...
# 4        삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...
#                                ...
# 77777    엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...
# 77778    외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...
# 77779    코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...
# 77780    DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...
# 77781    인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
# Name: 제목_키워드_전처리후, Length: 77782, dtype: object

# %%
# chatgpt - 원래 소스 대비 10배 빨라지며 50개 샘플링으로 테스트시 sentiments 동일/predicted_texts는 상이할 수 있으나
# 원래 소스도 재실행시 상이
# 개선사항
# 1. 병렬 처리: ThreadPoolExecutor를 사용하여 동시에 여러 요청을 보낼 수 있도록 했습니다. 이렇게 하면 처리 속도가 병목 현상 없이 크게 개선됩니다.
# 2. 딜레이 최적화: RateLimitError가 발생할 때 10초를 기다리는 대신, 1초 대기 후 재시도하도록 수정했습니다. 이렇게 하면 딜레이로 인한 비효율을 줄일 수 있습니다.
# 3. 오류 처리: RateLimitError 외의 예외가 발생할 경우도 안전하게 처리하여 실행이 중단되지 않도록 했습니다.
# 4. 결과 정리: sentiments와 predicted_texts 리스트를 오류 없이 저장할 수 있도록 수정했습니다.

import concurrent.futures
import time
from tqdm import tqdm

def analyze_text_impact(text):
    """
    주어진 텍스트가 삼성전자 주가에 미칠 영향을 분석하는 함수
    """
    prompt = f"""
    이전 지시사항을 모두 잊으세요. 당신은 주식 추천 경험이 있는 금융 전문가라고 가정하세요.
    -1에서 1 사이의 숫자로 응답하세요. -1은 매우 나쁜 소식, 0은 중립적이거나 불확실한 소식, 1은 매우 좋은 소식을 의미합니다. 소수점 한 자리까지 사용할 수 있습니다.
    첫 줄에 숫자로 답하고, 그 다음 줄에 한 문장으로 간결하게 설명하세요.
    이 텍스트는 앞으로 10일 동안에 삼성전자의 주가에 어떤 영향을 미칠까요?
    텍스트: {text}
    """
    model = "gpt-4o-mini"
    messages = [
        {"role": "user", "content": prompt}
    ]
    while True:
        try:
            # API 호출
            response = client.chat.completions.create(
                model=model,        
                messages=messages,    
                max_tokens=50,        
                temperature=0        
            )
            result = response.choices[0].message.content
            sentiment, predicted_text = result.split('\n', 1)
            return float(sentiment.strip()), predicted_text.strip()  # 값 정리
        except RateLimitError as e:
            print(f"Rate limit reached: {e}. Retrying in 1 second...")
            time.sleep(1)  # 대기 시간을 1초로 줄임
        except Exception as e:
            print(f"An error occurred: {e}")
            return None, None  # 오류 처리
# 텍스트 분석을 병렬로 처리
def analyze_texts_in_parallel(text_list):
    results = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(analyze_text_impact, text_list), total=len(text_list)))
    return results
# 분석할 텍스트 리스트
text_list = df_bigkinds['제목_키워드_전처리후'].tolist()

# 병렬 처리를 통한 결과 분석
results = analyze_texts_in_parallel(text_list)

# 결과 저장
sentiments = [result[0] for result in results if result[0] is not None]
predicted_texts = [result[1] for result in results if result[1] is not None]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 77782/77782 [1:20:40<00:00, 16.07it/s]

# %%
# 결과를 데이터프레임에 추가
df_bigkinds['GPT_Sentiment'] = sentiments
df_bigkinds['Predicted_Text'] = predicted_texts

# %%
df_bigkinds
# Out:
#                            뉴스 식별자         일자   언론사  기고자  \
# 0      02100101.20170901161300001 2017-09-01  매일경제  NaN
# 1      02100101.20170901162741001 2017-09-01  매일경제  김동은
# 2      02100101.20170901160436001 2017-09-01  매일경제  박진형
# 3      02100101.20170901084332002 2017-09-01  매일경제  박진형
# 4      02100101.20170901134823001 2017-09-01  매일경제  박진형
# ...                           ...        ...   ...  ...
# 77777  02100601.20240830155007001 2024-08-30  한국경제  한경우
# 77778  02100601.20240830110414001 2024-08-30  한국경제  한경우
# 77779  02100601.20240830092005001 2024-08-30  한국경제  한경우
# 77780  02100601.20240830174157001 2024-08-30  한국경제  황정수
# 77781  02100601.20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                          제목_키워드_전처리후_Okt  \
# 0      코스닥 공시 코웰 패션 유니 셈 MDS 테크 코웰 패션 유니 셈 MDS 테크 코웰 ...
# 1      함대 가라앉는건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계...
# 2      LG 유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG 유플러스 라...
# 3      Hot - Line 해성 옵 틱 스 듀얼 카메라 확대 따른 수혜 기대 해성 옵 틱 ...
# 4      삼성 갤 노트 8 100만원 웃 돌듯 고동진 낮추려 노력 했지만 어려워 삼성 갤 노...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 한 코스피 HLB 코스닥 시 총 3 위 올라 엔비디아 ...
# 77778  외국인 매수 코스피 강세 코스닥 선 바이오 vs 2 차전지 공 방 외국인 매수 코스...
# 77779  코스피 외국인 매수 강세 삼성 SK 하이닉스 소 폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                     제목_키워드_전처리후_Hannanum  \
# 0      코스닥 공시 코웰패션 유니셈 MDS 테크 코웰패션 유니셈 MDS 테크 코웰패션 안정...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독 ㄹ 세계가...
# 2      LG유플러스 천안역사 동아 라이크 텐 홈IoT 플랫폼 구축 LG유플러스 라이크 천안...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 갤노트8 100만원 웃돌 듯 고동진 낮추 려 노력 었지만 어렵 삼성 갤노트 1...
# ...                                                  ...
# 77777  엔비디 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 오르 엔비디아 쇼크 회...
# 77778  외국 ㄴ 매수 코스피 강세 코스닥 선 바 vs 2차전지 공방 외국 ㄴ 매수 코스피 ...
# 77779  코스피 외국 ㄴ 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국 ㄴ 매수 강...
# 77780  DB 글로벌칩 대표 박찬호 DDI 설계 제2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드 리 힘 빼 ㄴ다 인텔 파운드 리 실적 부진 구조조정 인텔 파운드 리 반...
#
#                                         제목_키워드_전처리후_Kkma  \
# 0      코스닥 공시 코 웨 ㄹ 패션 유니 셈 MDS 테크 코 웨 ㄹ 패션 유니 셈 MDS ...
# 1      함대 가라앉 는 은 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG 유 플러스 천안 역사 동아 라이크 터 ㄴ 홈 IoT 플랫폼 구축 LG 유 플러...
# 3      Hot-Line 해성 옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성 옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만 원 웃돌 듯 고동진 낮추 려 노력 었 어렵 삼성 개...
# ...                                                  ...
# 77777  엔 비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 올르 엔 비...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK 하이닉스 소폭 반등 코스 피 외국인 매수 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체...
#
#                                      제목_키워드_전처리후_Komoran  \
# 0      코스닥 공시 코웰패션 유니 셈 MDS 테크 코웰패션 유니 셈 MDS 테크 코웰패션 ...
# 1      함대 가라앉 는 건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG유플러스 라이 ...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만원 웃돌 듯 고동진 낮추 려 노력 았 어렵 삼성 개 ...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 오르 엔비디아...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 ...
#
#                                         제목_키워드_전처리후_kiwi  \
# 0      코스닥 공시 코웰 패션 유니셈 MDS 테크 코웰 패션 유니셈 MDS 테크 코웰 패션...
# 1      함대 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계 가전 박람...
# 2      LG유플러스 천안 역사 동아 라이크 IoT 플랫폼 구축 LG유플러스 라이크 천안 역...
# 3      Hot Line 해성옵틱스 듀얼 카메라 확대 수혜 기대 해성옵틱스 확대 듀얼 카메라...
# 4      삼성 갤노트8 100 고동진 노력 어렵 삼성 노트 100 고동진 노력 노트 삼성전자...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스피 HLB 코스닥 엔비디아 쇼크 회복 시도 코스피 HL...
# 77778  외국인 매수 코스피 강세 코스닥 바이오 vs 전지 공방 외국인 매수 코스피 강세 코...
# 77779  코스피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 대표 박찬호 DDI 설계 도약 DB 글로벌 대표 박찬호 DDI 설계 도...
# 77781  인텔 파운드리 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체 수탁 생산 ...
#
#                                   제목_키워드_전처리후_Komoran_명사 GPT_Sentiment  \
# 0      코스닥 공시 유니 셈 테크 유니 셈 테크 안정 임대 수익 창출 펜타포트 토지 건물 ...           0.5
# 1      함대 건 순식간 총수 부재 함대 순식간 함대 총수 부재 독일 세계 가전 박람회 윤 ...          -1.0
# 2      LG유플러스 천안 역사 동아 라이 텐 홈 플랫폼 구축 LG유플러스 라이 천안 역사 ...           0.5
# 3      카메라 확대 수혜 기대 확대 카메라 수혜 유진 투자 증권 채택 카메라 수혜 설립 전...           1.0
# 4      삼성 노트 만원 고동진 노력 삼성 노트 고동진 노력 노트 삼성전자 갤럭시 노트 가격...           0.5
# ...                                                  ...           ...
# 77777  엔비디아 쇼크 회복 시도 코스 피 코스닥 시 총 위 엔비디아 쇼크 회복 시도 코스 ...           0.0
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 차 전지 공방 외국인 매수 코스 피 강...           0.5
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...           0.7
# 77780  글로벌 칩 대표 박찬호 설계 도약 글로벌 대표 박찬호 설계 도약 분사 반도체 기업 ...           0.5
# 77781  인텔 파운드리 힘 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수 탁 생...           1.0
#
#                                           Predicted_Text
# 0      삼성전자가 유니셈과의 반도체 장비 공급 계약 체결로 긍정적인 매출 기회를 얻었지만,...
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 2      이 뉴스는 LG유플러스의 IoT 플랫폼 구축과 관련된 내용으로, 삼성전자의 IoT ...
# 3      해성옵틱스의 듀얼 카메라 확대에 따른 삼성전자의 수혜 기대감이 높아져 주가 상승에 ...
# 4      삼성전자의 갤럭시 노트8 가격이 100만원을 웃돌 것으로 예상되며, 이는 소비자 심...
# ...                                                  ...
# 77777  현재 삼성전자의 주가는 외부 요인에 의해 혼조세를 보이고 있으며, 향후 10일간의 ...
# 77778  현재 외국인 매수와 코스피 강세가 긍정적인 신호를 주지만, 2차 전지와 바이오주 간...
# 77779  외국인 매수세가 강세를 보이며 삼성전자와 SK하이닉스의 주가가 소폭 반등하고 있어 ...
# 77780  이 텍스트는 DB글로벌칩의 경영진 변화와 반도체 설계 전문성을 강조하고 있어, 삼성...
# 77781  인텔의 파운드리 사업 축소와 구조조정은 삼성전자에게 긍정적인 기회를 제공할 것으로 ...
#
# [77782 rows x 29 columns]

# %%
df_bigkinds.columns
# Out:
# Index(['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2', '통합 분류3',
#        '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드',
#        '특성추출(가중치순 상위 50개)', '본문', 'URL', '분석제외 여부', '제목_키워드', '제목_키워드_전처리후',
#        '제목_키워드_전처리후_Okt', '제목_키워드_전처리후_Hannanum', '제목_키워드_전처리후_Kkma',
#        '제목_키워드_전처리후_Komoran', '제목_키워드_전처리후_kiwi', '제목_키워드_전처리후_Komoran_명사',
#        'GPT_Sentiment', 'Predicted_Text'],
#       dtype='object')

# %%
# 원하는 열만 선택하여 새로운 데이터프레임 생성
df_bigkinds = df_bigkinds[['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2','통합 분류3',
                           '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드',
                           '특성추출(가중치순 상위 50개)', '본문', 'URL', '분석제외 여부', '제목_키워드', '제목_키워드_전처리후',
                           'GPT_Sentiment', 'Predicted_Text']]

# %%
df_bigkinds
# Out:
#                            뉴스 식별자         일자   언론사  기고자  \
# 0      02100101.20170901161300001 2017-09-01  매일경제  NaN
# 1      02100101.20170901162741001 2017-09-01  매일경제  김동은
# 2      02100101.20170901160436001 2017-09-01  매일경제  박진형
# 3      02100101.20170901084332002 2017-09-01  매일경제  박진형
# 4      02100101.20170901134823001 2017-09-01  매일경제  박진형
# ...                           ...        ...   ...  ...
# 77777  02100601.20240830155007001 2024-08-30  한국경제  한경우
# 77778  02100601.20240830110414001 2024-08-30  한국경제  한경우
# 77779  02100601.20240830092005001 2024-08-30  한국경제  한경우
# 77780  02100601.20240830174157001 2024-08-30  한국경제  황정수
# 77781  02100601.20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                       기관  \
# 0                              코웰패션,유니셈,MDS테크,삼성전자,한컴MDS
# 1                                            최고경영진,경영위원회
# 2                    천안역사,애플,동아건설산업,LG유플러스,LG전자,삼성전자,IoT
# 3                                  유진투자증권,삼성전자,해성옵틱스,코스닥
# 4                                                    NaN
# ...                                                  ...
# 77777  POSCO홀딩스,삼성물산,기아,알테오젠,클래시스,삼성전자,엔비디아,코스피,SK하이닉...
# 77778  POSCO홀딩스,기아,엔비디아발,엔켐,알테오젠,에코프로보,클래시스,리노공업,삼성전자...
# 77779  기아,엔켐,스탠더드앤드푸어스,다우존스,삼성전자,유가증권,POSCO,에코프로,SK하이...
# 77780  노바텍,DB글로벌,물리학과,대전고,매그나칩반도체,DB하이텍,DB글로벌칩,파운드리,서...
# 77781                            TSMC,마이크로소프트,MS,삼성전자,삼성
#
#                                                      키워드  \
# 0      코웰패션,유니셈,MDS테크,코웰패션,안정적,임대,수익,창출,펜타포트,토지,건물,양수...
# 1      함대,순식간,함대,총수부재,참담,독일,세계가전,박람회,IFA,윤부근,삼성전자,대표,...
# 2      LG유플러스,라이크,천안역사,동아,라이크,구축,플랫폼,LG유플러스,동아건설산업,건설...
# 3      해성옵틱스,확대,듀얼,카메라,수혜,유진투자증권,해성옵틱스,채택,듀얼,카메라,수혜,설...
# 4      삼성,갤노트,100만,고동진,노력,노트8,삼성전자,갤럭시,노트,가격,출시,100만,...
# ...                                                  ...
# 77777  엔비디아,쇼크,회복,시도,코스피,HLB,3위,코스닥,시총,코스피,기관,매수,상승헀,...
# 77778  외국인,매수,코스피,강세,코스닥선,2차,바이오,vs,전지,공방,코스피,매수,외국인,...
# 77779  코스피,외국인,매수,강세,삼성전자,SK하이닉스,소폭,반등,코스피,외국인,매수세,강세...
# 77780  DB글로벌,대표,박찬호,DDI,설계,제2,도약,DB하이텍,분사,팹리스,반도체,기업,...
# 77781  인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수탁생산,사업,축소,분리,매...
#
#                                        특성추출(가중치순 상위 50개)  \
# 0      유니셈,매출액,코웰패션,한컴,mds,경영목적,펜타포트,삼성전자,55억,반도체,mds...
# 1      삼성전자,부회장,참담,사업구조,독일,간담회,윤부근,순식간,부재중,선단장,유럽,베를린...
# 2      iot,유플러스,라이크,천안역사,스마트폰,만큼,류창수,lg유플러스,lg,천안역,네트...
# 3      해성옵틱스,삼성전자,중국향,전문제조업체,스마트폰,기대감,코스닥,상승세,박종선,연구원...
# 4      100만,갤럭시,삼성전자,출고가,독일,미국,고동진,영국,부담감,스마트폰,노트8,ol...
# ...                                                  ...
# 77777  원어치,코스닥,시총,외국인,코스피,밸류업,순매도,매수세,현물주식,상승폭,3위,엔비디...
# 77778  코스닥,원어치,외국인,2차,코스피,알테오젠,대장주,현물주식,에코프로,3위,에코프로비...
# 77779  원어치,외국인,코스피,코스닥,혼조세,종목들,하이닉스,약보합세,약보합,삼성전자,반도체...
# 77780  삼성전자,반도체,ddi,db,db글로벌칩,관계자,박찬호,다이오드,서울대,매그나칩반도...
# 77781  파운드리,인텔,반도체,미국,삼성전자,삼성,구조조정,관계자,최고경영자,tsmc,대만,...
#
#                                                       본문  \
# 0      ◇코웰패션=안정적 임대수익 창출을 위해 펜타포트 토지 및 건물 500억원에 양수 결...
# 1      ◆ 독일 세계가전박람회(IFA 2017) / 윤부근 삼성전자 대표 심경토로 ◆ \n...
# 2      LG유플러스는 동아건설산업이 건설 공급하는 48층 규모의 초고층 주상복합아파트 '천...
# 3      유진투자증권은 1일 해성옵틱스에 대해 듀얼 카메라 채택이 많아지기에 수혜를 기대한다...
# 4      삼성전자 '갤럭시 노트8'의 국내 출시 가격이 100만원을 넘을 전망이다. 갤럭시S...
# ...                                                  ...
# 77777  코스피가 기관 매수에 힙입어 상승헀다. 다만 엔비디아의 2분기 실적에 대한 주식시장...
# 77778  코스피가 외국인 선물 매수에 힘입어 강세를 보이고 있다. 지난 29일의 엔비디아발(...
# 77779  코스피가 외국인 매수세에 강세를 보이고 있다. \n \n30일 오전 9시6분 현재 ...
# 77780  DB하이텍에서 분사한 팹리스(반도체 설계 전문 기업)인 DB글로벌칩은 삼성전자 출신...
# 77781  실적 부진으로 인해 구조조정에 나선 인텔이 파운드리(반도체 수탁생산) 사업을 축소하...
#
#                                                      URL 분석제외 여부  \
# 0      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 1      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 2      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 3      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 4      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# ...                                                  ...     ...
# 77777     https://www.hankyung.com/article/2024083072596     NaN
# 77778     https://www.hankyung.com/article/2024083065006     NaN
# 77779     https://www.hankyung.com/article/2024083060686     NaN
# 77780     https://www.hankyung.com/article/2024083076661     NaN
# 77781     https://www.hankyung.com/article/2024083076681     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후 GPT_Sentiment  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...           0.5
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...          -1.0
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...           0.5
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...           1.0
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...           0.5
# ...                                                  ...           ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...           0.0
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...           0.5
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...           0.7
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...           0.5
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...           1.0
#
#                                           Predicted_Text
# 0      삼성전자가 유니셈과의 반도체 장비 공급 계약 체결로 긍정적인 매출 기회를 얻었지만,...
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 2      이 뉴스는 LG유플러스의 IoT 플랫폼 구축과 관련된 내용으로, 삼성전자의 IoT ...
# 3      해성옵틱스의 듀얼 카메라 확대에 따른 삼성전자의 수혜 기대감이 높아져 주가 상승에 ...
# 4      삼성전자의 갤럭시 노트8 가격이 100만원을 웃돌 것으로 예상되며, 이는 소비자 심...
# ...                                                  ...
# 77777  현재 삼성전자의 주가는 외부 요인에 의해 혼조세를 보이고 있으며, 향후 10일간의 ...
# 77778  현재 외국인 매수와 코스피 강세가 긍정적인 신호를 주지만, 2차 전지와 바이오주 간...
# 77779  외국인 매수세가 강세를 보이며 삼성전자와 SK하이닉스의 주가가 소폭 반등하고 있어 ...
# 77780  이 텍스트는 DB글로벌칩의 경영진 변화와 반도체 설계 전문성을 강조하고 있어, 삼성...
# 77781  인텔의 파운드리 사업 축소와 구조조정은 삼성전자에게 긍정적인 기회를 제공할 것으로 ...
#
# [77782 rows x 23 columns]

# %%
df_bigkinds.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt.xlsx', index=False)

# %%
# 'Date' 열을 datetime 타입으로 변환
df_bigkinds.loc[:, '일자'] = pd.to_datetime(df_bigkinds['일자'])

# 날짜별로 'GPT_Sentiment'의 평균을 계산
df_bigkinds_grouped = df_bigkinds.groupby('일자')['GPT_Sentiment'].mean().reset_index()

# 그래프 시각화
plt.figure(figsize=(12, 6))
plt.plot(df_bigkinds_grouped['일자'], df_bigkinds_grouped['GPT_Sentiment'], marker='o', linestyle='-', color='b')
plt.title('Time Series of GPT Sentiment')
plt.xlabel('일자')
plt.ylabel('GPT Sentiment')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# 그래프 보여주기
plt.show()

# %%
df_bigkinds_avg = df_bigkinds.groupby('일자', as_index=False)['GPT_Sentiment'].mean()

# 결과 확인
df_bigkinds_avg
# Out:
#              일자  GPT_Sentiment
# 0    2017-09-01       0.422222
# 1    2017-09-02      -0.033333
# 2    2017-09-03       0.433333
# 3    2017-09-04       0.197500
# 4    2017-09-05       0.367647
# ...         ...            ...
# 2551 2024-08-26       0.319355
# 2552 2024-08-27       0.568966
# 2553 2024-08-28       0.465000
# 2554 2024-08-29      -0.031579
# 2555 2024-08-30       0.366667
#
# [2556 rows x 2 columns]

# %%
# 감정 분석 결과 저장(일자별)
df_bigkinds_avg.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt_daily.xlsx', index=False)

# %% [markdown]
# chatgpt의 경우 다시 평가하는 경우 비용발생하여 기존에 평가 데이터를 필터링하여 정상 데이터만 추출

# %%
# EXCEL파일 읽기
file_path = './Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt.xlsx'
df_bigkinds = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# %%
df_bigkinds
# Out:
#                            뉴스 식별자         일자   언론사  기고자  \
# 0      02100101.20170901161300001 2017-09-01  매일경제  NaN
# 1      02100101.20170901162741001 2017-09-01  매일경제  김동은
# 2      02100101.20170901160436001 2017-09-01  매일경제  박진형
# 3      02100101.20170901084332002 2017-09-01  매일경제  박진형
# 4      02100101.20170901134823001 2017-09-01  매일경제  박진형
# ...                           ...        ...   ...  ...
# 77777  02100601.20240830155007001 2024-08-30  한국경제  한경우
# 77778  02100601.20240830110414001 2024-08-30  한국경제  한경우
# 77779  02100601.20240830092005001 2024-08-30  한국경제  한경우
# 77780  02100601.20240830174157001 2024-08-30  한국경제  황정수
# 77781  02100601.20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                       기관  \
# 0                              코웰패션,유니셈,MDS테크,삼성전자,한컴MDS
# 1                                            최고경영진,경영위원회
# 2                    천안역사,애플,동아건설산업,LG유플러스,LG전자,삼성전자,IoT
# 3                                  유진투자증권,삼성전자,해성옵틱스,코스닥
# 4                                                    NaN
# ...                                                  ...
# 77777  POSCO홀딩스,삼성물산,기아,알테오젠,클래시스,삼성전자,엔비디아,코스피,SK하이닉...
# 77778  POSCO홀딩스,기아,엔비디아발,엔켐,알테오젠,에코프로보,클래시스,리노공업,삼성전자...
# 77779  기아,엔켐,스탠더드앤드푸어스,다우존스,삼성전자,유가증권,POSCO,에코프로,SK하이...
# 77780  노바텍,DB글로벌,물리학과,대전고,매그나칩반도체,DB하이텍,DB글로벌칩,파운드리,서...
# 77781                            TSMC,마이크로소프트,MS,삼성전자,삼성
#
#                                                      키워드  \
# 0      코웰패션,유니셈,MDS테크,코웰패션,안정적,임대,수익,창출,펜타포트,토지,건물,양수...
# 1      함대,순식간,함대,총수부재,참담,독일,세계가전,박람회,IFA,윤부근,삼성전자,대표,...
# 2      LG유플러스,라이크,천안역사,동아,라이크,구축,플랫폼,LG유플러스,동아건설산업,건설...
# 3      해성옵틱스,확대,듀얼,카메라,수혜,유진투자증권,해성옵틱스,채택,듀얼,카메라,수혜,설...
# 4      삼성,갤노트,100만,고동진,노력,노트8,삼성전자,갤럭시,노트,가격,출시,100만,...
# ...                                                  ...
# 77777  엔비디아,쇼크,회복,시도,코스피,HLB,3위,코스닥,시총,코스피,기관,매수,상승헀,...
# 77778  외국인,매수,코스피,강세,코스닥선,2차,바이오,vs,전지,공방,코스피,매수,외국인,...
# 77779  코스피,외국인,매수,강세,삼성전자,SK하이닉스,소폭,반등,코스피,외국인,매수세,강세...
# 77780  DB글로벌,대표,박찬호,DDI,설계,제2,도약,DB하이텍,분사,팹리스,반도체,기업,...
# 77781  인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수탁생산,사업,축소,분리,매...
#
#                                        특성추출(가중치순 상위 50개)  \
# 0      유니셈,매출액,코웰패션,한컴,mds,경영목적,펜타포트,삼성전자,55억,반도체,mds...
# 1      삼성전자,부회장,참담,사업구조,독일,간담회,윤부근,순식간,부재중,선단장,유럽,베를린...
# 2      iot,유플러스,라이크,천안역사,스마트폰,만큼,류창수,lg유플러스,lg,천안역,네트...
# 3      해성옵틱스,삼성전자,중국향,전문제조업체,스마트폰,기대감,코스닥,상승세,박종선,연구원...
# 4      100만,갤럭시,삼성전자,출고가,독일,미국,고동진,영국,부담감,스마트폰,노트8,ol...
# ...                                                  ...
# 77777  원어치,코스닥,시총,외국인,코스피,밸류업,순매도,매수세,현물주식,상승폭,3위,엔비디...
# 77778  코스닥,원어치,외국인,2차,코스피,알테오젠,대장주,현물주식,에코프로,3위,에코프로비...
# 77779  원어치,외국인,코스피,코스닥,혼조세,종목들,하이닉스,약보합세,약보합,삼성전자,반도체...
# 77780  삼성전자,반도체,ddi,db,db글로벌칩,관계자,박찬호,다이오드,서울대,매그나칩반도...
# 77781  파운드리,인텔,반도체,미국,삼성전자,삼성,구조조정,관계자,최고경영자,tsmc,대만,...
#
#                                                       본문  \
# 0      ◇코웰패션=안정적 임대수익 창출을 위해 펜타포트 토지 및 건물 500억원에 양수 결...
# 1      ◆ 독일 세계가전박람회(IFA 2017) / 윤부근 삼성전자 대표 심경토로 ◆ \n...
# 2      LG유플러스는 동아건설산업이 건설 공급하는 48층 규모의 초고층 주상복합아파트 '천...
# 3      유진투자증권은 1일 해성옵틱스에 대해 듀얼 카메라 채택이 많아지기에 수혜를 기대한다...
# 4      삼성전자 '갤럭시 노트8'의 국내 출시 가격이 100만원을 넘을 전망이다. 갤럭시S...
# ...                                                  ...
# 77777  코스피가 기관 매수에 힙입어 상승헀다. 다만 엔비디아의 2분기 실적에 대한 주식시장...
# 77778  코스피가 외국인 선물 매수에 힘입어 강세를 보이고 있다. 지난 29일의 엔비디아발(...
# 77779  코스피가 외국인 매수세에 강세를 보이고 있다. \n \n30일 오전 9시6분 현재 ...
# 77780  DB하이텍에서 분사한 팹리스(반도체 설계 전문 기업)인 DB글로벌칩은 삼성전자 출신...
# 77781  실적 부진으로 인해 구조조정에 나선 인텔이 파운드리(반도체 수탁생산) 사업을 축소하...
#
#                                                      URL 분석제외 여부  \
# 0      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 1      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 2      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 3      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 4      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# ...                                                  ...     ...
# 77777     https://www.hankyung.com/article/2024083072596     NaN
# 77778     https://www.hankyung.com/article/2024083065006     NaN
# 77779     https://www.hankyung.com/article/2024083060686     NaN
# 77780     https://www.hankyung.com/article/2024083076661     NaN
# 77781     https://www.hankyung.com/article/2024083076681     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후 GPT_Sentiment  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...           0.5
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...          -1.0
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...           0.5
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...           1.0
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...           0.5
# ...                                                  ...           ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...           0.0
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...           0.5
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...           0.7
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...           0.5
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...           1.0
#
#                                           Predicted_Text
# 0      삼성전자가 유니셈과의 반도체 장비 공급 계약 체결로 긍정적인 매출 기회를 얻었지만,...
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 2      이 뉴스는 LG유플러스의 IoT 플랫폼 구축과 관련된 내용으로, 삼성전자의 IoT ...
# 3      해성옵틱스의 듀얼 카메라 확대에 따른 삼성전자의 수혜 기대감이 높아져 주가 상승에 ...
# 4      삼성전자의 갤럭시 노트8 가격이 100만원을 웃돌 것으로 예상되며, 이는 소비자 심...
# ...                                                  ...
# 77777  현재 삼성전자의 주가는 외부 요인에 의해 혼조세를 보이고 있으며, 향후 10일간의 ...
# 77778  현재 외국인 매수와 코스피 강세가 긍정적인 신호를 주지만, 2차 전지와 바이오주 간...
# 77779  외국인 매수세가 강세를 보이며 삼성전자와 SK하이닉스의 주가가 소폭 반등하고 있어 ...
# 77780  이 텍스트는 DB글로벌칩의 경영진 변화와 반도체 설계 전문성을 강조하고 있어, 삼성...
# 77781  인텔의 파운드리 사업 축소와 구조조정은 삼성전자에게 긍정적인 기회를 제공할 것으로 ...
#
# [77782 rows x 23 columns]

# %%
# 뉴스 식별자 컬럼에서 '.' 이후의 값만 조회
df_bigkinds['뉴스 식별자'] = df_bigkinds['뉴스 식별자'].str.split('.').str[1]

# %% [markdown]
# 분석제외 대상과 중복건 제거

# %%
df_bigkinds = df_bigkinds[df_bigkinds['분석제외 여부'].isnull()]

# %%
df_bigkinds
# Out:
#                   뉴스 식별자         일자   언론사  기고자  \
# 0      20170901161300001 2017-09-01  매일경제  NaN
# 1      20170901162741001 2017-09-01  매일경제  김동은
# 2      20170901160436001 2017-09-01  매일경제  박진형
# 3      20170901084332002 2017-09-01  매일경제  박진형
# 4      20170901134823001 2017-09-01  매일경제  박진형
# ...                  ...        ...   ...  ...
# 77777  20240830155007001 2024-08-30  한국경제  한경우
# 77778  20240830110414001 2024-08-30  한국경제  한경우
# 77779  20240830092005001 2024-08-30  한국경제  한경우
# 77780  20240830174157001 2024-08-30  한국경제  황정수
# 77781  20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                       기관  \
# 0                              코웰패션,유니셈,MDS테크,삼성전자,한컴MDS
# 1                                            최고경영진,경영위원회
# 2                    천안역사,애플,동아건설산업,LG유플러스,LG전자,삼성전자,IoT
# 3                                  유진투자증권,삼성전자,해성옵틱스,코스닥
# 4                                                    NaN
# ...                                                  ...
# 77777  POSCO홀딩스,삼성물산,기아,알테오젠,클래시스,삼성전자,엔비디아,코스피,SK하이닉...
# 77778  POSCO홀딩스,기아,엔비디아발,엔켐,알테오젠,에코프로보,클래시스,리노공업,삼성전자...
# 77779  기아,엔켐,스탠더드앤드푸어스,다우존스,삼성전자,유가증권,POSCO,에코프로,SK하이...
# 77780  노바텍,DB글로벌,물리학과,대전고,매그나칩반도체,DB하이텍,DB글로벌칩,파운드리,서...
# 77781                            TSMC,마이크로소프트,MS,삼성전자,삼성
#
#                                                      키워드  \
# 0      코웰패션,유니셈,MDS테크,코웰패션,안정적,임대,수익,창출,펜타포트,토지,건물,양수...
# 1      함대,순식간,함대,총수부재,참담,독일,세계가전,박람회,IFA,윤부근,삼성전자,대표,...
# 2      LG유플러스,라이크,천안역사,동아,라이크,구축,플랫폼,LG유플러스,동아건설산업,건설...
# 3      해성옵틱스,확대,듀얼,카메라,수혜,유진투자증권,해성옵틱스,채택,듀얼,카메라,수혜,설...
# 4      삼성,갤노트,100만,고동진,노력,노트8,삼성전자,갤럭시,노트,가격,출시,100만,...
# ...                                                  ...
# 77777  엔비디아,쇼크,회복,시도,코스피,HLB,3위,코스닥,시총,코스피,기관,매수,상승헀,...
# 77778  외국인,매수,코스피,강세,코스닥선,2차,바이오,vs,전지,공방,코스피,매수,외국인,...
# 77779  코스피,외국인,매수,강세,삼성전자,SK하이닉스,소폭,반등,코스피,외국인,매수세,강세...
# 77780  DB글로벌,대표,박찬호,DDI,설계,제2,도약,DB하이텍,분사,팹리스,반도체,기업,...
# 77781  인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수탁생산,사업,축소,분리,매...
#
#                                        특성추출(가중치순 상위 50개)  \
# 0      유니셈,매출액,코웰패션,한컴,mds,경영목적,펜타포트,삼성전자,55억,반도체,mds...
# 1      삼성전자,부회장,참담,사업구조,독일,간담회,윤부근,순식간,부재중,선단장,유럽,베를린...
# 2      iot,유플러스,라이크,천안역사,스마트폰,만큼,류창수,lg유플러스,lg,천안역,네트...
# 3      해성옵틱스,삼성전자,중국향,전문제조업체,스마트폰,기대감,코스닥,상승세,박종선,연구원...
# 4      100만,갤럭시,삼성전자,출고가,독일,미국,고동진,영국,부담감,스마트폰,노트8,ol...
# ...                                                  ...
# 77777  원어치,코스닥,시총,외국인,코스피,밸류업,순매도,매수세,현물주식,상승폭,3위,엔비디...
# 77778  코스닥,원어치,외국인,2차,코스피,알테오젠,대장주,현물주식,에코프로,3위,에코프로비...
# 77779  원어치,외국인,코스피,코스닥,혼조세,종목들,하이닉스,약보합세,약보합,삼성전자,반도체...
# 77780  삼성전자,반도체,ddi,db,db글로벌칩,관계자,박찬호,다이오드,서울대,매그나칩반도...
# 77781  파운드리,인텔,반도체,미국,삼성전자,삼성,구조조정,관계자,최고경영자,tsmc,대만,...
#
#                                                       본문  \
# 0      ◇코웰패션=안정적 임대수익 창출을 위해 펜타포트 토지 및 건물 500억원에 양수 결...
# 1      ◆ 독일 세계가전박람회(IFA 2017) / 윤부근 삼성전자 대표 심경토로 ◆ \n...
# 2      LG유플러스는 동아건설산업이 건설 공급하는 48층 규모의 초고층 주상복합아파트 '천...
# 3      유진투자증권은 1일 해성옵틱스에 대해 듀얼 카메라 채택이 많아지기에 수혜를 기대한다...
# 4      삼성전자 '갤럭시 노트8'의 국내 출시 가격이 100만원을 넘을 전망이다. 갤럭시S...
# ...                                                  ...
# 77777  코스피가 기관 매수에 힙입어 상승헀다. 다만 엔비디아의 2분기 실적에 대한 주식시장...
# 77778  코스피가 외국인 선물 매수에 힘입어 강세를 보이고 있다. 지난 29일의 엔비디아발(...
# 77779  코스피가 외국인 매수세에 강세를 보이고 있다. \n \n30일 오전 9시6분 현재 ...
# 77780  DB하이텍에서 분사한 팹리스(반도체 설계 전문 기업)인 DB글로벌칩은 삼성전자 출신...
# 77781  실적 부진으로 인해 구조조정에 나선 인텔이 파운드리(반도체 수탁생산) 사업을 축소하...
#
#                                                      URL 분석제외 여부  \
# 0      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 1      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 2      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 3      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 4      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# ...                                                  ...     ...
# 77777     https://www.hankyung.com/article/2024083072596     NaN
# 77778     https://www.hankyung.com/article/2024083065006     NaN
# 77779     https://www.hankyung.com/article/2024083060686     NaN
# 77780     https://www.hankyung.com/article/2024083076661     NaN
# 77781     https://www.hankyung.com/article/2024083076681     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후 GPT_Sentiment  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...           0.5
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...          -1.0
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...           0.5
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...           1.0
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...           0.5
# ...                                                  ...           ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...           0.0
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...           0.5
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...           0.7
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...           0.5
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...           1.0
#
#                                           Predicted_Text
# 0      삼성전자가 유니셈과의 반도체 장비 공급 계약 체결로 긍정적인 매출 기회를 얻었지만,...
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 2      이 뉴스는 LG유플러스의 IoT 플랫폼 구축과 관련된 내용으로, 삼성전자의 IoT ...
# 3      해성옵틱스의 듀얼 카메라 확대에 따른 삼성전자의 수혜 기대감이 높아져 주가 상승에 ...
# 4      삼성전자의 갤럭시 노트8 가격이 100만원을 웃돌 것으로 예상되며, 이는 소비자 심...
# ...                                                  ...
# 77777  현재 삼성전자의 주가는 외부 요인에 의해 혼조세를 보이고 있으며, 향후 10일간의 ...
# 77778  현재 외국인 매수와 코스피 강세가 긍정적인 신호를 주지만, 2차 전지와 바이오주 간...
# 77779  외국인 매수세가 강세를 보이며 삼성전자와 SK하이닉스의 주가가 소폭 반등하고 있어 ...
# 77780  이 텍스트는 DB글로벌칩의 경영진 변화와 반도체 설계 전문성을 강조하고 있어, 삼성...
# 77781  인텔의 파운드리 사업 축소와 구조조정은 삼성전자에게 긍정적인 기회를 제공할 것으로 ...
#
# [73266 rows x 23 columns]

# %% [markdown]
# 뉴스 식별자 최소값 기준으로 제목_키워드_전처리후 그룹핑

# %%
# 그룹핑할 컬럼 리스트
group_columns = ['제목_키워드_전처리후']

# 각 그룹에서 뉴스 식별자 컬럼의 최소값을 유지
df_bigkinds2 = df_bigkinds.groupby(group_columns, as_index=False).agg({'뉴스 식별자': 'min'})

# %%
df_bigkinds2
# Out:
#                                              제목_키워드_전처리후             뉴스 식별자
# 0      - 관계 개선 수혜 강세 화장품 여행 매수 기회 테마 섹터 수혜 개선 강세 화장품 ...  20171129112950001
# 1      - 기업 줄세우기 현실화 반도체 하반기 회복도 살얼음 기업 현실화 반도체 회복 살얼...  20190606173205001
# 2      - 기업 협력 가교 1사1병영 113곳 첨단 강군 육성 힘 모은다 기업 협력 가교 ...  20190926173022001
# 3      - 무역전쟁 에 중국 반도체 위험소식.. 그러나.. 반등 예상되는 국내 수혜주 살펴...  20190424163713001
# 4      - 무역전쟁 장기화될수록 반도체에 관심을 가져야 한다 국내 수혜주 Top 1 무역전...  20190425170957001
# ...                                                  ...                ...
# 71106  힘실리는 반도체 바닥론...삼성전자 하이닉스 강세 반도체 바닥 삼성전자 하이닉스 강...  20190321171650001
# 71107  힘쎈충남 출범 6개월만 정부예산 9조원 시대 개막 등 성과 올렸다 힘쎈충남 출범 정...  20230622192729001
# 71108  힘잃은 증시 외부 만 쳐다본다 증시 외부 속도조절 파월 긴축 속도 조절 신호에 연초...  20190106175544001
# 71109  힘찬건설 삼성 LG 배후수요 탄탄 고덕 헤리움 시그니어 8월 분양 건설 삼성 LG ...  20200727120638001
# 71110  힙합 아티스트들이 주목한 소셜엔터 플랫폼이 있다 Geeks Briefing 힙합 아...  20221102205645001
#
# [71111 rows x 2 columns]

# %%
# 필요한 컬럼만 선택하여 두 데이터프레임 병합
big_kinds_sentiment = pd.merge(
    df_bigkinds[['제목_키워드_전처리후', '뉴스 식별자','일자','GPT_Sentiment','Predicted_Text']],
    df_bigkinds2[['제목_키워드_전처리후', '뉴스 식별자']],
    on=['제목_키워드_전처리후', '뉴스 식별자'],
    how='inner'
)

big_kinds_sentiment = big_kinds_sentiment[['뉴스 식별자', '일자', '제목_키워드_전처리후', 'GPT_Sentiment', 'Predicted_Text']]
big_kinds_sentiment
# Out:
#                   뉴스 식별자         일자  \
# 0      20170901161300001 2017-09-01
# 1      20170901162741001 2017-09-01
# 2      20170901160436001 2017-09-01
# 3      20170901084332002 2017-09-01
# 4      20170901134823001 2017-09-01
# ...                  ...        ...
# 71106  20240830155007001 2024-08-30
# 71107  20240830110414001 2024-08-30
# 71108  20240830092005001 2024-08-30
# 71109  20240830174157001 2024-08-30
# 71110  20240830174248001 2024-08-30
#
#                                              제목_키워드_전처리후  GPT_Sentiment  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...            0.5
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...           -1.0
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...            0.5
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...            1.0
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...            0.5
# ...                                                  ...            ...
# 71106  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...            0.0
# 71107  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...            0.5
# 71108  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...            0.7
# 71109  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...            0.5
# 71110  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...            1.0
#
#                                           Predicted_Text
# 0      삼성전자가 유니셈과의 반도체 장비 공급 계약 체결로 긍정적인 매출 기회를 얻었지만,...
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 2      이 뉴스는 LG유플러스의 IoT 플랫폼 구축과 관련된 내용으로, 삼성전자의 IoT ...
# 3      해성옵틱스의 듀얼 카메라 확대에 따른 삼성전자의 수혜 기대감이 높아져 주가 상승에 ...
# 4      삼성전자의 갤럭시 노트8 가격이 100만원을 웃돌 것으로 예상되며, 이는 소비자 심...
# ...                                                  ...
# 71106  현재 삼성전자의 주가는 외부 요인에 의해 혼조세를 보이고 있으며, 향후 10일간의 ...
# 71107  현재 외국인 매수와 코스피 강세가 긍정적인 신호를 주지만, 2차 전지와 바이오주 간...
# 71108  외국인 매수세가 강세를 보이며 삼성전자와 SK하이닉스의 주가가 소폭 반등하고 있어 ...
# 71109  이 텍스트는 DB글로벌칩의 경영진 변화와 반도체 설계 전문성을 강조하고 있어, 삼성...
# 71110  인텔의 파운드리 사업 축소와 구조조정은 삼성전자에게 긍정적인 기회를 제공할 것으로 ...
#
# [71111 rows x 5 columns]

# %%
big_kinds_sentiment.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt_filter.xlsx', index=False)

# %%
big_kinds_sentiment_avg = big_kinds_sentiment.groupby('일자', as_index=False)['GPT_Sentiment'].mean()
# 소수점 1자리로 반올림
big_kinds_sentiment_avg['GPT_Sentiment'] = big_kinds_sentiment_avg['GPT_Sentiment'].round(1)
big_kinds_sentiment_avg['GPT_Sentiment'] = big_kinds_sentiment_avg['GPT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
big_kinds_sentiment_avg
# Out:
#              일자  GPT_Sentiment
# 0    2017-09-01            0.4
# 1    2017-09-02            0.0
# 2    2017-09-03            0.4
# 3    2017-09-04            0.2
# 4    2017-09-05            0.4
# ...         ...            ...
# 2544 2024-08-26            0.3
# 2545 2024-08-27            0.6
# 2546 2024-08-28            0.4
# 2547 2024-08-29            0.0
# 2548 2024-08-30            0.4
#
# [2549 rows x 2 columns]

# %%
# 감정 분석 결과 저장(일자별)
big_kinds_sentiment_avg.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt_daily_filter.xlsx', index=False)

# %%
df_bigkinds_economy = pd.read_excel('./Text_Data/bigkinds/삼성전자_국제_20170901-20240830_전처리후_원본_chatgpt_filter.xlsx')

# %%
df_bigkinds_economy
# Out:
#                  뉴스 식별자         일자  \
# 0     20170901163910001 2017-09-01
# 1     20170901174354001 2017-09-01
# 2     20170901181209001 2017-09-01
# 3     20170901141935001 2017-09-01
# 4     20170901153936001 2017-09-01
# ...                 ...        ...
# 3556  20240819060124001 2024-08-19
# 3557  20240820150930001 2024-08-20
# 3558  20240821175511003 2024-08-21
# 3559  20240822002505001 2024-08-22
# 3560  20240825142511001 2024-08-25
#
#                                             제목_키워드_전처리후  GPT_Sentiment  \
# 0     이재용 항소심 서울고법 형사 13부에 배당 이달중 첫 기일 이재용 항소심 13부 서...            0.0
# 1     최순실게이트 청문회 불출석 11인 중 8명 백수 불출석 최순실게이트 청문회 백수 문...            0.0
# 2     삼성 뇌물 이재용 항소심 신설 형사13부 배당 삼성 뇌물 신설 이재용 항소심 형사 ...           -1.0
# 3     두문불출 10개월만에 문고리 실세 이재만 안봉근 법정 나와 청문회불출석 인정 두문불...            0.0
# 4     청문회 불출석 혐의 건강상태-절차적 하자로 무죄 주장 혐의 청문회 건강상태 절차적 ...            0.0
# ...                                                 ...            ...
# 3556  퇴직금 두둑히 챙겨 퇴사 벌써 옛말 은행 안 떠나는 은행원 퇴직금 퇴사 옛말 은행 ...            0.0
# 3557  대기업도 고령화 임직원 구성에서 50세 이상이 20대 역전 대기업 고령화 임직원 구...            0.0
# 3558  의족 차고 자전거 국토횡단에 감동 뭉클 의족 자전거 국토횡단 감동 뭉클 왼쪽 다리 ...            1.0
# 3559  자전거 국토 횡단에 650만명이 울었다 ...이 선수 보자마자 뭉클 횡단 자전거 국...            0.5
# 3560  부산국제마케팅광고제 올해 그랑프리 수상작 발표 부산국제마케팅광고제 그랑프리 수상작 ...            0.0
#
#                                          Predicted_Text
# 0     이재용 부회장의 항소심이 진행 중인 상황은 불확실성을 동반하며, 삼성전자의 주가에 ...
# 1     이 사건은 삼성전자와 관련된 뇌물 사건이지만, 현재로서는 주가에 미치는 영향이 불확...
# 2     이재용 부회장의 뇌물 공여 혐의와 관련된 항소심 소식은 삼성전자의 주가에 부정적인 ...
# 3     이 텍스트는 삼성전자와 관련된 직접적인 정보가 부족하여 주가에 미치는 영향이 불확실...
# 4        현재 상황은 불확실하며, 삼성전자의 주가에 미치는 영향은 제한적일 것으로 보입니다.
# ...                                                 ...
# 3556  이 텍스트는 은행권의 희망퇴직과 관련된 내용으로, 삼성전자의 주가에 직접적인 영향을...
# 3557  이 텍스트는 삼성전자의 고령화 임직원 구성 변화에 대한 정보로, 주가에 미치는 영향...
# 3558  이 텍스트는 삼성전자의 갤럭시워치 울트라 출시와 관련된 긍정적인 감정과 도전 정신을...
# 3559  이 텍스트는 삼성전자의 갤럭시 스마트 시계와 관련된 긍정적인 마케팅 캠페인을 언급하...
# 3560  이 텍스트는 삼성전자의 주가에 중립적인 영향을 미칠 것으로 보이며, 특별한 긍정적 ...
#
# [3561 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_bigkinds_economy['일자'] = pd.to_datetime(df_bigkinds_economy['일자'])

sentiment_by_date = df_bigkinds_economy.groupby('일자')['GPT_Sentiment'].mean()

plt.figure(figsize=(10, 5))
plt.plot(sentiment_by_date.index, sentiment_by_date.values, marker='o', linestyle='-', color='b')

# 그래프 제목 및 라벨 설정
plt.title('일자별 경제-GPT 감정 점수 분포')
plt.xlabel('일자')
plt.ylabel('평균 감정 점수')
plt.grid(True)
plt.show()

# %%
df_bigkinds_economy_fl = df_bigkinds_economy[df_bigkinds_economy['Predicted_Text'].str.contains('불안') |
                                             df_bigkinds_economy['Predicted_Text'].str.contains('안정')]

# %%
df_bigkinds_economy_fl
# Out:
#                   뉴스 식별자         일자  \
# 1      20170901162741001 2017-09-01
# 24     20170901155455001 2017-09-01
# 30     20170901140647001 2017-09-01
# 40     20170901175324003 2017-09-02
# 74     20170904094928001 2017-09-04
# ...                  ...        ...
# 70815  20240818172623001 2024-08-18
# 70915  20240822175342001 2024-08-22
# 70941  20240823060218001 2024-08-23
# 71077  20240829155800001 2024-08-29
# 71099  20240830173848001 2024-08-30
#
#                                              제목_키워드_전처리후  GPT_Sentiment  \
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...           -1.0
# 24     윤부근 삼성 사장 선단장 없는 배 잠도 못 자고 참 무섭다 윤부근 삼성 사장 선단장...           -0.7
# 30     윤부근 삼성 사장 선단장 없는 배 무섭고 두렵다 윤부근 삼성 사장 선단장 사장 삼성...           -1.0
# 40     윤부근 선단장 없는 삼성 답답하고 두렵고 참담 윤부근 선단장 삼성 참담 선단장 일개...           -0.7
# 74     오전시황 북핵 쇼크 과거보다 컸다...개인 팔고 외국인 기관 사고 과거 쇼크 개인 ...           -0.8
# ...                                                  ...            ...
# 70815  퇴직금 쪼그라들고 재취업 한파 4대 희망퇴직 25% 줄었다 퇴직금 한파 4대 희망 ...            0.0
# 70915  폭락장 이후 안전벨트 매는 기관 금융 배당주 매집 폭락장 안전벨트 기관 금융 배당주...            0.5
# 70941  기관 폭락장 이후 경기방어 로 피신 금융 배당주 매집 기관 폭락장 경기방어 피신 금...            0.5
# 71077  충북도 JSR마이크로코리아 투자유치 성공 충북도 성공 JSR 마이크로코리아 투자 유...            1.0
# 71099  외국인 자금 2.8조 이탈에 9월도 불안 멀어지는 역대 최대 바이코리아 2.8 외국...           -0.7
#
#                                           Predicted_Text
# 1      삼성전자의 경영진 부재와 불안감이 지속되면서 기업의 미래 전략과 투자에 대한 신뢰가...
# 24     현재 삼성전자의 경영 불안과 총수 부재로 인해 향후 주가에 부정적인 영향을 미칠 것...
# 30     이 기사는 삼성전자의 경영 불안과 리더십 공백을 강조하고 있어, 주가에 부정적인 영...
# 40     이 텍스트는 삼성전자의 내부 불안감과 경영 위기를 강조하고 있어, 주가에 부정적인 ...
# 74     북한의 핵실험과 관련된 불안감으로 인해 코스피가 급락하고 있으며, 이는 삼성전자의 ...
# ...                                                  ...
# 70815  이 텍스트는 금융권의 불안정성과 퇴직금 축소에 대한 우려를 나타내며, 이는 삼성전자...
# 70915  현재 기관 투자자들이 배당주를 매집하고 있는 상황은 삼성전자의 주가에 긍정적인 영향...
# 70941  현재 금융 업종의 배당주 매집과 기관투자가들의 주주 환원 계획이 긍정적인 신호를 주...
# 71077  이 투자 유치는 삼성전자의 반도체 생산에 필요한 핵심 소재의 안정적 공급을 보장하여...
# 71099  외국인 자금 이탈과 경기 불안으로 인해 삼성전자의 주가는 단기적으로 부정적인 영향을...
#
# [2177 rows x 5 columns]

# %%
df_bigkinds_economy_fl_avg = df_bigkinds_economy_fl.groupby('일자', as_index=False)['GPT_Sentiment'].mean()
# 소수점 1자리로 반올림
df_bigkinds_economy_fl_avg['GPT_Sentiment'] = df_bigkinds_economy_fl_avg['GPT_Sentiment'].round(1)
df_bigkinds_economy_fl_avg['GPT_Sentiment'] = df_bigkinds_economy_fl_avg['GPT_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
df_bigkinds_economy_fl_avg
# Out:
#              일자  GPT_Sentiment
# 0    2017-09-01           -0.9
# 1    2017-09-02           -0.7
# 2    2017-09-04           -0.8
# 3    2017-09-05            0.2
# 4    2017-09-06           -0.2
# ...         ...            ...
# 1241 2024-08-18            0.0
# 1242 2024-08-22            0.5
# 1243 2024-08-23            0.5
# 1244 2024-08-29            1.0
# 1245 2024-08-30           -0.7
#
# [1246 rows x 2 columns]

# %%
# 감정 분석 결과 저장(일자별)
df_bigkinds_economy_fl_avg.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_원본_chatgpt_daily_손익_filter.xlsx', index=False)
