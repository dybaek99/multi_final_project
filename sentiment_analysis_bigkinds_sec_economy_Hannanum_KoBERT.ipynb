# %%
import pandas as pd
import torch
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
from torch.nn import CrossEntropyLoss
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
import matplotlib.pyplot as plt
from kobert_transformers import get_kobert_model
from kobert_transformers.tokenization_kobert import KoBertTokenizer
import numpy as np
import time
from matplotlib import rcParams
# 한글 폰트 설정
rcParams['font.family'] = 'Malgun Gothic'  # 맑은 고딕으로 설정
rcParams['axes.unicode_minus'] = False     # 음수 기호 문제 해결

# %%
df_bigkinds = pd.read_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후.xlsx', converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

# %%
df_bigkinds
# Out:
#                            뉴스 식별자         일자   언론사  기고자  \
# 0      02100101.20170901161300001 2017-09-01  매일경제  NaN
# 1      02100101.20170901162741001 2017-09-01  매일경제  김동은
# 2      02100101.20170901160436001 2017-09-01  매일경제  박진형
# 3      02100101.20170901084332002 2017-09-01  매일경제  박진형
# 4      02100101.20170901134823001 2017-09-01  매일경제  박진형
# ...                           ...        ...   ...  ...
# 77777  02100601.20240830155007001 2024-08-30  한국경제  한경우
# 77778  02100601.20240830110414001 2024-08-30  한국경제  한경우
# 77779  02100601.20240830092005001 2024-08-30  한국경제  한경우
# 77780  02100601.20240830174157001 2024-08-30  한국경제  황정수
# 77781  02100601.20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ...  \
# 0           경제>유통       NaN       NaN  ...
# 1             NaN       NaN       NaN  ...
# 2           경제>유통       NaN       NaN  ...
# 3             NaN       NaN       NaN  ...
# 4           경제>유통       NaN       NaN  ...
# ...           ...       ...       ...  ...
# 77777       경제>유통       NaN       NaN  ...
# 77778    경제>산업_기업       NaN       NaN  ...
# 77779      경제>부동산       NaN       NaN  ...
# 77780   IT_과학>모바일       NaN       NaN  ...
# 77781         NaN       NaN       NaN  ...
#
#                                                      URL 분석제외 여부  \
# 0      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 1      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 2      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 3      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# 4      http://news.mk.co.kr/newsRead.php?year=2017&no...     NaN
# ...                                                  ...     ...
# 77777     https://www.hankyung.com/article/2024083072596     NaN
# 77778     https://www.hankyung.com/article/2024083065006     NaN
# 77779     https://www.hankyung.com/article/2024083060686     NaN
# 77780     https://www.hankyung.com/article/2024083076661     NaN
# 77781     https://www.hankyung.com/article/2024083076681     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                          제목_키워드_전처리후_Okt  \
# 0      코스닥 공시 코웰 패션 유니 셈 MDS 테크 코웰 패션 유니 셈 MDS 테크 코웰 ...
# 1      함대 가라앉는건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계...
# 2      LG 유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG 유플러스 라...
# 3      Hot - Line 해성 옵 틱 스 듀얼 카메라 확대 따른 수혜 기대 해성 옵 틱 ...
# 4      삼성 갤 노트 8 100만원 웃 돌듯 고동진 낮추려 노력 했지만 어려워 삼성 갤 노...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 한 코스피 HLB 코스닥 시 총 3 위 올라 엔비디아 ...
# 77778  외국인 매수 코스피 강세 코스닥 선 바이오 vs 2 차전지 공 방 외국인 매수 코스...
# 77779  코스피 외국인 매수 강세 삼성 SK 하이닉스 소 폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                     제목_키워드_전처리후_Hannanum  \
# 0      코스닥 공시 코웰패션 유니셈 MDS 테크 코웰패션 유니셈 MDS 테크 코웰패션 안정...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독 ㄹ 세계가...
# 2      LG유플러스 천안역사 동아 라이크 텐 홈IoT 플랫폼 구축 LG유플러스 라이크 천안...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 갤노트8 100만원 웃돌 듯 고동진 낮추 려 노력 었지만 어렵 삼성 갤노트 1...
# ...                                                  ...
# 77777  엔비디 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 오르 엔비디아 쇼크 회...
# 77778  외국 ㄴ 매수 코스피 강세 코스닥 선 바 vs 2차전지 공방 외국 ㄴ 매수 코스피 ...
# 77779  코스피 외국 ㄴ 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국 ㄴ 매수 강...
# 77780  DB 글로벌칩 대표 박찬호 DDI 설계 제2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드 리 힘 빼 ㄴ다 인텔 파운드 리 실적 부진 구조조정 인텔 파운드 리 반...
#
#                                         제목_키워드_전처리후_Kkma  \
# 0      코스닥 공시 코 웨 ㄹ 패션 유니 셈 MDS 테크 코 웨 ㄹ 패션 유니 셈 MDS ...
# 1      함대 가라앉 는 은 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG 유 플러스 천안 역사 동아 라이크 터 ㄴ 홈 IoT 플랫폼 구축 LG 유 플러...
# 3      Hot-Line 해성 옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성 옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만 원 웃돌 듯 고동진 낮추 려 노력 었 어렵 삼성 개...
# ...                                                  ...
# 77777  엔 비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 올르 엔 비...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK 하이닉스 소폭 반등 코스 피 외국인 매수 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체...
#
#                                      제목_키워드_전처리후_Komoran  \
# 0      코스닥 공시 코웰패션 유니 셈 MDS 테크 코웰패션 유니 셈 MDS 테크 코웰패션 ...
# 1      함대 가라앉 는 건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG유플러스 라이 ...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만원 웃돌 듯 고동진 낮추 려 노력 았 어렵 삼성 개 ...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 오르 엔비디아...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 ...
#
#                                         제목_키워드_전처리후_kiwi  \
# 0      코스닥 공시 코웰 패션 유니셈 MDS 테크 코웰 패션 유니셈 MDS 테크 코웰 패션...
# 1      함대 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계 가전 박람...
# 2      LG유플러스 천안 역사 동아 라이크 IoT 플랫폼 구축 LG유플러스 라이크 천안 역...
# 3      Hot Line 해성옵틱스 듀얼 카메라 확대 수혜 기대 해성옵틱스 확대 듀얼 카메라...
# 4      삼성 갤노트8 100 고동진 노력 어렵 삼성 노트 100 고동진 노력 노트 삼성전자...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스피 HLB 코스닥 엔비디아 쇼크 회복 시도 코스피 HL...
# 77778  외국인 매수 코스피 강세 코스닥 바이오 vs 전지 공방 외국인 매수 코스피 강세 코...
# 77779  코스피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 대표 박찬호 DDI 설계 도약 DB 글로벌 대표 박찬호 DDI 설계 도...
# 77781  인텔 파운드리 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체 수탁 생산 ...
#
#                                   제목_키워드_전처리후_Komoran_명사
# 0      코스닥 공시 유니 셈 테크 유니 셈 테크 안정 임대 수익 창출 펜타포트 토지 건물 ...
# 1      함대 건 순식간 총수 부재 함대 순식간 함대 총수 부재 독일 세계 가전 박람회 윤 ...
# 2      LG유플러스 천안 역사 동아 라이 텐 홈 플랫폼 구축 LG유플러스 라이 천안 역사 ...
# 3      카메라 확대 수혜 기대 확대 카메라 수혜 유진 투자 증권 채택 카메라 수혜 설립 전...
# 4      삼성 노트 만원 고동진 노력 삼성 노트 고동진 노력 노트 삼성전자 갤럭시 노트 가격...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스 피 코스닥 시 총 위 엔비디아 쇼크 회복 시도 코스 ...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 차 전지 공방 외국인 매수 코스 피 강...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  글로벌 칩 대표 박찬호 설계 도약 글로벌 대표 박찬호 설계 도약 분사 반도체 기업 ...
# 77781  인텔 파운드리 힘 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수 탁 생...
#
# [77782 rows x 27 columns]

# %%
# KoBERT 모델 및 토크나이저 로드
tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
model = get_kobert_model()

# %%
# 감정 분석을 위한 회귀 레이어 추가
class KoBERTSentimentRegressor(nn.Module):
    def __init__(self, base_model, output_size=1):  # output_size를 1로 설정
        super(KoBERTSentimentRegressor, self).__init__()
        self.base_model = base_model
        self.regressor = nn.Linear(base_model.config.hidden_size, output_size)  # 연속적인 출력값을 위한 선형 레이어
    
    def forward(self, input_ids, attention_mask):
        outputs = self.base_model(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output  # [CLS] 토큰의 출력
        return self.regressor(pooled_output)

# 감정 분석 모델 생성
regressor = KoBERTSentimentRegressor(model)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
regressor.to(device)
# Out:
# KoBERTSentimentRegressor(
#   (base_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (regressor): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
# 데이터셋 클래스 정의
class SentimentDataset(Dataset):
    def __init__(self, texts, tokenizer, max_len):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        
        input_ids = encoding['input_ids'].squeeze(0)
        attention_mask = encoding['attention_mask'].squeeze(0)
        
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask
        }

# 데이터셋 준비
MAX_LEN = 64  # 최대 토큰 길이 설정
dataset = SentimentDataset(df_bigkinds['제목_키워드_전처리후_Hannanum'].values, tokenizer, MAX_LEN)
data_loader = DataLoader(dataset, batch_size=16)

# %%
# 감정 분석 예측 함수
def predict_sentiments(model, data_loader, device):
    model.eval()
    predictions = []
    
    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            sentiment_scores = model(input_ids=input_ids, attention_mask=attention_mask)
            scores = sentiment_scores.cpu().numpy().flatten()
            # -1 ~ 1 범위로 클리핑
            scores = np.clip(scores, -1, 1)
            predictions.extend(scores)
    
    return predictions

# 감정 분석 수행
s = time.time()
predicted_scores = predict_sentiments(regressor, data_loader, device)
print("Prediction Time: ", time.time()-s)
# Out:
# C:\Users\dybae\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:439: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Prediction Time:  447.4034514427185

# %%
# 뉴스 식별자 컬럼에서 '.' 이후의 값만 조회
df_bigkinds['뉴스 식별자'] = df_bigkinds['뉴스 식별자'].str.split('.').str[1]

# %%
# 데이터프레임에 결과 추가
df_bigkinds['Bert_Sentiment'] = predicted_scores
# 소수점 1자리로 반올림
df_bigkinds['Bert_Sentiment'] = df_bigkinds['Bert_Sentiment'].round(1)
df_bigkinds['Bert_Sentiment'] = df_bigkinds['Bert_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
df_bigkinds
# Out:
#                   뉴스 식별자         일자   언론사  기고자  \
# 0      20170901161300001 2017-09-01  매일경제  NaN
# 1      20170901162741001 2017-09-01  매일경제  김동은
# 2      20170901160436001 2017-09-01  매일경제  박진형
# 3      20170901084332002 2017-09-01  매일경제  박진형
# 4      20170901134823001 2017-09-01  매일경제  박진형
# ...                  ...        ...   ...  ...
# 77777  20240830155007001 2024-08-30  한국경제  한경우
# 77778  20240830110414001 2024-08-30  한국경제  한경우
# 77779  20240830092005001 2024-08-30  한국경제  한경우
# 77780  20240830174157001 2024-08-30  한국경제  황정수
# 77781  20240830174248001 2024-08-30  한국경제  황정수
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                  [코스닥 공시] 코웰패션 / 유니셈 / MDS테크     경제>부동산      경제>반도체
# 1                       "함대 가라앉는건 순식간 총수부재 참담"     경제>반도체         NaN
# 2         LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축  IT_과학>모바일      경제>부동산
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대"   경제>증권_증시   IT_과학>모바일
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워"  IT_과학>모바일    경제>산업_기업
# ...                                        ...        ...         ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라   경제>증권_증시      경제>부동산
# 77778     외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방   경제>증권_증시      경제>부동산
# 77779        코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등   경제>증권_증시    경제>산업_기업
# 77780          DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약"     경제>반도체    IT_과학>과학
# 77781                            인텔, 파운드리 힘 뺀다     경제>반도체       경제>유통
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2  ... 분석제외 여부  \
# 0           경제>유통       NaN       NaN  ...     NaN
# 1             NaN       NaN       NaN  ...     NaN
# 2           경제>유통       NaN       NaN  ...     NaN
# 3             NaN       NaN       NaN  ...     NaN
# 4           경제>유통       NaN       NaN  ...     NaN
# ...           ...       ...       ...  ...     ...
# 77777       경제>유통       NaN       NaN  ...     NaN
# 77778    경제>산업_기업       NaN       NaN  ...     NaN
# 77779      경제>부동산       NaN       NaN  ...     NaN
# 77780   IT_과학>모바일       NaN       NaN  ...     NaN
# 77781         NaN       NaN       NaN  ...     NaN
#
#                                                   제목_키워드  \
# 0      [코스닥 공시] 코웰패션 / 유니셈 / MDS테크 코웰패션,유니셈,MDS테크,코웰패...
# 1      "함대 가라앉는건 순식간 총수부재 참담" 함대,순식간,함대,총수부재,참담,독일,세계...
# 2      LG유플러스, `천안역사 동아 라이크 텐`에 홈IoT 플랫폼 구축 LG유플러스,라이...
# 3      [Hot-Line] "해성옵틱스, 듀얼 카메라 확대에 따른 수혜 기대" 해성옵틱스,...
# 4      삼성 `갤노트8` 100만원 웃돌듯 고동진 "낮추려 노력했지만 어려워" 삼성,갤노트...
# ...                                                  ...
# 77777  '엔비디아 쇼크'서 회복 시도한 코스피 HLB, 코스닥 시총 3위 올라 엔비디아,쇼...
# 77778  외국인 매수에 코스피 강세 코스닥선 '바이오 vs 2차전지' 공방 외국인,매수,코스...
# 77779  코스피, 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피,외국인,매수,강...
# 77780  DB글로벌칩 대표에 박찬호 "DDI 설계로 제2의 도약" DB글로벌,대표,박찬호,D...
# 77781  인텔, 파운드리 힘 뺀다 인텔,파운드리,실적,부진,구조조정,인텔,파운드리,반도체,수...
#
#                                              제목_키워드_전처리후  \
# 0      코스닥 공시 코웰패션 유니셈 MDS테크 코웰패션 유니셈 MDS테크 코웰패션 안정적 ...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독일 세계가전...
# 2      LG유플러스 천안역사 동아 라이크 텐 에 홈IoT 플랫폼 구축 LG유플러스 라이크 ...
# 3      Hot-Line 해성옵틱스 듀얼 카메라 확대에 따른 수혜 기대 해성옵틱스 확대 듀얼...
# 4      삼성 갤노트8 100만원 웃돌듯 고동진 낮추려 노력했지만 어려워 삼성 갤노트 100...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 올라 엔비디아 쇼크 ...
# 77778  외국인 매수에 코스피 강세 코스닥선 바이오 vs 2차전지 공방 외국인 매수 코스피 ...
# 77779  코스피 외국인 매수에 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세...
# 77780  DB글로벌칩 대표에 박찬호 DDI 설계로 제2의 도약 DB글로벌 대표 박찬호 DDI...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                          제목_키워드_전처리후_Okt  \
# 0      코스닥 공시 코웰 패션 유니 셈 MDS 테크 코웰 패션 유니 셈 MDS 테크 코웰 ...
# 1      함대 가라앉는건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계...
# 2      LG 유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG 유플러스 라...
# 3      Hot - Line 해성 옵 틱 스 듀얼 카메라 확대 따른 수혜 기대 해성 옵 틱 ...
# 4      삼성 갤 노트 8 100만원 웃 돌듯 고동진 낮추려 노력 했지만 어려워 삼성 갤 노...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 한 코스피 HLB 코스닥 시 총 3 위 올라 엔비디아 ...
# 77778  외국인 매수 코스피 강세 코스닥 선 바이오 vs 2 차전지 공 방 외국인 매수 코스...
# 77779  코스피 외국인 매수 강세 삼성 SK 하이닉스 소 폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 뺀다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수탁...
#
#                                     제목_키워드_전처리후_Hannanum  \
# 0      코스닥 공시 코웰패션 유니셈 MDS 테크 코웰패션 유니셈 MDS 테크 코웰패션 안정...
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독 ㄹ 세계가...
# 2      LG유플러스 천안역사 동아 라이크 텐 홈IoT 플랫폼 구축 LG유플러스 라이크 천안...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 갤노트8 100만원 웃돌 듯 고동진 낮추 려 노력 었지만 어렵 삼성 갤노트 1...
# ...                                                  ...
# 77777  엔비디 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 오르 엔비디아 쇼크 회...
# 77778  외국 ㄴ 매수 코스피 강세 코스닥 선 바 vs 2차전지 공방 외국 ㄴ 매수 코스피 ...
# 77779  코스피 외국 ㄴ 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국 ㄴ 매수 강...
# 77780  DB 글로벌칩 대표 박찬호 DDI 설계 제2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드 리 힘 빼 ㄴ다 인텔 파운드 리 실적 부진 구조조정 인텔 파운드 리 반...
#
#                                         제목_키워드_전처리후_Kkma  \
# 0      코스닥 공시 코 웨 ㄹ 패션 유니 셈 MDS 테크 코 웨 ㄹ 패션 유니 셈 MDS ...
# 1      함대 가라앉 는 은 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG 유 플러스 천안 역사 동아 라이크 터 ㄴ 홈 IoT 플랫폼 구축 LG 유 플러...
# 3      Hot-Line 해성 옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성 옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만 원 웃돌 듯 고동진 낮추 려 노력 었 어렵 삼성 개...
# ...                                                  ...
# 77777  엔 비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 올르 엔 비...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK 하이닉스 소폭 반등 코스 피 외국인 매수 ...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체...
#
#                                      제목_키워드_전처리후_Komoran  \
# 0      코스닥 공시 코웰패션 유니 셈 MDS 테크 코웰패션 유니 셈 MDS 테크 코웰패션 ...
# 1      함대 가라앉 는 건 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 ...
# 2      LG유플러스 천안 역사 동아 라이 크 텐 홈 IoT 플랫폼 구축 LG유플러스 라이 ...
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...
# 4      삼성 개 ㄹ 노트 8 100 만원 웃돌 듯 고동진 낮추 려 노력 았 어렵 삼성 개 ...
# ...                                                  ...
# 77777  엔비디아 쇼크 서 회복 시도 ㄴ 코스 피 HLB 코스닥 시 총 3 위 오르 엔비디아...
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 vs 2 차 전지 공방 외국인 매수 코...
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...
# 77780  DB 글로벌 칩 대표 박찬호 DDI 설계 2 도약 DB 글로벌 대표 박찬호 DDI ...
# 77781  인텔 파운드리 힘 빼 ㄴ다 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 ...
#
#                                         제목_키워드_전처리후_kiwi  \
# 0      코스닥 공시 코웰 패션 유니셈 MDS 테크 코웰 패션 유니셈 MDS 테크 코웰 패션...
# 1      함대 순식간 총수 부재 참담 함대 순식간 함대 총수 부재 참담 독일 세계 가전 박람...
# 2      LG유플러스 천안 역사 동아 라이크 IoT 플랫폼 구축 LG유플러스 라이크 천안 역...
# 3      Hot Line 해성옵틱스 듀얼 카메라 확대 수혜 기대 해성옵틱스 확대 듀얼 카메라...
# 4      삼성 갤노트8 100 고동진 노력 어렵 삼성 노트 100 고동진 노력 노트 삼성전자...
# ...                                                  ...
# 77777  엔비디아 쇼크 회복 시도 코스피 HLB 코스닥 엔비디아 쇼크 회복 시도 코스피 HL...
# 77778  외국인 매수 코스피 강세 코스닥 바이오 vs 전지 공방 외국인 매수 코스피 강세 코...
# 77779  코스피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국인 매수 강세 ...
# 77780  DB 글로벌 대표 박찬호 DDI 설계 도약 DB 글로벌 대표 박찬호 DDI 설계 도...
# 77781  인텔 파운드리 인텔 파운드리 실적 부진 구조 조정 인텔 파운드리 반도체 수탁 생산 ...
#
#                                   제목_키워드_전처리후_Komoran_명사 Bert_Sentiment
# 0      코스닥 공시 유니 셈 테크 유니 셈 테크 안정 임대 수익 창출 펜타포트 토지 건물 ...            0.2
# 1      함대 건 순식간 총수 부재 함대 순식간 함대 총수 부재 독일 세계 가전 박람회 윤 ...            0.0
# 2      LG유플러스 천안 역사 동아 라이 텐 홈 플랫폼 구축 LG유플러스 라이 천안 역사 ...            0.0
# 3      카메라 확대 수혜 기대 확대 카메라 수혜 유진 투자 증권 채택 카메라 수혜 설립 전...            0.0
# 4      삼성 노트 만원 고동진 노력 삼성 노트 고동진 노력 노트 삼성전자 갤럭시 노트 가격...           -0.1
# ...                                                  ...            ...
# 77777  엔비디아 쇼크 회복 시도 코스 피 코스닥 시 총 위 엔비디아 쇼크 회복 시도 코스 ...            0.0
# 77778  외국인 매수 코스 피 강세 코스닥 선 바이오 차 전지 공방 외국인 매수 코스 피 강...            0.0
# 77779  코스 피 외국인 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스 피 외국인 매수 강...            0.0
# 77780  글로벌 칩 대표 박찬호 설계 도약 글로벌 대표 박찬호 설계 도약 분사 반도체 기업 ...            0.1
# 77781  인텔 파운드리 힘 인텔 파운드리 실적 부진 구조조정 인텔 파운드리 반도체 수 탁 생...            0.0
#
# [77782 rows x 28 columns]

# %%
df_bigkinds.columns
# Out:
# Index(['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2', '통합 분류3',
#        '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드',
#        '특성추출(가중치순 상위 50개)', '본문', 'URL', '분석제외 여부', '제목_키워드', '제목_키워드_전처리후',
#        '제목_키워드_전처리후_Okt', '제목_키워드_전처리후_Hannanum', '제목_키워드_전처리후_Kkma',
#        '제목_키워드_전처리후_Komoran', '제목_키워드_전처리후_kiwi', '제목_키워드_전처리후_Komoran_명사',
#        'Bert_Sentiment'],
#       dtype='object')

# %%
df_bigkinds.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT.xlsx', index=False)

# %%
df_bigkinds = df_bigkinds.groupby('일자', as_index=False)['Bert_Sentiment'].mean()
# 소수점 1자리로 반올림
df_bigkinds['Bert_Sentiment'] = df_bigkinds['Bert_Sentiment'].round(1)
df_bigkinds['Bert_Sentiment'] = df_bigkinds['Bert_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
df_bigkinds
# Out:
#              일자  Bert_Sentiment
# 0    2017-09-01             0.0
# 1    2017-09-02             0.1
# 2    2017-09-03             0.0
# 3    2017-09-04             0.1
# 4    2017-09-05             0.0
# ...         ...             ...
# 2551 2024-08-26             0.1
# 2552 2024-08-27             0.0
# 2553 2024-08-28             0.0
# 2554 2024-08-29             0.0
# 2555 2024-08-30             0.1
#
# [2556 rows x 2 columns]

# %%
# 감정 분석 결과 저장(일자별)
df_bigkinds.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT_daily.xlsx', index=False)

# %%
#KoBERT의 경우 다시 평가하는 경우 시간 소요 및 데이터가 변경되어 기존에 평가 데이터를 필터링하여 정상 데이터만 추출
import pandas as pd
# EXCEL파일 읽기
file_path = './Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT.xlsx'
df_bigkinds = pd.read_excel(file_path, converters={'뉴스 식별자': str})  # '뉴스 식별자'는 해당 열의 실제 이름으로 대체

df_bigkinds = df_bigkinds[df_bigkinds['분석제외 여부'].isnull()]

df_bigkinds

# 그룹핑할 컬럼 리스트
group_columns = ['제목_키워드_전처리후_Hannanum']

# 각 그룹에서 뉴스 식별자 컬럼의 최소값을 유지
df_bigkinds2 = df_bigkinds.groupby(group_columns, as_index=False).agg({'뉴스 식별자': 'min'})

# 필요한 컬럼만 선택하여 두 데이터프레임 병합
big_kinds_sentiment = pd.merge(
    df_bigkinds[['제목_키워드_전처리후_Hannanum', '뉴스 식별자','일자','Bert_Sentiment']],
    df_bigkinds2[['제목_키워드_전처리후_Hannanum', '뉴스 식별자']],
    on=['제목_키워드_전처리후_Hannanum', '뉴스 식별자'],
    how='inner'
)

big_kinds_sentiment = big_kinds_sentiment[['뉴스 식별자', '일자', '제목_키워드_전처리후_Hannanum', 'Bert_Sentiment']]
big_kinds_sentiment

big_kinds_sentiment.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT_filter.xlsx', index=False)

big_kinds_sentiment_avg = big_kinds_sentiment.groupby('일자', as_index=False)['Bert_Sentiment'].mean()
# 소수점 1자리로 반올림
big_kinds_sentiment_avg['Bert_Sentiment'] = big_kinds_sentiment_avg['Bert_Sentiment'].round(1)
big_kinds_sentiment_avg['Bert_Sentiment'] = big_kinds_sentiment_avg['Bert_Sentiment'].apply(lambda x: 0 if x == -0.0 else x)
# 결과 확인
big_kinds_sentiment_avg

# 감정 분석 결과 저장(일자별)
big_kinds_sentiment_avg.to_excel('./Text_Data/bigkinds/삼성전자_경제_20170901-20240830_전처리후_Hannanum_KoBERT_daily_filter.xlsx', index=False)

# %%
big_kinds_sentiment_avg
# Out:
#              일자  Bert_Sentiment
# 0    2017-09-01             0.0
# 1    2017-09-02             0.1
# 2    2017-09-03             0.0
# 3    2017-09-04             0.1
# 4    2017-09-05             0.0
# ...         ...             ...
# 2544 2024-08-26             0.1
# 2545 2024-08-27             0.0
# 2546 2024-08-28             0.0
# 2547 2024-08-29             0.0
# 2548 2024-08-30             0.1
#
# [2549 rows x 2 columns]

# %%
big_kinds_sentiment
# Out:
#                   뉴스 식별자         일자  \
# 0      20170901161300001 2017-09-01
# 1      20170901162741001 2017-09-01
# 2      20170901160436001 2017-09-01
# 3      20170901084332002 2017-09-01
# 4      20170901134823001 2017-09-01
# ...                  ...        ...
# 71106  20240830155007001 2024-08-30
# 71107  20240830110414001 2024-08-30
# 71108  20240830092005001 2024-08-30
# 71109  20240830174157001 2024-08-30
# 71110  20240830174248001 2024-08-30
#
#                                     제목_키워드_전처리후_Hannanum  Bert_Sentiment
# 0      코스닥 공시 코웰패션 유니셈 MDS 테크 코웰패션 유니셈 MDS 테크 코웰패션 안정...             0.2
# 1      함대 가라앉는건 순식간 총수부재 참담 함대 순식간 함대 총수부재 참담 독 ㄹ 세계가...             0.0
# 2      LG유플러스 천안역사 동아 라이크 텐 홈IoT 플랫폼 구축 LG유플러스 라이크 천안...             0.0
# 3      Hot - Line 해성옵틱스 듀얼 카메라 확대 따르 ㄴ 수혜 기대 해성옵틱스 확대...             0.0
# 4      삼성 갤노트8 100만원 웃돌 듯 고동진 낮추 려 노력 었지만 어렵 삼성 갤노트 1...            -0.1
# ...                                                  ...             ...
# 71106  엔비디 쇼크 서 회복 시도한 코스피 HLB 코스닥 시총 3위 오르 엔비디아 쇼크 회...             0.0
# 71107  외국 ㄴ 매수 코스피 강세 코스닥 선 바 vs 2차전지 공방 외국 ㄴ 매수 코스피 ...             0.0
# 71108  코스피 외국 ㄴ 매수 강세 삼성전자 SK하이닉스 소폭 반등 코스피 외국 ㄴ 매수 강...             0.0
# 71109  DB 글로벌칩 대표 박찬호 DDI 설계 제2 도약 DB 글로벌 대표 박찬호 DDI ...             0.1
# 71110  인텔 파운드 리 힘 빼 ㄴ다 인텔 파운드 리 실적 부진 구조조정 인텔 파운드 리 반...             0.0
#
# [71111 rows x 4 columns]
